# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import pyreadstat
import requests
import statsmodels.api as smf
from stargazer.stargazer import Stargazer

# %%
'''
Regressions/Data 

I can do a deep dive into the food service industry, and run two types of regressions: A "Diff-in-Diff" kind of 
regression that measures it with a very rough treatment. I could also look at how exposure score to AI (provided by
Michael Webb) relates to the number of feeling tasks relating to jobs within that industry. I could also do a 
Diff-in-Diff with the change in the number of feeling tasks in an industry/job as the dependent variable, and the 
treatment being invention of IBM Watson. 

1. Difference in Differences
    - dependent variables: mean wages by occupation, mean employment by occupation
    - treatment variables: invention of IBM Watson (2014), 
    - control variables: age, race, education, etc. 
    
2. A lot of people/research has looked at the task-level changes over time. I could look at a specific industry, for 
example, the food service industry and then classify tasks for each job as thinking, feeling, or mechanical. I could 
then regress the mean wage and employment for jobs within those industries over time (between 2000 and 2019), 
controlling for: 
    1. indicator = 1 if in quantile of tasks that are "mechanical/thinking"
    2. exposure score for that job
    3. year fixed effects 
    4. extra controls. 
    
3. Jobs to compare: 
    1. Fast food Cooks (35-2011.00) to Chefs/Head Chefs (35-1011.00)
    2. Radiologists/Telemarketers (replaced) vs Teachers/Librarians (increased production/helped by AI) vs
       Athletes (not at all affected by AI aside from advice) 
       
       
4. New Type of Analysis: Comparing Jobs with Mechanical Work that can be completely replaced by AI with Jobs that
    can only be replaced partially by AI. 
    
    Agrawal, Gans, Goldfarb: Artificial Intelligence: The Ambiguous Labor Market Impact of Automating Prediction
        - Types of substitution: 
            - substitute capital for labor in prediction tasks (Automating Prediction Tasks) 
                - decrease in employment, decrease in wage? 
                - Legal Services
                    - Kira Systems uses AI to scan contracts and summarize relevant content in the fraction of time
                      it would take a lawyer or *paralegal*, lawyers still have to make decisions
                    - BlueJ makes judicial decisions easier by using AI to predict the correct verdict. 
                - Automating Email Responses 
                    - Correspondence Clerks, Tellers, Receptionists and Information Clerks, Medical Secretaries
                        License Clerks, Legal Secretaries, Insurance Policy Processing Clerks, *Executive Assistants*
                
            - automating decision tasks when automating prediction increases the relative returns to capital vs labor
              (Automating Decision Tasks)
                - decrease in employment, increase in wage? 
                - nothing very substantial here 
                
            - enhancing labor when automating the prediction task increases labor productivity (Augmenting Labor
              on Decision Tasks)
                - ambiguous on employment, increase in wage? 
                - Radiologists, only two tasks are directly affeted by an image recognition AI, plenty of human
                  facing tasks remain. Question is: are these taks better performed by someone who is not a 
                  radiologist? 
                
            - creating new decision tasks when automating prediction sufficiently reduces uncertainty as to enable 
              new decisions that were not feasible before. 
                  - increase in employment, increase in wage? 
                  
                  
    Idea: Instead of trying to isolate solely the impact of AI, since that is almost impossible, try to isolate 
          jobs that fall into these different categories and compare how their wages and employment change over
          time. Can still use a Diff-in-Diff like analysis by using IBM Watson as a treatment. 
          
          Jobs to Compare:
          (Augment Labor on Decision Tasks) |   (Automating Prediction Tasks)
    
          Diagnostic Related Technicians    |   Secretaries and Administrative Assistants
          (292030), (292031-292035, 29203X)     (436010), (436011-436014)
          
          Paralegals & Legal Assistants     |   Insurance Claims and Policy Processing Clerks
          (232011)                              (439041)
          
          Financial Analysts                |   Tellers (in Financial Industry)
          (132051)                              (433071) 
          
          Financial Analysts                |   Credit Analysts
                                                (132041)
          
          Accountants & Auditors            |   Secretaries and Administrative Assistants
          (132011)
          
          Paralegals/Lawyers                |   Secretaries and Administrative Assistants
          
                                            |   Telemarketers (419041)
          
          
'''

# %% [markdown]
# **LOOKING ONLY AT COOKS AND FOOD PREPARATION WORKERS**

# %%
code_df = {} 

code_df['419041'] = 'Telemarketers'
code_df['132011'] = 'Accountants & Auditors' 
code_df['132041'] = 'Credit Analysts'
code_df['433071'] = 'Tellers'
code_df['132051'] = 'Financial Analysts'
code_df['439041'] = 'Insurance Claims and Policy Processing Clerks' 
code_df['232011'] = 'Paralegals & Legal Assistants'

code_df['292030'] = 'Diagnostic Related Technicians'
code_df['292031'] = 'Diagnostic Related Technicians'
code_df['292032'] = 'Diagnostic Related Technicians'
code_df['292033'] = 'Diagnostic Related Technicians'
code_df['292034'] = 'Diagnostic Related Technicians'
code_df['292035'] = 'Diagnostic Related Technicians'
code_df['29203X'] = 'Diagnostic Related Technicians'

code_df['436010'] = 'Secretaries and Administrative Assistants'
code_df['436011'] = 'Secretaries and Administrative Assistants'
code_df['436012'] = 'Secretaries and Administrative Assistants'
code_df['436013'] = 'Secretaries and Administrative Assistants'
code_df['436014'] = 'Secretaries and Administrative Assistants'
# code_df['351011'] = "Chefs and Head Cooks"
# code_df['351012'] = "First-Line Supervisors of Food Preparation and Serving Workers"
# code_df['352010'] = "Cooks"
# code_df['352021'] = "Food Preparation Workers"
# code_df['353021'] = "Combined Food Preparation and Serving Workers, Including Fast Food"
# code_df['353022'] = "Counter Attendant, Cafeteria, Food Concession, and Coffee Shop"
# code_df['353023'] = "Fast Food and Counter Workers"


codes = list(code_df.keys())

# %%
 # Assumptions: Looking only @ Full-Time, Full-Year Workers (35+ hours worked, 40+ weeks worked)

# read in IPUMS Data and take only full-time full-year workers
# also only take ages 18-65

TextFileReader = pd.read_csv("data/usa_00010.csv", chunksize = 20000)

def calculate_emp(x, y): 
    if (x == 1): 
        return x*y
    else: 
        return 0 

dfList = []
counter = 0
for df in TextFileReader: 
    
    # extract important rows 
    df = df[(df['AGE'] >= 18) & (df['AGE'] <= 65)]
    
    # get only occupations of interest from 2000 to 2017 
    df = df[df['OCCSOC'].isin(codes)]
    
    # get full-time, full-year workers (35+ hours/wk, 40+ wks/yr)
    df = df[(df['UHRSWORK'] >= 35)]
    df = df[(df['WKSWORK1'] >= 40) | (df['WKSWORK2'] >= 4)]
    
    dfList.append(df)
    
    # verbose...
    counter += 1 
    if (counter % 100000): 
        print("processed ", round(counter*20000*100/65483126, 3), " percent of rows")

df = pd.concat(dfList, sort=False)
df
# Out:
# processed  0.031  percent of rows
# processed  0.061  percent of rows
# processed  0.092  percent of rows
# processed  0.122  percent of rows
# processed  0.153  percent of rows
# processed  0.183  percent of rows
# processed  0.214  percent of rows
# processed  0.244  percent of rows
# processed  0.275  percent of rows
# processed  0.305  percent of rows
# processed  0.336  percent of rows
# processed  0.367  percent of rows
# processed  0.397  percent of rows
# processed  0.428  percent of rows
# processed  0.458  percent of rows
# processed  0.489  percent of rows
# processed  0.519  percent of rows
# processed  0.55  percent of rows
# processed  0.58  percent of rows
# processed  0.611  percent of rows
# processed  0.641  percent of rows
# processed  0.672  percent of rows
# processed  0.702  percent of rows
# processed  0.733  percent of rows
# processed  0.764  percent of rows
# processed  0.794  percent of rows
# processed  0.825  percent of rows
# processed  0.855  percent of rows
# processed  0.886  percent of rows
# processed  0.916  percent of rows
# processed  0.947  percent of rows
# processed  0.977  percent of rows
# processed  1.008  percent of rows
# processed  1.038  percent of rows
# processed  1.069  percent of rows
# processed  1.1  percent of rows
# processed  1.13  percent of rows
# processed  1.161  percent of rows
# processed  1.191  percent of rows
# processed  1.222  percent of rows
# processed  1.252  percent of rows
# processed  1.283  percent of rows
# processed  1.313  percent of rows
# processed  1.344  percent of rows
# processed  1.374  percent of rows
# processed  1.405  percent of rows
# processed  1.435  percent of rows
# processed  1.466  percent of rows
# processed  1.497  percent of rows
# processed  1.527  percent of rows
# processed  1.558  percent of rows
# processed  1.588  percent of rows
# processed  1.619  percent of rows
# processed  1.649  percent of rows
# processed  1.68  percent of rows
# processed  1.71  percent of rows
# processed  1.741  percent of rows
# processed  1.771  percent of rows
# processed  1.802  percent of rows
# processed  1.833  percent of rows
# processed  1.863  percent of rows
# processed  1.894  percent of rows
# processed  1.924  percent of rows
# processed  1.955  percent of rows
# processed  1.985  percent of rows
# processed  2.016  percent of rows
# processed  2.046  percent of rows
# processed  2.077  percent of rows
# processed  2.107  percent of rows
# processed  2.138  percent of rows
# processed  2.168  percent of rows
# processed  2.199  percent of rows
# processed  2.23  percent of rows
# processed  2.26  percent of rows
# processed  2.291  percent of rows
# processed  2.321  percent of rows
# processed  2.352  percent of rows
# processed  2.382  percent of rows
# processed  2.413  percent of rows
# processed  2.443  percent of rows
# processed  2.474  percent of rows
# processed  2.504  percent of rows
# processed  2.535  percent of rows
# processed  2.566  percent of rows
# processed  2.596  percent of rows
# processed  2.627  percent of rows
# processed  2.657  percent of rows
# processed  2.688  percent of rows
# processed  2.718  percent of rows
# processed  2.749  percent of rows
# processed  2.779  percent of rows
# processed  2.81  percent of rows
# processed  2.84  percent of rows
# processed  2.871  percent of rows
# processed  2.902  percent of rows
# processed  2.932  percent of rows
# processed  2.963  percent of rows
# processed  2.993  percent of rows
# processed  3.024  percent of rows
# processed  3.054  percent of rows
# processed  3.085  percent of rows
# processed  3.115  percent of rows
# processed  3.146  percent of rows
# processed  3.176  percent of rows
# processed  3.207  percent of rows
# processed  3.237  percent of rows
# processed  3.268  percent of rows
# processed  3.299  percent of rows
# processed  3.329  percent of rows
# processed  3.36  percent of rows
# processed  3.39  percent of rows
# processed  3.421  percent of rows
# processed  3.451  percent of rows
# processed  3.482  percent of rows
# processed  3.512  percent of rows
# processed  3.543  percent of rows
# processed  3.573  percent of rows
# processed  3.604  percent of rows
# processed  3.635  percent of rows
# processed  3.665  percent of rows
# processed  3.696  percent of rows
# processed  3.726  percent of rows
# processed  3.757  percent of rows
# processed  3.787  percent of rows
# processed  3.818  percent of rows
# processed  3.848  percent of rows
# processed  3.879  percent of rows
# processed  3.909  percent of rows
# processed  3.94  percent of rows
# processed  3.97  percent of rows
# processed  4.001  percent of rows
# processed  4.032  percent of rows
# processed  4.062  percent of rows
# processed  4.093  percent of rows
# processed  4.123  percent of rows
# processed  4.154  percent of rows
# processed  4.184  percent of rows
# processed  4.215  percent of rows
# processed  4.245  percent of rows
# processed  4.276  percent of rows
# processed  4.306  percent of rows
# processed  4.337  percent of rows
# processed  4.368  percent of rows
# processed  4.398  percent of rows
# processed  4.429  percent of rows
# processed  4.459  percent of rows
# processed  4.49  percent of rows
# processed  4.52  percent of rows
# processed  4.551  percent of rows
# processed  4.581  percent of rows
# processed  4.612  percent of rows
# processed  4.642  percent of rows
# processed  4.673  percent of rows
# processed  4.704  percent of rows
# processed  4.734  percent of rows
# processed  4.765  percent of rows
# processed  4.795  percent of rows
# processed  4.826  percent of rows
# processed  4.856  percent of rows
# processed  4.887  percent of rows
# processed  4.917  percent of rows
# processed  4.948  percent of rows
# processed  4.978  percent of rows
# processed  5.009  percent of rows
# processed  5.039  percent of rows
# processed  5.07  percent of rows
# processed  5.101  percent of rows
# processed  5.131  percent of rows
# processed  5.162  percent of rows
# processed  5.192  percent of rows
# processed  5.223  percent of rows
# processed  5.253  percent of rows
# processed  5.284  percent of rows
# processed  5.314  percent of rows
# processed  5.345  percent of rows
# processed  5.375  percent of rows
# processed  5.406  percent of rows
# processed  5.437  percent of rows
# processed  5.467  percent of rows
# processed  5.498  percent of rows
# processed  5.528  percent of rows
# processed  5.559  percent of rows
# processed  5.589  percent of rows
# processed  5.62  percent of rows
# processed  5.65  percent of rows
# processed  5.681  percent of rows
# processed  5.711  percent of rows
# processed  5.742  percent of rows
# processed  5.772  percent of rows
# processed  5.803  percent of rows
# processed  5.834  percent of rows
# processed  5.864  percent of rows
# processed  5.895  percent of rows
# processed  5.925  percent of rows
# processed  5.956  percent of rows
# processed  5.986  percent of rows
# processed  6.017  percent of rows
# processed  6.047  percent of rows
# processed  6.078  percent of rows
# processed  6.108  percent of rows
# processed  6.139  percent of rows
# processed  6.17  percent of rows
# processed  6.2  percent of rows
# processed  6.231  percent of rows
# processed  6.261  percent of rows
# processed  6.292  percent of rows
# processed  6.322  percent of rows
# processed  6.353  percent of rows
# processed  6.383  percent of rows
# processed  6.414  percent of rows
# processed  6.444  percent of rows
# processed  6.475  percent of rows
# processed  6.505  percent of rows
# processed  6.536  percent of rows
# processed  6.567  percent of rows
# processed  6.597  percent of rows
# processed  6.628  percent of rows
# processed  6.658  percent of rows
# processed  6.689  percent of rows
# processed  6.719  percent of rows
# processed  6.75  percent of rows
# processed  6.78  percent of rows
# processed  6.811  percent of rows
# processed  6.841  percent of rows
# processed  6.872  percent of rows
# processed  6.903  percent of rows
# processed  6.933  percent of rows
# processed  6.964  percent of rows
# processed  6.994  percent of rows
# processed  7.025  percent of rows
# processed  7.055  percent of rows
# processed  7.086  percent of rows
# processed  7.116  percent of rows
# processed  7.147  percent of rows
# processed  7.177  percent of rows
# processed  7.208  percent of rows
# processed  7.239  percent of rows
# processed  7.269  percent of rows
# processed  7.3  percent of rows
# processed  7.33  percent of rows
# processed  7.361  percent of rows
# processed  7.391  percent of rows
# processed  7.422  percent of rows
# processed  7.452  percent of rows
# processed  7.483  percent of rows
# processed  7.513  percent of rows
# processed  7.544  percent of rows
# processed  7.574  percent of rows
# processed  7.605  percent of rows
# processed  7.636  percent of rows
# processed  7.666  percent of rows
# processed  7.697  percent of rows
# processed  7.727  percent of rows
# processed  7.758  percent of rows
# processed  7.788  percent of rows
# processed  7.819  percent of rows
# processed  7.849  percent of rows
# processed  7.88  percent of rows
# processed  7.91  percent of rows
# processed  7.941  percent of rows
# processed  7.972  percent of rows
# processed  8.002  percent of rows
# processed  8.033  percent of rows
# processed  8.063  percent of rows
# processed  8.094  percent of rows
# processed  8.124  percent of rows
# processed  8.155  percent of rows
# processed  8.185  percent of rows
# processed  8.216  percent of rows
# processed  8.246  percent of rows
# processed  8.277  percent of rows
# processed  8.307  percent of rows
# processed  8.338  percent of rows
# processed  8.369  percent of rows
# processed  8.399  percent of rows
# processed  8.43  percent of rows
# processed  8.46  percent of rows
# processed  8.491  percent of rows
# processed  8.521  percent of rows
# processed  8.552  percent of rows
# processed  8.582  percent of rows
# processed  8.613  percent of rows
# processed  8.643  percent of rows
# processed  8.674  percent of rows
# processed  8.705  percent of rows
# processed  8.735  percent of rows
# processed  8.766  percent of rows
# processed  8.796  percent of rows
# processed  8.827  percent of rows
# processed  8.857  percent of rows
# processed  8.888  percent of rows
# processed  8.918  percent of rows
# processed  8.949  percent of rows
# processed  8.979  percent of rows
# processed  9.01  percent of rows
# processed  9.04  percent of rows
# processed  9.071  percent of rows
# processed  9.102  percent of rows
# processed  9.132  percent of rows
# processed  9.163  percent of rows
# processed  9.193  percent of rows
# processed  9.224  percent of rows
# processed  9.254  percent of rows
# processed  9.285  percent of rows
# processed  9.315  percent of rows
# processed  9.346  percent of rows
# processed  9.376  percent of rows
# processed  9.407  percent of rows
# processed  9.438  percent of rows
# processed  9.468  percent of rows
# processed  9.499  percent of rows
# processed  9.529  percent of rows
# processed  9.56  percent of rows
# processed  9.59  percent of rows
# processed  9.621  percent of rows
# processed  9.651  percent of rows
# processed  9.682  percent of rows
# processed  9.712  percent of rows
# processed  9.743  percent of rows
# processed  9.774  percent of rows
# processed  9.804  percent of rows
# processed  9.835  percent of rows
# processed  9.865  percent of rows
# processed  9.896  percent of rows
# processed  9.926  percent of rows
# processed  9.957  percent of rows
# processed  9.987  percent of rows
# processed  10.018  percent of rows
# processed  10.048  percent of rows
# processed  10.079  percent of rows
# processed  10.109  percent of rows
# processed  10.14  percent of rows
# processed  10.171  percent of rows
# processed  10.201  percent of rows
# processed  10.232  percent of rows
# processed  10.262  percent of rows
# processed  10.293  percent of rows
# processed  10.323  percent of rows
# processed  10.354  percent of rows
# processed  10.384  percent of rows
# processed  10.415  percent of rows
# processed  10.445  percent of rows
# processed  10.476  percent of rows
# processed  10.507  percent of rows
# processed  10.537  percent of rows
# processed  10.568  percent of rows
# processed  10.598  percent of rows
# processed  10.629  percent of rows
# processed  10.659  percent of rows
# processed  10.69  percent of rows
# processed  10.72  percent of rows
# processed  10.751  percent of rows
# processed  10.781  percent of rows
# processed  10.812  percent of rows
# processed  10.842  percent of rows
# processed  10.873  percent of rows
# processed  10.904  percent of rows
# processed  10.934  percent of rows
# processed  10.965  percent of rows
# processed  10.995  percent of rows
# processed  11.026  percent of rows
# processed  11.056  percent of rows
# processed  11.087  percent of rows
# processed  11.117  percent of rows
# processed  11.148  percent of rows
# processed  11.178  percent of rows
# processed  11.209  percent of rows
# processed  11.24  percent of rows
# processed  11.27  percent of rows
# processed  11.301  percent of rows
# processed  11.331  percent of rows
# processed  11.362  percent of rows
# processed  11.392  percent of rows
# processed  11.423  percent of rows
# processed  11.453  percent of rows
# processed  11.484  percent of rows
# processed  11.514  percent of rows
# processed  11.545  percent of rows
# processed  11.576  percent of rows
# processed  11.606  percent of rows
# processed  11.637  percent of rows
# processed  11.667  percent of rows
# processed  11.698  percent of rows
# processed  11.728  percent of rows
# processed  11.759  percent of rows
# processed  11.789  percent of rows
# processed  11.82  percent of rows
# processed  11.85  percent of rows
# processed  11.881  percent of rows
# processed  11.911  percent of rows
# processed  11.942  percent of rows
# processed  11.973  percent of rows
# processed  12.003  percent of rows
# processed  12.034  percent of rows
# processed  12.064  percent of rows
# processed  12.095  percent of rows
# processed  12.125  percent of rows
# processed  12.156  percent of rows
# processed  12.186  percent of rows
# processed  12.217  percent of rows
# processed  12.247  percent of rows
# processed  12.278  percent of rows
# processed  12.309  percent of rows
# processed  12.339  percent of rows
# processed  12.37  percent of rows
# processed  12.4  percent of rows
# processed  12.431  percent of rows
# processed  12.461  percent of rows
# processed  12.492  percent of rows
# processed  12.522  percent of rows
# processed  12.553  percent of rows
# processed  12.583  percent of rows
# processed  12.614  percent of rows
# processed  12.644  percent of rows
# processed  12.675  percent of rows
# processed  12.706  percent of rows
# processed  12.736  percent of rows
# processed  12.767  percent of rows
# processed  12.797  percent of rows
# processed  12.828  percent of rows
# processed  12.858  percent of rows
# processed  12.889  percent of rows
# processed  12.919  percent of rows
# processed  12.95  percent of rows
# processed  12.98  percent of rows
# processed  13.011  percent of rows
# processed  13.042  percent of rows
# processed  13.072  percent of rows
# processed  13.103  percent of rows
# processed  13.133  percent of rows
# processed  13.164  percent of rows
# processed  13.194  percent of rows
# processed  13.225  percent of rows
# processed  13.255  percent of rows
# processed  13.286  percent of rows
# processed  13.316  percent of rows
# processed  13.347  percent of rows
# processed  13.377  percent of rows
# processed  13.408  percent of rows
# processed  13.439  percent of rows
# processed  13.469  percent of rows
# processed  13.5  percent of rows
# processed  13.53  percent of rows
# processed  13.561  percent of rows
# processed  13.591  percent of rows
# processed  13.622  percent of rows
# processed  13.652  percent of rows
# processed  13.683  percent of rows
# processed  13.713  percent of rows
# processed  13.744  percent of rows
# processed  13.775  percent of rows
# processed  13.805  percent of rows
# processed  13.836  percent of rows
# processed  13.866  percent of rows
# processed  13.897  percent of rows
# processed  13.927  percent of rows
# processed  13.958  percent of rows
# processed  13.988  percent of rows
# processed  14.019  percent of rows
# processed  14.049  percent of rows
# processed  14.08  percent of rows
# processed  14.111  percent of rows
# processed  14.141  percent of rows
# processed  14.172  percent of rows
# processed  14.202  percent of rows
# processed  14.233  percent of rows
# processed  14.263  percent of rows
# processed  14.294  percent of rows
# processed  14.324  percent of rows
# processed  14.355  percent of rows
# processed  14.385  percent of rows
# processed  14.416  percent of rows
# processed  14.446  percent of rows
# processed  14.477  percent of rows
# processed  14.508  percent of rows
# processed  14.538  percent of rows
# processed  14.569  percent of rows
# processed  14.599  percent of rows
# processed  14.63  percent of rows
# processed  14.66  percent of rows
# processed  14.691  percent of rows
# processed  14.721  percent of rows
# processed  14.752  percent of rows
# processed  14.782  percent of rows
# processed  14.813  percent of rows
# processed  14.844  percent of rows
# processed  14.874  percent of rows
# processed  14.905  percent of rows
# processed  14.935  percent of rows
# processed  14.966  percent of rows
# processed  14.996  percent of rows
# processed  15.027  percent of rows
# processed  15.057  percent of rows
# processed  15.088  percent of rows
# processed  15.118  percent of rows
# processed  15.149  percent of rows
# processed  15.179  percent of rows
# processed  15.21  percent of rows
# processed  15.241  percent of rows
# processed  15.271  percent of rows
# processed  15.302  percent of rows
# processed  15.332  percent of rows
# processed  15.363  percent of rows
# processed  15.393  percent of rows
# processed  15.424  percent of rows
# processed  15.454  percent of rows
# processed  15.485  percent of rows
# processed  15.515  percent of rows
# processed  15.546  percent of rows
# processed  15.577  percent of rows
# processed  15.607  percent of rows
# processed  15.638  percent of rows
# processed  15.668  percent of rows
# processed  15.699  percent of rows
# processed  15.729  percent of rows
# processed  15.76  percent of rows
# processed  15.79  percent of rows
# processed  15.821  percent of rows
# processed  15.851  percent of rows
# processed  15.882  percent of rows
# processed  15.912  percent of rows
# processed  15.943  percent of rows
# processed  15.974  percent of rows
# processed  16.004  percent of rows
# processed  16.035  percent of rows
# processed  16.065  percent of rows
# processed  16.096  percent of rows
# processed  16.126  percent of rows
# processed  16.157  percent of rows
# processed  16.187  percent of rows
# processed  16.218  percent of rows
# processed  16.248  percent of rows
# processed  16.279  percent of rows
# processed  16.31  percent of rows
# processed  16.34  percent of rows
# processed  16.371  percent of rows
# processed  16.401  percent of rows
# processed  16.432  percent of rows
# processed  16.462  percent of rows
# processed  16.493  percent of rows
# processed  16.523  percent of rows
# processed  16.554  percent of rows
# processed  16.584  percent of rows
# processed  16.615  percent of rows
# processed  16.646  percent of rows
# processed  16.676  percent of rows
# processed  16.707  percent of rows
# processed  16.737  percent of rows
# processed  16.768  percent of rows
# processed  16.798  percent of rows
# processed  16.829  percent of rows
# processed  16.859  percent of rows
# processed  16.89  percent of rows
# processed  16.92  percent of rows
# processed  16.951  percent of rows
# processed  16.981  percent of rows
# processed  17.012  percent of rows
# processed  17.043  percent of rows
# processed  17.073  percent of rows
# processed  17.104  percent of rows
# processed  17.134  percent of rows
# processed  17.165  percent of rows
# processed  17.195  percent of rows
# processed  17.226  percent of rows
# processed  17.256  percent of rows
# processed  17.287  percent of rows
# processed  17.317  percent of rows
# processed  17.348  percent of rows
# processed  17.379  percent of rows
# processed  17.409  percent of rows
# processed  17.44  percent of rows
# processed  17.47  percent of rows
# processed  17.501  percent of rows
# processed  17.531  percent of rows
# processed  17.562  percent of rows
# processed  17.592  percent of rows
# processed  17.623  percent of rows
# processed  17.653  percent of rows
# processed  17.684  percent of rows
# processed  17.714  percent of rows
# processed  17.745  percent of rows
# processed  17.776  percent of rows
# processed  17.806  percent of rows
# processed  17.837  percent of rows
# processed  17.867  percent of rows
# processed  17.898  percent of rows
# processed  17.928  percent of rows
# processed  17.959  percent of rows
# processed  17.989  percent of rows
# processed  18.02  percent of rows
# processed  18.05  percent of rows
# processed  18.081  percent of rows
# processed  18.112  percent of rows
# processed  18.142  percent of rows
# processed  18.173  percent of rows
# processed  18.203  percent of rows
# processed  18.234  percent of rows
# processed  18.264  percent of rows
# processed  18.295  percent of rows
# processed  18.325  percent of rows
# processed  18.356  percent of rows
# processed  18.386  percent of rows
# processed  18.417  percent of rows
# processed  18.448  percent of rows
# processed  18.478  percent of rows
# processed  18.509  percent of rows
# processed  18.539  percent of rows
# processed  18.57  percent of rows
# processed  18.6  percent of rows
# processed  18.631  percent of rows
# processed  18.661  percent of rows
# processed  18.692  percent of rows
# processed  18.722  percent of rows
# processed  18.753  percent of rows
# processed  18.783  percent of rows
# processed  18.814  percent of rows
# processed  18.845  percent of rows
# processed  18.875  percent of rows
# processed  18.906  percent of rows
# processed  18.936  percent of rows
# processed  18.967  percent of rows
# processed  18.997  percent of rows
# processed  19.028  percent of rows
# processed  19.058  percent of rows
# processed  19.089  percent of rows
# processed  19.119  percent of rows
# processed  19.15  percent of rows
# processed  19.181  percent of rows
# processed  19.211  percent of rows
# processed  19.242  percent of rows
# processed  19.272  percent of rows
# processed  19.303  percent of rows
# processed  19.333  percent of rows
# processed  19.364  percent of rows
# processed  19.394  percent of rows
# processed  19.425  percent of rows
# processed  19.455  percent of rows
# processed  19.486  percent of rows
# processed  19.516  percent of rows
# processed  19.547  percent of rows
# processed  19.578  percent of rows
# processed  19.608  percent of rows
# processed  19.639  percent of rows
# processed  19.669  percent of rows
# processed  19.7  percent of rows
# processed  19.73  percent of rows
# processed  19.761  percent of rows
# processed  19.791  percent of rows
# processed  19.822  percent of rows
# processed  19.852  percent of rows
# processed  19.883  percent of rows
# processed  19.914  percent of rows
# processed  19.944  percent of rows
# processed  19.975  percent of rows
# processed  20.005  percent of rows
# processed  20.036  percent of rows
# processed  20.066  percent of rows
# processed  20.097  percent of rows
# processed  20.127  percent of rows
# processed  20.158  percent of rows
# processed  20.188  percent of rows
# processed  20.219  percent of rows
# processed  20.249  percent of rows
# processed  20.28  percent of rows
# processed  20.311  percent of rows
# processed  20.341  percent of rows
# processed  20.372  percent of rows
# processed  20.402  percent of rows
# processed  20.433  percent of rows
# processed  20.463  percent of rows
# processed  20.494  percent of rows
# processed  20.524  percent of rows
# processed  20.555  percent of rows
# processed  20.585  percent of rows
# processed  20.616  percent of rows
# processed  20.647  percent of rows
# processed  20.677  percent of rows
# processed  20.708  percent of rows
# processed  20.738  percent of rows
# processed  20.769  percent of rows
# processed  20.799  percent of rows
# processed  20.83  percent of rows
# processed  20.86  percent of rows
# processed  20.891  percent of rows
# processed  20.921  percent of rows
# processed  20.952  percent of rows
# processed  20.983  percent of rows
# processed  21.013  percent of rows
# processed  21.044  percent of rows
# processed  21.074  percent of rows
# processed  21.105  percent of rows
# processed  21.135  percent of rows
# processed  21.166  percent of rows
# processed  21.196  percent of rows
# processed  21.227  percent of rows
# processed  21.257  percent of rows
# processed  21.288  percent of rows
# processed  21.318  percent of rows
# processed  21.349  percent of rows
# processed  21.38  percent of rows
# processed  21.41  percent of rows
# processed  21.441  percent of rows
# processed  21.471  percent of rows
# processed  21.502  percent of rows
# processed  21.532  percent of rows
# processed  21.563  percent of rows
# processed  21.593  percent of rows
# processed  21.624  percent of rows
# processed  21.654  percent of rows
# processed  21.685  percent of rows
# processed  21.716  percent of rows
# processed  21.746  percent of rows
# processed  21.777  percent of rows
# processed  21.807  percent of rows
# processed  21.838  percent of rows
# processed  21.868  percent of rows
# processed  21.899  percent of rows
# processed  21.929  percent of rows
# processed  21.96  percent of rows
# processed  21.99  percent of rows
# processed  22.021  percent of rows
# processed  22.051  percent of rows
# processed  22.082  percent of rows
# processed  22.113  percent of rows
# processed  22.143  percent of rows
# processed  22.174  percent of rows
# processed  22.204  percent of rows
# processed  22.235  percent of rows
# processed  22.265  percent of rows
# processed  22.296  percent of rows
# processed  22.326  percent of rows
# processed  22.357  percent of rows
# processed  22.387  percent of rows
# processed  22.418  percent of rows
# processed  22.449  percent of rows
# processed  22.479  percent of rows
# processed  22.51  percent of rows
# processed  22.54  percent of rows
# processed  22.571  percent of rows
# processed  22.601  percent of rows
# processed  22.632  percent of rows
# processed  22.662  percent of rows
# processed  22.693  percent of rows
# processed  22.723  percent of rows
# processed  22.754  percent of rows
# processed  22.784  percent of rows
# processed  22.815  percent of rows
# processed  22.846  percent of rows
# processed  22.876  percent of rows
# processed  22.907  percent of rows
# processed  22.937  percent of rows
# processed  22.968  percent of rows
# processed  22.998  percent of rows
# processed  23.029  percent of rows
# processed  23.059  percent of rows
# processed  23.09  percent of rows
# processed  23.12  percent of rows
# processed  23.151  percent of rows
# processed  23.182  percent of rows
# processed  23.212  percent of rows
# processed  23.243  percent of rows
# processed  23.273  percent of rows
# processed  23.304  percent of rows
# processed  23.334  percent of rows
# processed  23.365  percent of rows
# processed  23.395  percent of rows
# processed  23.426  percent of rows
# processed  23.456  percent of rows
# processed  23.487  percent of rows
# processed  23.518  percent of rows
# processed  23.548  percent of rows
# processed  23.579  percent of rows
# processed  23.609  percent of rows
# processed  23.64  percent of rows
# processed  23.67  percent of rows
# processed  23.701  percent of rows
# processed  23.731  percent of rows
# processed  23.762  percent of rows
# processed  23.792  percent of rows
# processed  23.823  percent of rows
# processed  23.853  percent of rows
# processed  23.884  percent of rows
# processed  23.915  percent of rows
# processed  23.945  percent of rows
# processed  23.976  percent of rows
# processed  24.006  percent of rows
# processed  24.037  percent of rows
# processed  24.067  percent of rows
# processed  24.098  percent of rows
# processed  24.128  percent of rows
# processed  24.159  percent of rows
# processed  24.189  percent of rows
# processed  24.22  percent of rows
# processed  24.251  percent of rows
# processed  24.281  percent of rows
# processed  24.312  percent of rows
# processed  24.342  percent of rows
# processed  24.373  percent of rows
# processed  24.403  percent of rows
# processed  24.434  percent of rows
# processed  24.464  percent of rows
# processed  24.495  percent of rows
# processed  24.525  percent of rows
# processed  24.556  percent of rows
# processed  24.586  percent of rows
# processed  24.617  percent of rows
# processed  24.648  percent of rows
# processed  24.678  percent of rows
# processed  24.709  percent of rows
# processed  24.739  percent of rows
# processed  24.77  percent of rows
# processed  24.8  percent of rows
# processed  24.831  percent of rows
# processed  24.861  percent of rows
# processed  24.892  percent of rows
# processed  24.922  percent of rows
# processed  24.953  percent of rows
# processed  24.984  percent of rows
# processed  25.014  percent of rows
# processed  25.045  percent of rows
# processed  25.075  percent of rows
# processed  25.106  percent of rows
# processed  25.136  percent of rows
# processed  25.167  percent of rows
# processed  25.197  percent of rows
# processed  25.228  percent of rows
# processed  25.258  percent of rows
# processed  25.289  percent of rows
# processed  25.319  percent of rows
# processed  25.35  percent of rows
# processed  25.381  percent of rows
# processed  25.411  percent of rows
# processed  25.442  percent of rows
# processed  25.472  percent of rows
# processed  25.503  percent of rows
# processed  25.533  percent of rows
# processed  25.564  percent of rows
# processed  25.594  percent of rows
# processed  25.625  percent of rows
# processed  25.655  percent of rows
# processed  25.686  percent of rows
# processed  25.717  percent of rows
# processed  25.747  percent of rows
# processed  25.778  percent of rows
# processed  25.808  percent of rows
# processed  25.839  percent of rows
# processed  25.869  percent of rows
# processed  25.9  percent of rows
# processed  25.93  percent of rows
# processed  25.961  percent of rows
# processed  25.991  percent of rows
# processed  26.022  percent of rows
# processed  26.053  percent of rows
# processed  26.083  percent of rows
# processed  26.114  percent of rows
# processed  26.144  percent of rows
# processed  26.175  percent of rows
# processed  26.205  percent of rows
# processed  26.236  percent of rows
# processed  26.266  percent of rows
# processed  26.297  percent of rows
# processed  26.327  percent of rows
# processed  26.358  percent of rows
# processed  26.388  percent of rows
# processed  26.419  percent of rows
# processed  26.45  percent of rows
# processed  26.48  percent of rows
# processed  26.511  percent of rows
# processed  26.541  percent of rows
# processed  26.572  percent of rows
# processed  26.602  percent of rows
# processed  26.633  percent of rows
# processed  26.663  percent of rows
# processed  26.694  percent of rows
# processed  26.724  percent of rows
# processed  26.755  percent of rows
# processed  26.786  percent of rows
# processed  26.816  percent of rows
# processed  26.847  percent of rows
# processed  26.877  percent of rows
# processed  26.908  percent of rows
# processed  26.938  percent of rows
# processed  26.969  percent of rows
# processed  26.999  percent of rows
# processed  27.03  percent of rows
# processed  27.06  percent of rows
# processed  27.091  percent of rows
# processed  27.121  percent of rows
# processed  27.152  percent of rows
# processed  27.183  percent of rows
# processed  27.213  percent of rows
# processed  27.244  percent of rows
# processed  27.274  percent of rows
# processed  27.305  percent of rows
# processed  27.335  percent of rows
# processed  27.366  percent of rows
# processed  27.396  percent of rows
# processed  27.427  percent of rows
# processed  27.457  percent of rows
# processed  27.488  percent of rows
# processed  27.519  percent of rows
# processed  27.549  percent of rows
# processed  27.58  percent of rows
# processed  27.61  percent of rows
# processed  27.641  percent of rows
# processed  27.671  percent of rows
# processed  27.702  percent of rows
# processed  27.732  percent of rows
# processed  27.763  percent of rows
# processed  27.793  percent of rows
# processed  27.824  percent of rows
# processed  27.855  percent of rows
# processed  27.885  percent of rows
# processed  27.916  percent of rows
# processed  27.946  percent of rows
# processed  27.977  percent of rows
# processed  28.007  percent of rows
# processed  28.038  percent of rows
# processed  28.068  percent of rows
# processed  28.099  percent of rows
# processed  28.129  percent of rows
# processed  28.16  percent of rows
# processed  28.19  percent of rows
# processed  28.221  percent of rows
# processed  28.252  percent of rows
# processed  28.282  percent of rows
# processed  28.313  percent of rows
# processed  28.343  percent of rows
# processed  28.374  percent of rows
# processed  28.404  percent of rows
# processed  28.435  percent of rows
# processed  28.465  percent of rows
# processed  28.496  percent of rows
# processed  28.526  percent of rows
# processed  28.557  percent of rows
# processed  28.588  percent of rows
# processed  28.618  percent of rows
# processed  28.649  percent of rows
# processed  28.679  percent of rows
# processed  28.71  percent of rows
# processed  28.74  percent of rows
# processed  28.771  percent of rows
# processed  28.801  percent of rows
# processed  28.832  percent of rows
# processed  28.862  percent of rows
# processed  28.893  percent of rows
# processed  28.923  percent of rows
# processed  28.954  percent of rows
# processed  28.985  percent of rows
# processed  29.015  percent of rows
# processed  29.046  percent of rows
# processed  29.076  percent of rows
# processed  29.107  percent of rows
# processed  29.137  percent of rows
# processed  29.168  percent of rows
# processed  29.198  percent of rows
# processed  29.229  percent of rows
# processed  29.259  percent of rows
# processed  29.29  percent of rows
# processed  29.321  percent of rows
# processed  29.351  percent of rows
# processed  29.382  percent of rows
# processed  29.412  percent of rows
# processed  29.443  percent of rows
# processed  29.473  percent of rows
# processed  29.504  percent of rows
# processed  29.534  percent of rows
# processed  29.565  percent of rows
# processed  29.595  percent of rows
# processed  29.626  percent of rows
# processed  29.656  percent of rows
# processed  29.687  percent of rows
# processed  29.718  percent of rows
# processed  29.748  percent of rows
# processed  29.779  percent of rows
# processed  29.809  percent of rows
# processed  29.84  percent of rows
# processed  29.87  percent of rows
# processed  29.901  percent of rows
# processed  29.931  percent of rows
# processed  29.962  percent of rows
# processed  29.992  percent of rows
# processed  30.023  percent of rows
# processed  30.054  percent of rows
# processed  30.084  percent of rows
# processed  30.115  percent of rows
# processed  30.145  percent of rows
# processed  30.176  percent of rows
# processed  30.206  percent of rows
# processed  30.237  percent of rows
# processed  30.267  percent of rows
# processed  30.298  percent of rows
# processed  30.328  percent of rows
# processed  30.359  percent of rows
# processed  30.39  percent of rows
# processed  30.42  percent of rows
# processed  30.451  percent of rows
# processed  30.481  percent of rows
# processed  30.512  percent of rows
# processed  30.542  percent of rows
# processed  30.573  percent of rows
# processed  30.603  percent of rows
# processed  30.634  percent of rows
# processed  30.664  percent of rows
# processed  30.695  percent of rows
# processed  30.725  percent of rows
# processed  30.756  percent of rows
# processed  30.787  percent of rows
# processed  30.817  percent of rows
# processed  30.848  percent of rows
# processed  30.878  percent of rows
# processed  30.909  percent of rows
# processed  30.939  percent of rows
# processed  30.97  percent of rows
# processed  31.0  percent of rows
# processed  31.031  percent of rows
# processed  31.061  percent of rows
# processed  31.092  percent of rows
# processed  31.123  percent of rows
# processed  31.153  percent of rows
# processed  31.184  percent of rows
# processed  31.214  percent of rows
# processed  31.245  percent of rows
# processed  31.275  percent of rows
# processed  31.306  percent of rows
# processed  31.336  percent of rows
# processed  31.367  percent of rows
# processed  31.397  percent of rows
# processed  31.428  percent of rows
# processed  31.458  percent of rows
# processed  31.489  percent of rows
# processed  31.52  percent of rows
# processed  31.55  percent of rows
# processed  31.581  percent of rows
# processed  31.611  percent of rows
# processed  31.642  percent of rows
# processed  31.672  percent of rows
# processed  31.703  percent of rows
# processed  31.733  percent of rows
# processed  31.764  percent of rows
# processed  31.794  percent of rows
# processed  31.825  percent of rows
# processed  31.856  percent of rows
# processed  31.886  percent of rows
# processed  31.917  percent of rows
# processed  31.947  percent of rows
# processed  31.978  percent of rows
# processed  32.008  percent of rows
# processed  32.039  percent of rows
# processed  32.069  percent of rows
# processed  32.1  percent of rows
# processed  32.13  percent of rows
# processed  32.161  percent of rows
# processed  32.191  percent of rows
# processed  32.222  percent of rows
# processed  32.253  percent of rows
# processed  32.283  percent of rows
# processed  32.314  percent of rows
# processed  32.344  percent of rows
# processed  32.375  percent of rows
# processed  32.405  percent of rows
# processed  32.436  percent of rows
# processed  32.466  percent of rows
# processed  32.497  percent of rows
# processed  32.527  percent of rows
# processed  32.558  percent of rows
# processed  32.589  percent of rows
# processed  32.619  percent of rows
# processed  32.65  percent of rows
# processed  32.68  percent of rows
# processed  32.711  percent of rows
# processed  32.741  percent of rows
# processed  32.772  percent of rows
# processed  32.802  percent of rows
# processed  32.833  percent of rows
# processed  32.863  percent of rows
# processed  32.894  percent of rows
# processed  32.925  percent of rows
# processed  32.955  percent of rows
# processed  32.986  percent of rows
# processed  33.016  percent of rows
# processed  33.047  percent of rows
# processed  33.077  percent of rows
# processed  33.108  percent of rows
# processed  33.138  percent of rows
# processed  33.169  percent of rows
# processed  33.199  percent of rows
# processed  33.23  percent of rows
# processed  33.26  percent of rows
# processed  33.291  percent of rows
# processed  33.322  percent of rows
# processed  33.352  percent of rows
# processed  33.383  percent of rows
# processed  33.413  percent of rows
# processed  33.444  percent of rows
# processed  33.474  percent of rows
# processed  33.505  percent of rows
# processed  33.535  percent of rows
# processed  33.566  percent of rows
# processed  33.596  percent of rows
# processed  33.627  percent of rows
# processed  33.658  percent of rows
# processed  33.688  percent of rows
# processed  33.719  percent of rows
# processed  33.749  percent of rows
# processed  33.78  percent of rows
# processed  33.81  percent of rows
# processed  33.841  percent of rows
# processed  33.871  percent of rows
# processed  33.902  percent of rows
# processed  33.932  percent of rows
# processed  33.963  percent of rows
# processed  33.993  percent of rows
# processed  34.024  percent of rows
# processed  34.055  percent of rows
# processed  34.085  percent of rows
# processed  34.116  percent of rows
# processed  34.146  percent of rows
# processed  34.177  percent of rows
# processed  34.207  percent of rows
# processed  34.238  percent of rows
# processed  34.268  percent of rows
# processed  34.299  percent of rows
# processed  34.329  percent of rows
# processed  34.36  percent of rows
# processed  34.391  percent of rows
# processed  34.421  percent of rows
# processed  34.452  percent of rows
# processed  34.482  percent of rows
# processed  34.513  percent of rows
# processed  34.543  percent of rows
# processed  34.574  percent of rows
# processed  34.604  percent of rows
# processed  34.635  percent of rows
# processed  34.665  percent of rows
# processed  34.696  percent of rows
# processed  34.727  percent of rows
# processed  34.757  percent of rows
# processed  34.788  percent of rows
# processed  34.818  percent of rows
# processed  34.849  percent of rows
# processed  34.879  percent of rows
# processed  34.91  percent of rows
# processed  34.94  percent of rows
# processed  34.971  percent of rows
# processed  35.001  percent of rows
# processed  35.032  percent of rows
# processed  35.062  percent of rows
# processed  35.093  percent of rows
# processed  35.124  percent of rows
# processed  35.154  percent of rows
# processed  35.185  percent of rows
# processed  35.215  percent of rows
# processed  35.246  percent of rows
# processed  35.276  percent of rows
# processed  35.307  percent of rows
# processed  35.337  percent of rows
# processed  35.368  percent of rows
# processed  35.398  percent of rows
# processed  35.429  percent of rows
# processed  35.46  percent of rows
# processed  35.49  percent of rows
# processed  35.521  percent of rows
# processed  35.551  percent of rows
# processed  35.582  percent of rows
# processed  35.612  percent of rows
# processed  35.643  percent of rows
# processed  35.673  percent of rows
# processed  35.704  percent of rows
# processed  35.734  percent of rows
# processed  35.765  percent of rows
# processed  35.795  percent of rows
# processed  35.826  percent of rows
# processed  35.857  percent of rows
# processed  35.887  percent of rows
# processed  35.918  percent of rows
# processed  35.948  percent of rows
# processed  35.979  percent of rows
# processed  36.009  percent of rows
# processed  36.04  percent of rows
# processed  36.07  percent of rows
# processed  36.101  percent of rows
# processed  36.131  percent of rows
# processed  36.162  percent of rows
# processed  36.193  percent of rows
# processed  36.223  percent of rows
# processed  36.254  percent of rows
# processed  36.284  percent of rows
# processed  36.315  percent of rows
# processed  36.345  percent of rows
# processed  36.376  percent of rows
# processed  36.406  percent of rows
# processed  36.437  percent of rows
# processed  36.467  percent of rows
# processed  36.498  percent of rows
# processed  36.528  percent of rows
# processed  36.559  percent of rows
# processed  36.59  percent of rows
# processed  36.62  percent of rows
# processed  36.651  percent of rows
# processed  36.681  percent of rows
# processed  36.712  percent of rows
# processed  36.742  percent of rows
# processed  36.773  percent of rows
# processed  36.803  percent of rows
# processed  36.834  percent of rows
# processed  36.864  percent of rows
# processed  36.895  percent of rows
# processed  36.926  percent of rows
# processed  36.956  percent of rows
# processed  36.987  percent of rows
# processed  37.017  percent of rows
# processed  37.048  percent of rows
# processed  37.078  percent of rows
# processed  37.109  percent of rows
# processed  37.139  percent of rows
# processed  37.17  percent of rows
# processed  37.2  percent of rows
# processed  37.231  percent of rows
# processed  37.262  percent of rows
# processed  37.292  percent of rows
# processed  37.323  percent of rows
# processed  37.353  percent of rows
# processed  37.384  percent of rows
# processed  37.414  percent of rows
# processed  37.445  percent of rows
# processed  37.475  percent of rows
# processed  37.506  percent of rows
# processed  37.536  percent of rows
# processed  37.567  percent of rows
# processed  37.597  percent of rows
# processed  37.628  percent of rows
# processed  37.659  percent of rows
# processed  37.689  percent of rows
# processed  37.72  percent of rows
# processed  37.75  percent of rows
# processed  37.781  percent of rows
# processed  37.811  percent of rows
# processed  37.842  percent of rows
# processed  37.872  percent of rows
# processed  37.903  percent of rows
# processed  37.933  percent of rows
# processed  37.964  percent of rows
# processed  37.995  percent of rows
# processed  38.025  percent of rows
# processed  38.056  percent of rows
# processed  38.086  percent of rows
# processed  38.117  percent of rows
# processed  38.147  percent of rows
# processed  38.178  percent of rows
# processed  38.208  percent of rows
# processed  38.239  percent of rows
# processed  38.269  percent of rows
# processed  38.3  percent of rows
# processed  38.33  percent of rows
# processed  38.361  percent of rows
# processed  38.392  percent of rows
# processed  38.422  percent of rows
# processed  38.453  percent of rows
# processed  38.483  percent of rows
# processed  38.514  percent of rows
# processed  38.544  percent of rows
# processed  38.575  percent of rows
# processed  38.605  percent of rows
# processed  38.636  percent of rows
# processed  38.666  percent of rows
# processed  38.697  percent of rows
# processed  38.728  percent of rows
# processed  38.758  percent of rows
# processed  38.789  percent of rows
# processed  38.819  percent of rows
# processed  38.85  percent of rows
# processed  38.88  percent of rows
# processed  38.911  percent of rows
# processed  38.941  percent of rows
# processed  38.972  percent of rows
# processed  39.002  percent of rows
# processed  39.033  percent of rows
# processed  39.063  percent of rows
# processed  39.094  percent of rows
# processed  39.125  percent of rows
# processed  39.155  percent of rows
# processed  39.186  percent of rows
# processed  39.216  percent of rows
# processed  39.247  percent of rows
# processed  39.277  percent of rows
# processed  39.308  percent of rows
# processed  39.338  percent of rows
# processed  39.369  percent of rows
# processed  39.399  percent of rows
# processed  39.43  percent of rows
# processed  39.461  percent of rows
# processed  39.491  percent of rows
# processed  39.522  percent of rows
# processed  39.552  percent of rows
# processed  39.583  percent of rows
# processed  39.613  percent of rows
# processed  39.644  percent of rows
# processed  39.674  percent of rows
# processed  39.705  percent of rows
# processed  39.735  percent of rows
# processed  39.766  percent of rows
# processed  39.797  percent of rows
# processed  39.827  percent of rows
# processed  39.858  percent of rows
# processed  39.888  percent of rows
# processed  39.919  percent of rows
# processed  39.949  percent of rows
# processed  39.98  percent of rows
# processed  40.01  percent of rows
# processed  40.041  percent of rows
# processed  40.071  percent of rows
# processed  40.102  percent of rows
# processed  40.132  percent of rows
# processed  40.163  percent of rows
# processed  40.194  percent of rows
# processed  40.224  percent of rows
# processed  40.255  percent of rows
# processed  40.285  percent of rows
# processed  40.316  percent of rows
# processed  40.346  percent of rows
# processed  40.377  percent of rows
# processed  40.407  percent of rows
# processed  40.438  percent of rows
# processed  40.468  percent of rows
# processed  40.499  percent of rows
# processed  40.53  percent of rows
# processed  40.56  percent of rows
# processed  40.591  percent of rows
# processed  40.621  percent of rows
# processed  40.652  percent of rows
# processed  40.682  percent of rows
# processed  40.713  percent of rows
# processed  40.743  percent of rows
# processed  40.774  percent of rows
# processed  40.804  percent of rows
# processed  40.835  percent of rows
# processed  40.865  percent of rows
# processed  40.896  percent of rows
# processed  40.927  percent of rows
# processed  40.957  percent of rows
# processed  40.988  percent of rows
# processed  41.018  percent of rows
# processed  41.049  percent of rows
# processed  41.079  percent of rows
# processed  41.11  percent of rows
# processed  41.14  percent of rows
# processed  41.171  percent of rows
# processed  41.201  percent of rows
# processed  41.232  percent of rows
# processed  41.263  percent of rows
# processed  41.293  percent of rows
# processed  41.324  percent of rows
# processed  41.354  percent of rows
# processed  41.385  percent of rows
# processed  41.415  percent of rows
# processed  41.446  percent of rows
# processed  41.476  percent of rows
# processed  41.507  percent of rows
# processed  41.537  percent of rows
# processed  41.568  percent of rows
# processed  41.599  percent of rows
# processed  41.629  percent of rows
# processed  41.66  percent of rows
# processed  41.69  percent of rows
# processed  41.721  percent of rows
# processed  41.751  percent of rows
# processed  41.782  percent of rows
# processed  41.812  percent of rows
# processed  41.843  percent of rows
# processed  41.873  percent of rows
# processed  41.904  percent of rows
# processed  41.934  percent of rows
# processed  41.965  percent of rows
# processed  41.996  percent of rows
# processed  42.026  percent of rows
# processed  42.057  percent of rows
# processed  42.087  percent of rows
# processed  42.118  percent of rows
# processed  42.148  percent of rows
# processed  42.179  percent of rows
# processed  42.209  percent of rows
# processed  42.24  percent of rows
# processed  42.27  percent of rows
# processed  42.301  percent of rows
# ...
# processed  88.389  percent of rows
# processed  88.42  percent of rows
# processed  88.45  percent of rows
# processed  88.481  percent of rows
# processed  88.511  percent of rows
# processed  88.542  percent of rows
# processed  88.572  percent of rows
# processed  88.603  percent of rows
# processed  88.634  percent of rows
# processed  88.664  percent of rows
# processed  88.695  percent of rows
# processed  88.725  percent of rows
# processed  88.756  percent of rows
# processed  88.786  percent of rows
# processed  88.817  percent of rows
# processed  88.847  percent of rows
# processed  88.878  percent of rows
# processed  88.908  percent of rows
# processed  88.939  percent of rows
# processed  88.969  percent of rows
# processed  89.0  percent of rows
# processed  89.031  percent of rows
# processed  89.061  percent of rows
# processed  89.092  percent of rows
# processed  89.122  percent of rows
# processed  89.153  percent of rows
# processed  89.183  percent of rows
# processed  89.214  percent of rows
# processed  89.244  percent of rows
# processed  89.275  percent of rows
# processed  89.305  percent of rows
# processed  89.336  percent of rows
# processed  89.367  percent of rows
# processed  89.397  percent of rows
# processed  89.428  percent of rows
# processed  89.458  percent of rows
# processed  89.489  percent of rows
# processed  89.519  percent of rows
# processed  89.55  percent of rows
# processed  89.58  percent of rows
# processed  89.611  percent of rows
# processed  89.641  percent of rows
# processed  89.672  percent of rows
# processed  89.702  percent of rows
# processed  89.733  percent of rows
# processed  89.764  percent of rows
# processed  89.794  percent of rows
# processed  89.825  percent of rows
# processed  89.855  percent of rows
# processed  89.886  percent of rows
# processed  89.916  percent of rows
# processed  89.947  percent of rows
# processed  89.977  percent of rows
# processed  90.008  percent of rows
# processed  90.038  percent of rows
# processed  90.069  percent of rows
# processed  90.1  percent of rows
# processed  90.13  percent of rows
# processed  90.161  percent of rows
# processed  90.191  percent of rows
# processed  90.222  percent of rows
# processed  90.252  percent of rows
# processed  90.283  percent of rows
# processed  90.313  percent of rows
# processed  90.344  percent of rows
# processed  90.374  percent of rows
# processed  90.405  percent of rows
# processed  90.436  percent of rows
# processed  90.466  percent of rows
# processed  90.497  percent of rows
# processed  90.527  percent of rows
# processed  90.558  percent of rows
# processed  90.588  percent of rows
# processed  90.619  percent of rows
# processed  90.649  percent of rows
# processed  90.68  percent of rows
# processed  90.71  percent of rows
# processed  90.741  percent of rows
# processed  90.771  percent of rows
# processed  90.802  percent of rows
# processed  90.833  percent of rows
# processed  90.863  percent of rows
# processed  90.894  percent of rows
# processed  90.924  percent of rows
# processed  90.955  percent of rows
# processed  90.985  percent of rows
# processed  91.016  percent of rows
# processed  91.046  percent of rows
# processed  91.077  percent of rows
# processed  91.107  percent of rows
# processed  91.138  percent of rows
# processed  91.169  percent of rows
# processed  91.199  percent of rows
# processed  91.23  percent of rows
# processed  91.26  percent of rows
# processed  91.291  percent of rows
# processed  91.321  percent of rows
# processed  91.352  percent of rows
# processed  91.382  percent of rows
# processed  91.413  percent of rows
# processed  91.443  percent of rows
# processed  91.474  percent of rows
# processed  91.504  percent of rows
# processed  91.535  percent of rows
# processed  91.566  percent of rows
# processed  91.596  percent of rows
# processed  91.627  percent of rows
# processed  91.657  percent of rows
# processed  91.688  percent of rows
# processed  91.718  percent of rows
# processed  91.749  percent of rows
# processed  91.779  percent of rows
# processed  91.81  percent of rows
# processed  91.84  percent of rows
# processed  91.871  percent of rows
# processed  91.902  percent of rows
# processed  91.932  percent of rows
# processed  91.963  percent of rows
# processed  91.993  percent of rows
# processed  92.024  percent of rows
# processed  92.054  percent of rows
# processed  92.085  percent of rows
# processed  92.115  percent of rows
# processed  92.146  percent of rows
# processed  92.176  percent of rows
# processed  92.207  percent of rows
# processed  92.238  percent of rows
# processed  92.268  percent of rows
# processed  92.299  percent of rows
# processed  92.329  percent of rows
# processed  92.36  percent of rows
# processed  92.39  percent of rows
# processed  92.421  percent of rows
# processed  92.451  percent of rows
# processed  92.482  percent of rows
# processed  92.512  percent of rows
# processed  92.543  percent of rows
# processed  92.573  percent of rows
# processed  92.604  percent of rows
# processed  92.635  percent of rows
# processed  92.665  percent of rows
# processed  92.696  percent of rows
# processed  92.726  percent of rows
# processed  92.757  percent of rows
# processed  92.787  percent of rows
# processed  92.818  percent of rows
# processed  92.848  percent of rows
# processed  92.879  percent of rows
# processed  92.909  percent of rows
# processed  92.94  percent of rows
# processed  92.971  percent of rows
# processed  93.001  percent of rows
# processed  93.032  percent of rows
# processed  93.062  percent of rows
# processed  93.093  percent of rows
# processed  93.123  percent of rows
# processed  93.154  percent of rows
# processed  93.184  percent of rows
# processed  93.215  percent of rows
# processed  93.245  percent of rows
# processed  93.276  percent of rows
# processed  93.306  percent of rows
# processed  93.337  percent of rows
# processed  93.368  percent of rows
# processed  93.398  percent of rows
# processed  93.429  percent of rows
# processed  93.459  percent of rows
# processed  93.49  percent of rows
# processed  93.52  percent of rows
# processed  93.551  percent of rows
# processed  93.581  percent of rows
# processed  93.612  percent of rows
# processed  93.642  percent of rows
# processed  93.673  percent of rows
# processed  93.704  percent of rows
# processed  93.734  percent of rows
# processed  93.765  percent of rows
# processed  93.795  percent of rows
# processed  93.826  percent of rows
# processed  93.856  percent of rows
# processed  93.887  percent of rows
# processed  93.917  percent of rows
# processed  93.948  percent of rows
# processed  93.978  percent of rows
# processed  94.009  percent of rows
# processed  94.039  percent of rows
# processed  94.07  percent of rows
# processed  94.101  percent of rows
# processed  94.131  percent of rows
# processed  94.162  percent of rows
# processed  94.192  percent of rows
# processed  94.223  percent of rows
# processed  94.253  percent of rows
# processed  94.284  percent of rows
# processed  94.314  percent of rows
# processed  94.345  percent of rows
# processed  94.375  percent of rows
# processed  94.406  percent of rows
# processed  94.437  percent of rows
# processed  94.467  percent of rows
# processed  94.498  percent of rows
# processed  94.528  percent of rows
# processed  94.559  percent of rows
# processed  94.589  percent of rows
# processed  94.62  percent of rows
# processed  94.65  percent of rows
# processed  94.681  percent of rows
# processed  94.711  percent of rows
# processed  94.742  percent of rows
# processed  94.773  percent of rows
# processed  94.803  percent of rows
# processed  94.834  percent of rows
# processed  94.864  percent of rows
# processed  94.895  percent of rows
# processed  94.925  percent of rows
# processed  94.956  percent of rows
# processed  94.986  percent of rows
# processed  95.017  percent of rows
# processed  95.047  percent of rows
# processed  95.078  percent of rows
# processed  95.108  percent of rows
# processed  95.139  percent of rows
# processed  95.17  percent of rows
# processed  95.2  percent of rows
# processed  95.231  percent of rows
# processed  95.261  percent of rows
# processed  95.292  percent of rows
# processed  95.322  percent of rows
# processed  95.353  percent of rows
# processed  95.383  percent of rows
# processed  95.414  percent of rows
# processed  95.444  percent of rows
# processed  95.475  percent of rows
# processed  95.506  percent of rows
# processed  95.536  percent of rows
# processed  95.567  percent of rows
# processed  95.597  percent of rows
# processed  95.628  percent of rows
# processed  95.658  percent of rows
# processed  95.689  percent of rows
# processed  95.719  percent of rows
# processed  95.75  percent of rows
# processed  95.78  percent of rows
# processed  95.811  percent of rows
# processed  95.841  percent of rows
# processed  95.872  percent of rows
# processed  95.903  percent of rows
# processed  95.933  percent of rows
# processed  95.964  percent of rows
# processed  95.994  percent of rows
# processed  96.025  percent of rows
# processed  96.055  percent of rows
# processed  96.086  percent of rows
# processed  96.116  percent of rows
# processed  96.147  percent of rows
# processed  96.177  percent of rows
# processed  96.208  percent of rows
# processed  96.239  percent of rows
# processed  96.269  percent of rows
# processed  96.3  percent of rows
# processed  96.33  percent of rows
# processed  96.361  percent of rows
# processed  96.391  percent of rows
# processed  96.422  percent of rows
# processed  96.452  percent of rows
# processed  96.483  percent of rows
# processed  96.513  percent of rows
# processed  96.544  percent of rows
# processed  96.574  percent of rows
# processed  96.605  percent of rows
# processed  96.636  percent of rows
# processed  96.666  percent of rows
# processed  96.697  percent of rows
# processed  96.727  percent of rows
# processed  96.758  percent of rows
# processed  96.788  percent of rows
# processed  96.819  percent of rows
# processed  96.849  percent of rows
# processed  96.88  percent of rows
# processed  96.91  percent of rows
# processed  96.941  percent of rows
# processed  96.972  percent of rows
# processed  97.002  percent of rows
# processed  97.033  percent of rows
# processed  97.063  percent of rows
# processed  97.094  percent of rows
# processed  97.124  percent of rows
# processed  97.155  percent of rows
# processed  97.185  percent of rows
# processed  97.216  percent of rows
# processed  97.246  percent of rows
# processed  97.277  percent of rows
# processed  97.308  percent of rows
# processed  97.338  percent of rows
# processed  97.369  percent of rows
# processed  97.399  percent of rows
# processed  97.43  percent of rows
# processed  97.46  percent of rows
# processed  97.491  percent of rows
# processed  97.521  percent of rows
# processed  97.552  percent of rows
# processed  97.582  percent of rows
# processed  97.613  percent of rows
# processed  97.643  percent of rows
# processed  97.674  percent of rows
# processed  97.705  percent of rows
# processed  97.735  percent of rows
# processed  97.766  percent of rows
# processed  97.796  percent of rows
# processed  97.827  percent of rows
# processed  97.857  percent of rows
# processed  97.888  percent of rows
# processed  97.918  percent of rows
# processed  97.949  percent of rows
# processed  97.979  percent of rows
# processed  98.01  percent of rows
# processed  98.041  percent of rows
# processed  98.071  percent of rows
# processed  98.102  percent of rows
# processed  98.132  percent of rows
# processed  98.163  percent of rows
# processed  98.193  percent of rows
# processed  98.224  percent of rows
# processed  98.254  percent of rows
# processed  98.285  percent of rows
# processed  98.315  percent of rows
# processed  98.346  percent of rows
# processed  98.376  percent of rows
# processed  98.407  percent of rows
# processed  98.438  percent of rows
# processed  98.468  percent of rows
# processed  98.499  percent of rows
# processed  98.529  percent of rows
# processed  98.56  percent of rows
# processed  98.59  percent of rows
# processed  98.621  percent of rows
# processed  98.651  percent of rows
# processed  98.682  percent of rows
# processed  98.712  percent of rows
# processed  98.743  percent of rows
# processed  98.774  percent of rows
# processed  98.804  percent of rows
# processed  98.835  percent of rows
# processed  98.865  percent of rows
# processed  98.896  percent of rows
# processed  98.926  percent of rows
# processed  98.957  percent of rows
# processed  98.987  percent of rows
# processed  99.018  percent of rows
# processed  99.048  percent of rows
# processed  99.079  percent of rows
# processed  99.11  percent of rows
# processed  99.14  percent of rows
# processed  99.171  percent of rows
# processed  99.201  percent of rows
# processed  99.232  percent of rows
# processed  99.262  percent of rows
# processed  99.293  percent of rows
# processed  99.323  percent of rows
# processed  99.354  percent of rows
# processed  99.384  percent of rows
# processed  99.415  percent of rows
# processed  99.445  percent of rows
# processed  99.476  percent of rows
# processed  99.507  percent of rows
# processed  99.537  percent of rows
# processed  99.568  percent of rows
# processed  99.598  percent of rows
# processed  99.629  percent of rows
# processed  99.659  percent of rows
# processed  99.69  percent of rows
# processed  99.72  percent of rows
# processed  99.751  percent of rows
# processed  99.781  percent of rows
# processed  99.812  percent of rows
# processed  99.843  percent of rows
# processed  99.873  percent of rows
# processed  99.904  percent of rows
# processed  99.934  percent of rows
# processed  99.965  percent of rows
# processed  99.995  percent of rows
# processed  100.026  percent of rows
#           YEAR  SAMPLE   SERIAL      CBSERIAL  HHWT        CLUSTER  STATEICP  \
# 13        2000  200001        4           NaN    19  2000000000041         5
# 70        2000  200001       33           NaN    21  2000000000331         5
# 125       2000  200001       58           NaN    23  2000000000581         5
# 148       2000  200001       68           NaN    21  2000000000681         5
# 412       2000  200001      184           NaN    21  2000000001841         5
# ...        ...     ...      ...           ...   ...            ...       ...
# 65482830  2019  201901  1427919  2.019001e+12    48  2019014279191        68
# 65482850  2019  201901  1427930  2.019001e+12    16  2019014279301        68
# 65482870  2019  201901  1427936  2.019001e+12    73  2019014279361        68
# 65482985  2019  201901  1427983  2.019001e+12    15  2019014279831        68
# 65483081  2019  201901  1428017  2.019001e+12    86  2019014280171        68
#
#           STRATA  GQ  PERNUM  ...  OCCSOC   IND  IND1990  INDNAICS  WKSWORK1  \
# 13            65   1       1  ...  436010   398      391    3399ZM      52.0
# 70            52   1       2  ...  436010   787      850     611M1      50.0
# 125           60   1       2  ...  436010   447      550      4224      52.0
# 148           64   1       2  ...  436010   919      881     8139Z      52.0
# 412           60   1       2  ...  436010   819      831       622      41.0
# ...          ...  ..     ...  ...     ...   ...      ...       ...       ...
# 65482830   20056   1       1  ...  436014  7190      732       53M      44.0
# 65482850   10056   1       2  ...  436014  8170      840      6216      52.0
# 65482870   10056   1       2  ...  132011  7280      890      5412      52.0
# 65482985   50056   1       1  ...  132011  9370      901    9211MP      52.0
# 65483081   30056   1       2  ...  132011  9390      901     92119      52.0
#
#           WKSWORK2  UHRSWORK  LOOKING  WORKEDYR  INCWAGE
# 13               6        50        0         3    42600
# 70               6        40        0         3    72000
# 125              6        50        0         3    26000
# 148              6        35        0         3    25000
# 412              4        40        0         3    17700
# ...            ...       ...      ...       ...      ...
# 65482830         4        40        3         3    56000
# 65482850         6        40        3         3    42400
# 65482870         6        55        3         3    40000
# 65482985         6        40        2         3    39000
# 65483081         6        52        3         3   100000
#
# [1175018 rows x 33 columns]

# %%
# add occupation (SOC) titles 
df['OCCSOCTITLE'] = df['OCCSOC'].apply(lambda x: code_df[x])
df.head()
# Out:
#      YEAR  SAMPLE  SERIAL  CBSERIAL  HHWT        CLUSTER  STATEICP  STRATA  \
# 13   2000  200001       4       NaN    19  2000000000041         5      65
# 70   2000  200001      33       NaN    21  2000000000331         5      52
# 125  2000  200001      58       NaN    23  2000000000581         5      60
# 148  2000  200001      68       NaN    21  2000000000681         5      64
# 412  2000  200001     184       NaN    21  2000000001841         5      60
#
#      GQ  PERNUM  ...  IND  IND1990  INDNAICS  WKSWORK1  WKSWORK2  UHRSWORK  \
# 13    1       1  ...  398      391    3399ZM      52.0         6        50
# 70    1       2  ...  787      850     611M1      50.0         6        40
# 125   1       2  ...  447      550      4224      52.0         6        50
# 148   1       2  ...  919      881     8139Z      52.0         6        35
# 412   1       2  ...  819      831       622      41.0         4        40
#
#      LOOKING  WORKEDYR  INCWAGE                                OCCSOCTITLE
# 13         0         3    42600  Secretaries and Administrative Assistants
# 70         0         3    72000  Secretaries and Administrative Assistants
# 125        0         3    26000  Secretaries and Administrative Assistants
# 148        0         3    25000  Secretaries and Administrative Assistants
# 412        0         3    17700  Secretaries and Administrative Assistants
#
# [5 rows x 34 columns]

# %%
# Read in Exposure scores for the ONET SOC Codes 
import pyreadstat
import requests

# get crosswalk data from url 
url = 'https://s3.us-west-2.amazonaws.com/secure.notion-static.com/970d6f83-c888-48ea-a562-719f39f9f097/final_df_out.dta?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAT73L2G45O3KS52Y5%2F20210422%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20210422T004432Z&X-Amz-Expires=86400&X-Amz-Signature=62b57ea928fd04362f23d5efb5bf82916a8a58a75aa8690c4c8f95b829c95f17&X-Amz-SignedHeaders=host&response-content-disposition=filename%20%3D%22final_df_out.dta%22'
r = requests.get(url, allow_redirects=True)

open('data/exposure1.dta', 'wb').write(r.content)

exposure, meta = pyreadstat.read_dta('data/exposure1.dta')

# %%
exposure
# Out:
#                                          index onetsoccode  agg_pairs  \
# 0                             Chief Executives  11-1011.00       50.0
# 1                Chief Sustainability Officers  11-1011.03       22.0
# 2              General and Operations Managers  11-1021.00       27.0
# 3          Advertising and Promotions Managers  11-2011.00       38.0
# 4                           Marketing Managers  11-2021.00       31.0
# ..                                         ...         ...        ...
# 959    Pump Operators, Except Wellhead Pumpers  53-7072.00       25.0
# 960                           Wellhead Pumpers  53-7073.00       23.0
# 961  Refuse and Recyclable Material Collectors  53-7081.00       26.0
# 962                 Mine Shuttle Car Operators  53-7111.00       27.0
# 963          Tank Car, Truck, and Ship Loaders  53-7121.00       42.0
#
#      ai_score  software_score  robot_score
# 0    0.204306        0.180725     0.122230
# 1    0.298717        0.459575     0.053837
# 2    0.247979        0.384658     0.263024
# 3    0.223920        0.453487     0.126255
# 4    0.560194        0.392555     0.086466
# ..        ...             ...          ...
# 959  0.401895        1.074947     1.286106
# 960  0.586677        1.162941     1.860223
# 961  0.386635        0.739286     1.996589
# 962  0.282193        0.836086     1.769110
# 963  0.215644        0.706582     0.684761
#
# [964 rows x 6 columns]

# %% [markdown]
# **Looking at Change in Wages over Time**

# %% [markdown]
# Work to be done:
#     - run the regression for this
#     - figure out how to create industry fixed effects
#     - single out two jobs to compare and reasons why
#     - do the same thing for employment
#     - group fast food workers properly
#
#
# HUGE IDEA:
#     - There seems to be a big jump in the wage of diagnostic technicians, this could be tied to advancements in
#       medical imaging in 2017: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6199205/
#     - I can use 2017 as a treatment and compare these technicians to secretaries. The reason this could work is
#       because both jobs are impacted by AI. However, this is a direct affect to one job, and they both seemed to
#       be trending a similar way in terms of wage.

# %%
# SOURCE: https://usa.ipums.org/usa/cpi99.shtml
cpi99 = {} 
cpi99[1980] = 2.295 
cpi99[1990] = 1.344
cpi99[2000] = 0.967
cpi99[2001] = 0.941
cpi99[2002] = 0.926
cpi99[2003] = 0.905
cpi99[2004] = 0.882
cpi99[2005] = 0.853
cpi99[2006] = 0.826
cpi99[2007] = 0.804
cpi99[2008] = 0.774
cpi99[2009] = 0.777
cpi99[2010] = 0.764
cpi99[2011] = 0.741
cpi99[2012] = 0.726
cpi99[2013] = 0.715
cpi99[2014] = 0.704
cpi99[2015] = 0.703
cpi99[2016] = 0.694
cpi99[2017] = 0.679
cpi99[2018] = 0.663
cpi99[2019] = 0.652

def convert_99(x, y):
    return cpi99[x]*y

# %%
# group by year and occupational code
wage_df = df.groupby(['YEAR', 'OCCSOCTITLE']).agg('mean').reset_index()

# convert dollars to 1999 dollars 
wage_df['INCWAGE_REAL'] = wage_df.apply(lambda x: convert_99(x['YEAR'], x['INCWAGE']), axis=1)
wage_df.head()
# Out:
#    YEAR                                    OCCSOCTITLE         SAMPLE  \
# 0  2000                         Accountants & Auditors  200001.091745
# 1  2000                                Credit Analysts  200001.091533
# 2  2000                 Diagnostic Related Technicians  200001.072490
# 3  2000                             Financial Analysts  200001.120712
# 4  2000  Insurance Claims and Policy Processing Clerks  200001.107605
#
#          SERIAL  CBSERIAL       HHWT       CLUSTER   STATEICP     STRATA  \
# 0  3.019066e+06       NaN  40.824159  2.000030e+12  39.213442  69.014926
# 1  2.880077e+06       NaN  41.512586  2.000029e+12  36.503432  70.091533
# 2  2.963764e+06       NaN  35.942484  2.000030e+12  38.588656  67.350652
# 3  2.756903e+06       NaN  47.723846  2.000028e+12  33.453198  68.556120
# 4  3.068639e+06       NaN  45.124322  2.000031e+12  37.436400  70.240120
#
#          GQ  ...  OCC2010         IND     IND1990   WKSWORK1  WKSWORK2  \
# 0  1.003603  ...    800.0  630.921423  666.751487  51.385051  5.882177
# 1  1.006865  ...    830.0  607.333333  618.870328  51.308924  5.868040
# 2  1.014634  ...   3320.0  808.737379  822.958026  51.305275  5.868179
# 3  1.000000  ...    840.0  669.544261  679.578145  51.288861  5.866158
# 4  1.003432  ...   5840.0  698.811690  710.823425  51.226392  5.846673
#
#     UHRSWORK   LOOKING  WORKEDYR       INCWAGE  INCWAGE_REAL
# 0  43.946157  0.092931       3.0  47171.639454  45614.975352
# 1  42.411899  0.116705       3.0  39719.832189  38409.077727
# 2  42.353602  0.127510       3.0  38446.946115  37178.196893
# 3  48.072427  0.080051       3.0  88209.610335  85298.693194
# 4  40.961364  0.144138       3.0  28949.374958  27994.045585
#
# [5 rows x 33 columns]

# %%
# construct time series
years = np.arange(2000, 2020, 1)

ts_df_wage = pd.DataFrame({'Year': years})

# cooks = [] 
for occ in np.unique(list(code_df.values())):
    mean_wages = [] 
    for year in years: 
        wage = np.mean(wage_df[(wage_df['YEAR'] == year) & (wage_df['OCCSOCTITLE'] == occ)]['INCWAGE_REAL'])
        mean_wages.append(wage)
    
    ts_df_wage[occ] = mean_wages

# %%
ts_df_wage
# Out:
#     Year  Accountants & Auditors  Credit Analysts  \
# 0   2000            45614.975352     38409.077727
# 1   2001            47258.482106     37851.904580
# 2   2002            50109.516103     48562.660870
# 3   2003            48614.110187     36445.268116
# 4   2004            50773.378221     43038.754839
# 5   2005            51251.043028     40842.143882
# 6   2006            51923.449967     42946.169412
# 7   2007            53468.552843     51980.015493
# 8   2008            53606.489806     45790.513043
# 9   2009            54168.463726     41893.037705
# 10  2010            54266.581628     45049.467782
# 11  2011            53394.421865     47645.011304
# 12  2012            53143.536859     46091.885714
# 13  2013            53965.159672     49003.387931
# 14  2014            52198.046775     49927.403922
# 15  2015            53601.141801     48884.626820
# 16  2016            54181.491972     51399.664167
# 17  2017            54845.736359     49051.614458
# 18  2018            55854.283007     56398.863878
# 19  2019            56356.525443     51308.424390
#
#     Diagnostic Related Technicians  Financial Analysts  \
# 0                     37178.196893        85298.693194
# 1                     38539.706706        80489.351155
# 2                     40814.540511        78482.391884
# 3                     42531.430662        83090.088933
# 4                     41287.726667        77953.873846
# 5                     42523.132073        92815.310925
# 6                     41763.806495        99278.438202
# 7                     42277.532010        98218.225352
# 8                     41910.042365        99115.661538
# 9                     43021.575124        99387.825207
# 10                    42403.460682        91750.780764
# 11                    42081.083907        94574.179293
# 12                    41786.025877       100349.619813
# 13                    41875.531211        97352.797414
# 14                    41772.352675        77958.147178
# 15                    43163.742361        80498.404651
# 16                    42476.237448        81977.891828
# 17                    42491.973841        84013.173606
# 18                    57000.159733        83421.375479
# 19                    55934.147468        81019.438829
#
#     Insurance Claims and Policy Processing Clerks  \
# 0                                    27994.045585
# 1                                    29755.451499
# 2                                    28505.350966
# 3                                    27884.537671
# 4                                    27455.260239
# 5                                    28048.958499
# 6                                    27448.912948
# 7                                    28807.091715
# 8                                    27904.311257
# 9                                    28879.175118
# 10                                   28188.557943
# 11                                   28261.509978
# 12                                   29396.184705
# 13                                   29778.764411
# 14                                   29183.807402
# 15                                   30170.978975
# 16                                   30026.389306
# 17                                   31011.570507
# 18                                   32685.824358
# 19                                   29691.633282
#
#     Paralegals & Legal Assistants  Secretaries and Administrative Assistants  \
# 0                    33900.164214                               26273.925165
# 1                    35568.667402                               25929.252940
# 2                    36343.997363                               26147.201686
# 3                    36482.666169                               26149.540470
# 4                    37969.824129                               26641.745455
# 5                    37038.543389                               26443.960088
# 6                    36723.058412                               26560.983291
# 7                    37403.882769                               26952.387092
# 8                    37058.952043                               26733.400779
# 9                    37886.281435                               27714.652792
# 10                   37931.241313                               27690.476795
# 11                   36286.414691                               26867.041960
# 12                   36523.040976                               27040.598728
# 13                   36956.625461                               26838.844878
# 14                   37028.869565                               27060.316917
# 15                   37723.409860                               27985.131958
# 16                   35949.958359                               27840.829125
# 17                   38205.640035                               28232.323630
# 18                   37010.659623                               28117.306444
# 19                   37061.436268                               29086.136335
#
#          Tellers
# 0   18702.593615
# 1   18291.849089
# 2   18584.336546
# 3   19922.894248
# 4   20055.996032
# 5   18826.699270
# 6   19199.144615
# 7   18926.430377
# 8   18770.392338
# 9   19460.315601
# 10  18981.758394
# 11  18535.390511
# 12  18497.636152
# 13  18868.228261
# 14  18933.896335
# 15  19818.495166
# 16  18845.095567
# 17  19914.375379
# 18  20300.042116
# 19  20705.095812

# %%
plt.figure(figsize=(16,8))
plt.plot(ts_df_wage['Year'], ts_df_wage['Paralegals & Legal Assistants'], label='Paralegals')
plt.plot(ts_df_wage['Year'], ts_df_wage['Secretaries and Administrative Assistants'], label='Secretaries')
plt.plot(ts_df_wage['Year'], ts_df_wage['Accountants & Auditors'], label='Accountants & Auditors')
plt.plot(ts_df_wage['Year'], ts_df_wage['Diagnostic Related Technicians'], label='Diagnostic Technicians')
plt.plot(ts_df_wage['Year'], ts_df_wage['Insurance Claims and Policy Processing Clerks'], label='ICPP Clerks')
plt.plot(ts_df_wage['Year'], ts_df_wage['Tellers'], label='Tellers')
plt.plot(ts_df_wage['Year'], ts_df_wage['Credit Analysts'], label='Credit Analysts')
plt.plot(ts_df_wage['Year'], ts_df_wage['Financial Analysts'], label='Financial Analysts')

plt.xticks(years)
plt.legend()
plt.title("Change in Mean Real Yearly Wages (1999 Dollars) over Time")
# Out:
# Text(0.5, 1.0, 'Change in Mean Real Yearly Wages (1999 Dollars) over Time')

# %% [markdown]
# **Looking at Changes in Employment Over Time**
#
# need to multiply empstat by perwt to get population represented by sample

# %%
def calculate_emp(x, y): 
    if (x == 1): 
        return x*y
    else: 
        return 0
    
df['NUM_EMPLOYED'] = df.apply(lambda x: calculate_emp(x['EMPSTAT'], x['PERWT']), axis=1)
df
# Out:
#           YEAR  SAMPLE   SERIAL      CBSERIAL  HHWT        CLUSTER  STATEICP  \
# 13        2000  200001        4           NaN    19  2000000000041         5
# 70        2000  200001       33           NaN    21  2000000000331         5
# 125       2000  200001       58           NaN    23  2000000000581         5
# 148       2000  200001       68           NaN    21  2000000000681         5
# 412       2000  200001      184           NaN    21  2000000001841         5
# ...        ...     ...      ...           ...   ...            ...       ...
# 65482830  2019  201901  1427919  2.019001e+12    48  2019014279191        68
# 65482850  2019  201901  1427930  2.019001e+12    16  2019014279301        68
# 65482870  2019  201901  1427936  2.019001e+12    73  2019014279361        68
# 65482985  2019  201901  1427983  2.019001e+12    15  2019014279831        68
# 65483081  2019  201901  1428017  2.019001e+12    86  2019014280171        68
#
#           STRATA  GQ  PERNUM  ...  IND1990  INDNAICS  WKSWORK1  WKSWORK2  \
# 13            65   1       1  ...      391    3399ZM      52.0         6
# 70            52   1       2  ...      850     611M1      50.0         6
# 125           60   1       2  ...      550      4224      52.0         6
# 148           64   1       2  ...      881     8139Z      52.0         6
# 412           60   1       2  ...      831       622      41.0         4
# ...          ...  ..     ...  ...      ...       ...       ...       ...
# 65482830   20056   1       1  ...      732       53M      44.0         4
# 65482850   10056   1       2  ...      840      6216      52.0         6
# 65482870   10056   1       2  ...      890      5412      52.0         6
# 65482985   50056   1       1  ...      901    9211MP      52.0         6
# 65483081   30056   1       2  ...      901     92119      52.0         6
#
#           UHRSWORK  LOOKING  WORKEDYR  INCWAGE  \
# 13              50        0         3    42600
# 70              40        0         3    72000
# 125             50        0         3    26000
# 148             35        0         3    25000
# 412             40        0         3    17700
# ...            ...      ...       ...      ...
# 65482830        40        3         3    56000
# 65482850        40        3         3    42400
# 65482870        55        3         3    40000
# 65482985        40        2         3    39000
# 65483081        52        3         3   100000
#
#                                         OCCSOCTITLE  NUM_EMPLOYED
# 13        Secretaries and Administrative Assistants            16
# 70        Secretaries and Administrative Assistants            26
# 125       Secretaries and Administrative Assistants            27
# 148       Secretaries and Administrative Assistants            26
# 412       Secretaries and Administrative Assistants            16
# ...                                             ...           ...
# 65482830  Secretaries and Administrative Assistants            49
# 65482850  Secretaries and Administrative Assistants            14
# 65482870                     Accountants & Auditors            20
# 65482985                     Accountants & Auditors            16
# 65483081                     Accountants & Auditors            71
#
# [1175018 rows x 35 columns]

# %%
# group by year and occupational code, taking sum of employment from each year
emp_df = df.groupby(['YEAR', 'OCCSOCTITLE']).agg('sum').reset_index()

emp_df
# Out:
#      YEAR                                    OCCSOCTITLE       SAMPLE  \
# 0    2000                         Accountants & Auditors  13988876361
# 1    2000                                Credit Analysts    262201431
# 2    2000                 Diagnostic Related Technicians   1763009454
# 3    2000                             Financial Analysts    472202646
# 4    2000  Insurance Claims and Policy Processing Clerks   1806610005
# ..    ...                                            ...          ...
# 155  2019                             Financial Analysts    524134996
# 156  2019  Insurance Claims and Policy Processing Clerks    327685323
# 157  2019                  Paralegals & Legal Assistants    688078608
# 158  2019      Secretaries and Administrative Assistants   4236892485
# 159  2019                                        Tellers    395322158
#
#            SERIAL      CBSERIAL     HHWT             CLUSTER  STATEICP  \
# 0    211165564591  0.000000e+00  2855405  139890111655722496   2742745
# 1      3775780843  0.000000e+00    54423    2622037757809861     47856
# 2     26125583102  0.000000e+00   316833   17630261255840506    340159
# 3      6509047143  0.000000e+00   112676    4722065090474076     78983
# 4     27719019543  0.000000e+00   407608   18066277190205480    338163
# ..            ...           ...      ...                 ...       ...
# 155    1829792465  5.241326e+15   253706    5241342297927246    100680
# 156    1197997637  3.276838e+15   170113    3276848979977993     64335
# 157    2367753578  6.880755e+15   333791    6880775677539188    139993
# 158   15162365630  4.236873e+16  1926034   42368866623676824    836141
# 159    1464915919  3.953203e+15   188068    3953216649161148     75047
#
#          STRATA     GQ  ...    OCC2010        IND   IND1990   WKSWORK1  \
# 0       4827180  70196  ...   55955200   44129168  46635266  3594076.0
# 1         91890   1320  ...    1088130     796214    811339    67266.0
# 2        593696   8944  ...   29265800    7129020   7254375   452256.0
# 3        161861   2361  ...    1983240    1580794   1604484   121093.0
# 4        634479   9064  ...   52752720    6312366   6420868   462728.0
# ..          ...    ...  ...        ...        ...       ...        ...
# 155  1374073028   2599  ...    2180640   16857075   1712486   134304.0
# 156   687704988   1625  ...    9478320   11700574   1192900    83912.0
# 157  1569538689   3445  ...    7293120   25177458   2809221   176335.0
# 158  9468542977  21145  ...  119614500  141831294  14473461  1083359.0
# 159   739659702   1982  ...   10103280   13466025   1371922   101049.0
#
#      WKSWORK2  UHRSWORK  LOOKING  WORKEDYR     INCWAGE  NUM_EMPLOYED
# 0      411423   3073770     6500    209832  3299373150       2796996
# 1        7693     55602      153      3933    52072700         51190
# 2       51728    373347     1124     26445   338909830        309990
# 3       13850    113499      189      7083   208262890        111602
# 4       52813    370004     1302     27099   261499704        389921
# ..        ...       ...      ...       ...         ...           ...
# 155     15444    117177     7628      7788   322586600        260425
# 156      9634     66377     4653      4869    73910308        176220
# 157     20266    140559     9791     10224   193719900        340274
# 158    124235    862844    60189     62955   936154250       1973368
# 159     11586     78624     5580      5874    62178800        200452
#
# [160 rows x 33 columns]

# %%
# construct time series
years = np.arange(2001, 2020, 1)
chefs = [] 
food_prep_sup = [] 
cooks = [] 
food_prep = [] 

ts_df_emp = pd.DataFrame({'Year': years})

# cooks = [] 
for code in np.unique(list(code_df.values())):
    tot_emp = [] 
    for year in years: 
        emp = np.mean(emp_df[(emp_df['YEAR'] == year) & (emp_df['OCCSOCTITLE'] == code)]['NUM_EMPLOYED'])
        tot_emp.append(emp)
    
    ts_df_emp[code] = tot_emp

ts_df_emp
# Out:
#     Year  Accountants & Auditors  Credit Analysts  \
# 0   2001               1380529.0          29431.0
# 1   2002               1373121.0          27657.0
# 2   2003               1480037.0          28124.0
# 3   2004               1508693.0          28492.0
# 4   2005               1533641.0          23794.0
# 5   2006               1601620.0          27308.0
# 6   2007               1664353.0          27079.0
# 7   2008               1746601.0          24398.0
# 8   2009               1711154.0          24175.0
# 9   2010               1648005.0          25519.0
# 10  2011               1664556.0          24431.0
# 11  2012               1713330.0          24511.0
# 12  2013               1670327.0          22498.0
# 13  2014               1566948.0          26506.0
# 14  2015               1588493.0          26844.0
# 15  2016               1608723.0          26462.0
# 16  2017               1688497.0          24783.0
# 17  2018               1690362.0          28015.0
# 18  2019               1419022.0          34782.0
#
#     Diagnostic Related Technicians  Financial Analysts  \
# 0                         187867.0             67844.0
# 1                         183189.0             88089.0
# 2                         179818.0             60447.0
# 3                         183456.0             47065.0
# 4                         198467.0             65409.0
# 5                         202331.0             62248.0
# 6                         229129.0             61554.0
# 7                         231311.0             70298.0
# 8                         236607.0             73039.0
# 9                         232879.0             70742.0
# 10                        232374.0             64484.0
# 11                        247813.0             61733.0
# 12                        240282.0             60267.0
# 13                        252716.0            184213.0
# 14                        257249.0            205874.0
# 15                        266325.0            192768.0
# 16                        293880.0            204326.0
# 17                        319586.0            194128.0
# 18                        329178.0            260425.0
#
#     Insurance Claims and Policy Processing Clerks  \
# 0                                        217613.0
# 1                                        246312.0
# 2                                        265510.0
# 3                                        274291.0
# 4                                        243300.0
# 5                                        257185.0
# 6                                        258841.0
# 7                                        268257.0
# 8                                        262161.0
# 9                                        246047.0
# 10                                       244946.0
# 11                                       292148.0
# 12                                       294882.0
# 13                                       308903.0
# 14                                       325563.0
# 15                                       335157.0
# 16                                       327752.0
# 17                                       184356.0
# 18                                       176220.0
#
#     Paralegals & Legal Assistants  Secretaries and Administrative Assistants  \
# 0                        235653.0                                  2831571.0
# 1                        252760.0                                  2699397.0
# 2                        240738.0                                  2556677.0
# 3                        258865.0                                  2683643.0
# 4                        267854.0                                  2634311.0
# 5                        279271.0                                  2732593.0
# 6                        285839.0                                  2668706.0
# 7                        280525.0                                  2750676.0
# 8                        290276.0                                  2657870.0
# 9                        296571.0                                  2551936.0
# 10                       303375.0                                  2407806.0
# 11                       308189.0                                  2477119.0
# 12                       308013.0                                  2413753.0
# 13                       316975.0                                  2270376.0
# 14                       319075.0                                  2299926.0
# 15                       319849.0                                  2243306.0
# 16                       326251.0                                  2204469.0
# 17                       331186.0                                  2046723.0
# 18                       340274.0                                  1973368.0
#
#      Tellers
# 0   227009.0
# 1   243590.0
# 2   246924.0
# 3   243385.0
# 4   244690.0
# 5   270025.0
# 6   273801.0
# 7   291303.0
# 8   274365.0
# 9   252407.0
# 10  252924.0
# 11  253259.0
# 12  246972.0
# 13  238464.0
# 14  226147.0
# 15  213806.0
# 16  205709.0
# 17  195483.0
# 18  200452.0

# %%
plt.figure(figsize=(16,8))
plt.plot(ts_df_emp['Year'], ts_df_emp['Paralegals & Legal Assistants'], label='Paralegals')
plt.plot(ts_df_emp['Year'], ts_df_emp['Secretaries and Administrative Assistants'], label='Secretaries')
#plt.plot(ts_df_emp['Year'], ts_df_emp['Accountants & Auditors'], label='Accountants & Auditors')
plt.plot(ts_df_emp['Year'], ts_df_emp['Diagnostic Related Technicians'], label='Diagnostic Technicians')
plt.plot(ts_df_emp['Year'], ts_df_emp['Insurance Claims and Policy Processing Clerks'], label='ICPP Clerks')
plt.plot(ts_df_emp['Year'], ts_df_emp['Tellers'], label='Tellers')
plt.plot(ts_df_emp['Year'], ts_df_emp['Credit Analysts'], label='Credit Analysts')
plt.plot(ts_df_emp['Year'], ts_df_emp['Financial Analysts'], label='Financial Analysts')

plt.xticks(years)
plt.legend()
plt.title("Change in Total Employment Over Time By Occupation")
# Out:
# Text(0.5, 1.0, 'Change in Total Employment Over Time By Occupation')

# %% [markdown]
# **TOMORROW: RUN DIFFERENCE IN DIFFERENCES**
#
# IBM Watson was introduced in 2006, and had its first commercial use with the Memorial Sloan Kettering Center for Cancer Research in 2013. Thus, I will use the year 2013 as the treatment year.
#
# Due to the capabilities of Watson with Natural Language Processing, Question and Answering, and Speech Recognition, the jobs it would likely immediately effect upon the introduction of commercial artificial intelligence usage would be jobs that require mechanical Q&A and scheduling work, such as Telemarketers. This is an example of substituting capital for labor in prediction tasks (Automating Prediction Tasks), as the appropriate response to a question is predicted. On the other hand, managerial positions and jobs focused on decision tasks, such as paralegal work, and financial managers
#
# In September 2011, IBM and WellPoint (now Anthem) announced a partnership to utilize Watson's data crunching capability to help suggest treatment options to physicians.[98] Then, in February 2013, IBM and WellPoint gave Watson its first commercial application, for utilization management decisions in lung cancer treatment at Memorial Sloan–Kettering Cancer Center.[9]
#
# Thus, I can look at wages and employment for medical assistants, secretaries, and physicians and surgeons before and after 2013, which is when AI started to be used commercially within the medical industry. These jobs will have to be restricted to the medical industry
#
# My hypothesis is that wages will increase for medical assistants and secretaries while employment falls. This is because those that can handle the technology will be paid more, but also more efficient. This is an example of substituting capital for labor. Furthermore, I would hypothesize that there will be a slight increase in wages and an ambiguous effect on employment for physicians and surgeons. This is because their jobs are augmented by AI, but most of the central tasks remain the same, so the technology hasn't reached a point where it can displace some major tasks.
#
# Equation:
#
# $Y_{ot} = T_{1ot}\sigma_{1} + T_{2ot}\sigma_{2} + AI_{ot}Post_{ot}\beta_{1} + AI_{ot}\pi + Educ_{o}\beta_{2}+ v_{ot}$
#
# Y_ot is outcome variable for occupation o in time t. T1 and T2 are dummies for pre and post periods. AI_ot is an indicator = 1 if the job is one related to Automating Prediction Tasks and 0 otherwise. Post_ot is an indicator = 1 if in the post period of the treatment. Educ is the mean years of education for each occupation.

# %%
# Look at Years 2000 - 2017
# Look only at Physicians and Surgeons, and Secretaries

medical_dict = {} 
medical_dict['291060'] = 'Physicians & Surgeons'
medical_dict['436010'] = 'Secretaries & Administrative Assistants'

medical_codes = list(medical_dict.keys())

medical_inds = {}
medical_inds[812] = 'Offices and clinics of physicians'
medical_inds[820] = 'Offices and clinics of dentists' 
medical_inds[821] = 'Offices and clinics of chripractors' 
medical_inds[822] = 'Offices and clinics of optometrists' 
medical_inds[830] = 'Offices and clinics of health practictioers, n.e.c' 
medical_inds[831] = 'Hospitals' 
medical_inds[832] = 'Nursing and personal care facilities' 
medical_inds[840] = 'Health services, n.e.c' 

medical_ind_codes = list(medical_inds.keys())

# %%
# Assumptions: Looking only @ Full-Time, Full-Year Workers (35+ hours worked, 40+ weeks worked)

# read in IPUMS Data and take only full-time full-year workers in medical jobs and industries
# also only take ages 18-65

TextFileReader = pd.read_csv("data/usa_00010.csv", chunksize = 20000)

def calculate_emp(x, y): 
    if (x == 1): 
        return x*y
    else: 
        return 0 

dfList_medical = []
counter = 0
for df in TextFileReader: 
    
    # extract important rows 
    df = df[(df['AGE'] >= 18) & (df['AGE'] <= 65)]
    
    # get only occupations of interest from 2000 to 2017 
    df = df[(df['OCCSOC'].isin(medical_codes)) & (df['IND1990'].isin(medical_ind_codes))]
    
    # get full-time, full-year workers (35+ hours/wk, 40+ wks/yr)
    df = df[(df['UHRSWORK'] >= 35)]
    df = df[(df['WKSWORK1'] >= 40) | (df['WKSWORK2'] >= 4)]
    
    dfList_medical.append(df)
    
    # verbose...
    counter += 1 
    if (counter % 100000): 
        print("processed ", round(counter*20000*100/65483126, 3), " percent of rows")

df_medical = pd.concat(dfList_medical, sort=False)
df_medical
# Out:
# processed  0.031  percent of rows
# processed  0.061  percent of rows
# processed  0.092  percent of rows
# processed  0.122  percent of rows
# processed  0.153  percent of rows
# processed  0.183  percent of rows
# processed  0.214  percent of rows
# processed  0.244  percent of rows
# processed  0.275  percent of rows
# processed  0.305  percent of rows
# processed  0.336  percent of rows
# processed  0.367  percent of rows
# processed  0.397  percent of rows
# processed  0.428  percent of rows
# processed  0.458  percent of rows
# processed  0.489  percent of rows
# processed  0.519  percent of rows
# processed  0.55  percent of rows
# processed  0.58  percent of rows
# processed  0.611  percent of rows
# processed  0.641  percent of rows
# processed  0.672  percent of rows
# processed  0.702  percent of rows
# processed  0.733  percent of rows
# processed  0.764  percent of rows
# processed  0.794  percent of rows
# processed  0.825  percent of rows
# processed  0.855  percent of rows
# processed  0.886  percent of rows
# processed  0.916  percent of rows
# processed  0.947  percent of rows
# processed  0.977  percent of rows
# processed  1.008  percent of rows
# processed  1.038  percent of rows
# processed  1.069  percent of rows
# processed  1.1  percent of rows
# processed  1.13  percent of rows
# processed  1.161  percent of rows
# processed  1.191  percent of rows
# processed  1.222  percent of rows
# processed  1.252  percent of rows
# processed  1.283  percent of rows
# processed  1.313  percent of rows
# processed  1.344  percent of rows
# processed  1.374  percent of rows
# processed  1.405  percent of rows
# processed  1.435  percent of rows
# processed  1.466  percent of rows
# processed  1.497  percent of rows
# processed  1.527  percent of rows
# processed  1.558  percent of rows
# processed  1.588  percent of rows
# processed  1.619  percent of rows
# processed  1.649  percent of rows
# processed  1.68  percent of rows
# processed  1.71  percent of rows
# processed  1.741  percent of rows
# processed  1.771  percent of rows
# processed  1.802  percent of rows
# processed  1.833  percent of rows
# processed  1.863  percent of rows
# processed  1.894  percent of rows
# processed  1.924  percent of rows
# processed  1.955  percent of rows
# processed  1.985  percent of rows
# processed  2.016  percent of rows
# processed  2.046  percent of rows
# processed  2.077  percent of rows
# processed  2.107  percent of rows
# processed  2.138  percent of rows
# processed  2.168  percent of rows
# processed  2.199  percent of rows
# processed  2.23  percent of rows
# processed  2.26  percent of rows
# processed  2.291  percent of rows
# processed  2.321  percent of rows
# processed  2.352  percent of rows
# processed  2.382  percent of rows
# processed  2.413  percent of rows
# processed  2.443  percent of rows
# processed  2.474  percent of rows
# processed  2.504  percent of rows
# processed  2.535  percent of rows
# processed  2.566  percent of rows
# processed  2.596  percent of rows
# processed  2.627  percent of rows
# processed  2.657  percent of rows
# processed  2.688  percent of rows
# processed  2.718  percent of rows
# processed  2.749  percent of rows
# processed  2.779  percent of rows
# processed  2.81  percent of rows
# processed  2.84  percent of rows
# processed  2.871  percent of rows
# processed  2.902  percent of rows
# processed  2.932  percent of rows
# processed  2.963  percent of rows
# processed  2.993  percent of rows
# processed  3.024  percent of rows
# processed  3.054  percent of rows
# processed  3.085  percent of rows
# processed  3.115  percent of rows
# processed  3.146  percent of rows
# processed  3.176  percent of rows
# processed  3.207  percent of rows
# processed  3.237  percent of rows
# processed  3.268  percent of rows
# processed  3.299  percent of rows
# processed  3.329  percent of rows
# processed  3.36  percent of rows
# processed  3.39  percent of rows
# processed  3.421  percent of rows
# processed  3.451  percent of rows
# processed  3.482  percent of rows
# processed  3.512  percent of rows
# processed  3.543  percent of rows
# processed  3.573  percent of rows
# processed  3.604  percent of rows
# processed  3.635  percent of rows
# processed  3.665  percent of rows
# processed  3.696  percent of rows
# processed  3.726  percent of rows
# processed  3.757  percent of rows
# processed  3.787  percent of rows
# processed  3.818  percent of rows
# processed  3.848  percent of rows
# processed  3.879  percent of rows
# processed  3.909  percent of rows
# processed  3.94  percent of rows
# processed  3.97  percent of rows
# processed  4.001  percent of rows
# processed  4.032  percent of rows
# processed  4.062  percent of rows
# processed  4.093  percent of rows
# processed  4.123  percent of rows
# processed  4.154  percent of rows
# processed  4.184  percent of rows
# processed  4.215  percent of rows
# processed  4.245  percent of rows
# processed  4.276  percent of rows
# processed  4.306  percent of rows
# processed  4.337  percent of rows
# processed  4.368  percent of rows
# processed  4.398  percent of rows
# processed  4.429  percent of rows
# processed  4.459  percent of rows
# processed  4.49  percent of rows
# processed  4.52  percent of rows
# processed  4.551  percent of rows
# processed  4.581  percent of rows
# processed  4.612  percent of rows
# processed  4.642  percent of rows
# processed  4.673  percent of rows
# processed  4.704  percent of rows
# processed  4.734  percent of rows
# processed  4.765  percent of rows
# processed  4.795  percent of rows
# processed  4.826  percent of rows
# processed  4.856  percent of rows
# processed  4.887  percent of rows
# processed  4.917  percent of rows
# processed  4.948  percent of rows
# processed  4.978  percent of rows
# processed  5.009  percent of rows
# processed  5.039  percent of rows
# processed  5.07  percent of rows
# processed  5.101  percent of rows
# processed  5.131  percent of rows
# processed  5.162  percent of rows
# processed  5.192  percent of rows
# processed  5.223  percent of rows
# processed  5.253  percent of rows
# processed  5.284  percent of rows
# processed  5.314  percent of rows
# processed  5.345  percent of rows
# processed  5.375  percent of rows
# processed  5.406  percent of rows
# processed  5.437  percent of rows
# processed  5.467  percent of rows
# processed  5.498  percent of rows
# processed  5.528  percent of rows
# processed  5.559  percent of rows
# processed  5.589  percent of rows
# processed  5.62  percent of rows
# processed  5.65  percent of rows
# processed  5.681  percent of rows
# processed  5.711  percent of rows
# processed  5.742  percent of rows
# processed  5.772  percent of rows
# processed  5.803  percent of rows
# processed  5.834  percent of rows
# processed  5.864  percent of rows
# processed  5.895  percent of rows
# processed  5.925  percent of rows
# processed  5.956  percent of rows
# processed  5.986  percent of rows
# processed  6.017  percent of rows
# processed  6.047  percent of rows
# processed  6.078  percent of rows
# processed  6.108  percent of rows
# processed  6.139  percent of rows
# processed  6.17  percent of rows
# processed  6.2  percent of rows
# processed  6.231  percent of rows
# processed  6.261  percent of rows
# processed  6.292  percent of rows
# processed  6.322  percent of rows
# processed  6.353  percent of rows
# processed  6.383  percent of rows
# processed  6.414  percent of rows
# processed  6.444  percent of rows
# processed  6.475  percent of rows
# processed  6.505  percent of rows
# processed  6.536  percent of rows
# processed  6.567  percent of rows
# processed  6.597  percent of rows
# processed  6.628  percent of rows
# processed  6.658  percent of rows
# processed  6.689  percent of rows
# processed  6.719  percent of rows
# processed  6.75  percent of rows
# processed  6.78  percent of rows
# processed  6.811  percent of rows
# processed  6.841  percent of rows
# processed  6.872  percent of rows
# processed  6.903  percent of rows
# processed  6.933  percent of rows
# processed  6.964  percent of rows
# processed  6.994  percent of rows
# processed  7.025  percent of rows
# processed  7.055  percent of rows
# processed  7.086  percent of rows
# processed  7.116  percent of rows
# processed  7.147  percent of rows
# processed  7.177  percent of rows
# processed  7.208  percent of rows
# processed  7.239  percent of rows
# processed  7.269  percent of rows
# processed  7.3  percent of rows
# processed  7.33  percent of rows
# processed  7.361  percent of rows
# processed  7.391  percent of rows
# processed  7.422  percent of rows
# processed  7.452  percent of rows
# processed  7.483  percent of rows
# processed  7.513  percent of rows
# processed  7.544  percent of rows
# processed  7.574  percent of rows
# processed  7.605  percent of rows
# processed  7.636  percent of rows
# processed  7.666  percent of rows
# processed  7.697  percent of rows
# processed  7.727  percent of rows
# processed  7.758  percent of rows
# processed  7.788  percent of rows
# processed  7.819  percent of rows
# processed  7.849  percent of rows
# processed  7.88  percent of rows
# processed  7.91  percent of rows
# processed  7.941  percent of rows
# processed  7.972  percent of rows
# processed  8.002  percent of rows
# processed  8.033  percent of rows
# processed  8.063  percent of rows
# processed  8.094  percent of rows
# processed  8.124  percent of rows
# processed  8.155  percent of rows
# processed  8.185  percent of rows
# processed  8.216  percent of rows
# processed  8.246  percent of rows
# processed  8.277  percent of rows
# processed  8.307  percent of rows
# processed  8.338  percent of rows
# processed  8.369  percent of rows
# processed  8.399  percent of rows
# processed  8.43  percent of rows
# processed  8.46  percent of rows
# processed  8.491  percent of rows
# processed  8.521  percent of rows
# processed  8.552  percent of rows
# processed  8.582  percent of rows
# processed  8.613  percent of rows
# processed  8.643  percent of rows
# processed  8.674  percent of rows
# processed  8.705  percent of rows
# processed  8.735  percent of rows
# processed  8.766  percent of rows
# processed  8.796  percent of rows
# processed  8.827  percent of rows
# processed  8.857  percent of rows
# processed  8.888  percent of rows
# processed  8.918  percent of rows
# processed  8.949  percent of rows
# processed  8.979  percent of rows
# processed  9.01  percent of rows
# processed  9.04  percent of rows
# processed  9.071  percent of rows
# processed  9.102  percent of rows
# processed  9.132  percent of rows
# processed  9.163  percent of rows
# processed  9.193  percent of rows
# processed  9.224  percent of rows
# processed  9.254  percent of rows
# processed  9.285  percent of rows
# processed  9.315  percent of rows
# processed  9.346  percent of rows
# processed  9.376  percent of rows
# processed  9.407  percent of rows
# processed  9.438  percent of rows
# processed  9.468  percent of rows
# processed  9.499  percent of rows
# processed  9.529  percent of rows
# processed  9.56  percent of rows
# processed  9.59  percent of rows
# processed  9.621  percent of rows
# processed  9.651  percent of rows
# processed  9.682  percent of rows
# processed  9.712  percent of rows
# processed  9.743  percent of rows
# processed  9.774  percent of rows
# processed  9.804  percent of rows
# processed  9.835  percent of rows
# processed  9.865  percent of rows
# processed  9.896  percent of rows
# processed  9.926  percent of rows
# processed  9.957  percent of rows
# processed  9.987  percent of rows
# processed  10.018  percent of rows
# processed  10.048  percent of rows
# processed  10.079  percent of rows
# processed  10.109  percent of rows
# processed  10.14  percent of rows
# processed  10.171  percent of rows
# processed  10.201  percent of rows
# processed  10.232  percent of rows
# processed  10.262  percent of rows
# processed  10.293  percent of rows
# processed  10.323  percent of rows
# processed  10.354  percent of rows
# processed  10.384  percent of rows
# processed  10.415  percent of rows
# processed  10.445  percent of rows
# processed  10.476  percent of rows
# processed  10.507  percent of rows
# processed  10.537  percent of rows
# processed  10.568  percent of rows
# processed  10.598  percent of rows
# processed  10.629  percent of rows
# processed  10.659  percent of rows
# processed  10.69  percent of rows
# processed  10.72  percent of rows
# processed  10.751  percent of rows
# processed  10.781  percent of rows
# processed  10.812  percent of rows
# processed  10.842  percent of rows
# processed  10.873  percent of rows
# processed  10.904  percent of rows
# processed  10.934  percent of rows
# processed  10.965  percent of rows
# processed  10.995  percent of rows
# processed  11.026  percent of rows
# processed  11.056  percent of rows
# processed  11.087  percent of rows
# processed  11.117  percent of rows
# processed  11.148  percent of rows
# processed  11.178  percent of rows
# processed  11.209  percent of rows
# processed  11.24  percent of rows
# processed  11.27  percent of rows
# processed  11.301  percent of rows
# processed  11.331  percent of rows
# processed  11.362  percent of rows
# processed  11.392  percent of rows
# processed  11.423  percent of rows
# processed  11.453  percent of rows
# processed  11.484  percent of rows
# processed  11.514  percent of rows
# processed  11.545  percent of rows
# processed  11.576  percent of rows
# processed  11.606  percent of rows
# processed  11.637  percent of rows
# processed  11.667  percent of rows
# processed  11.698  percent of rows
# processed  11.728  percent of rows
# processed  11.759  percent of rows
# processed  11.789  percent of rows
# processed  11.82  percent of rows
# processed  11.85  percent of rows
# processed  11.881  percent of rows
# processed  11.911  percent of rows
# processed  11.942  percent of rows
# processed  11.973  percent of rows
# processed  12.003  percent of rows
# processed  12.034  percent of rows
# processed  12.064  percent of rows
# processed  12.095  percent of rows
# processed  12.125  percent of rows
# processed  12.156  percent of rows
# processed  12.186  percent of rows
# processed  12.217  percent of rows
# processed  12.247  percent of rows
# processed  12.278  percent of rows
# processed  12.309  percent of rows
# processed  12.339  percent of rows
# processed  12.37  percent of rows
# processed  12.4  percent of rows
# processed  12.431  percent of rows
# processed  12.461  percent of rows
# processed  12.492  percent of rows
# processed  12.522  percent of rows
# processed  12.553  percent of rows
# processed  12.583  percent of rows
# processed  12.614  percent of rows
# processed  12.644  percent of rows
# processed  12.675  percent of rows
# processed  12.706  percent of rows
# processed  12.736  percent of rows
# processed  12.767  percent of rows
# processed  12.797  percent of rows
# processed  12.828  percent of rows
# processed  12.858  percent of rows
# processed  12.889  percent of rows
# processed  12.919  percent of rows
# processed  12.95  percent of rows
# processed  12.98  percent of rows
# processed  13.011  percent of rows
# processed  13.042  percent of rows
# processed  13.072  percent of rows
# processed  13.103  percent of rows
# processed  13.133  percent of rows
# processed  13.164  percent of rows
# processed  13.194  percent of rows
# processed  13.225  percent of rows
# processed  13.255  percent of rows
# processed  13.286  percent of rows
# processed  13.316  percent of rows
# processed  13.347  percent of rows
# processed  13.377  percent of rows
# processed  13.408  percent of rows
# processed  13.439  percent of rows
# processed  13.469  percent of rows
# processed  13.5  percent of rows
# processed  13.53  percent of rows
# processed  13.561  percent of rows
# processed  13.591  percent of rows
# processed  13.622  percent of rows
# processed  13.652  percent of rows
# processed  13.683  percent of rows
# processed  13.713  percent of rows
# processed  13.744  percent of rows
# processed  13.775  percent of rows
# processed  13.805  percent of rows
# processed  13.836  percent of rows
# processed  13.866  percent of rows
# processed  13.897  percent of rows
# processed  13.927  percent of rows
# processed  13.958  percent of rows
# processed  13.988  percent of rows
# processed  14.019  percent of rows
# processed  14.049  percent of rows
# processed  14.08  percent of rows
# processed  14.111  percent of rows
# processed  14.141  percent of rows
# processed  14.172  percent of rows
# processed  14.202  percent of rows
# processed  14.233  percent of rows
# processed  14.263  percent of rows
# processed  14.294  percent of rows
# processed  14.324  percent of rows
# processed  14.355  percent of rows
# processed  14.385  percent of rows
# processed  14.416  percent of rows
# processed  14.446  percent of rows
# processed  14.477  percent of rows
# processed  14.508  percent of rows
# processed  14.538  percent of rows
# processed  14.569  percent of rows
# processed  14.599  percent of rows
# processed  14.63  percent of rows
# processed  14.66  percent of rows
# processed  14.691  percent of rows
# processed  14.721  percent of rows
# processed  14.752  percent of rows
# processed  14.782  percent of rows
# processed  14.813  percent of rows
# processed  14.844  percent of rows
# processed  14.874  percent of rows
# processed  14.905  percent of rows
# processed  14.935  percent of rows
# processed  14.966  percent of rows
# processed  14.996  percent of rows
# processed  15.027  percent of rows
# processed  15.057  percent of rows
# processed  15.088  percent of rows
# processed  15.118  percent of rows
# processed  15.149  percent of rows
# processed  15.179  percent of rows
# processed  15.21  percent of rows
# processed  15.241  percent of rows
# processed  15.271  percent of rows
# processed  15.302  percent of rows
# processed  15.332  percent of rows
# processed  15.363  percent of rows
# processed  15.393  percent of rows
# processed  15.424  percent of rows
# processed  15.454  percent of rows
# processed  15.485  percent of rows
# processed  15.515  percent of rows
# processed  15.546  percent of rows
# processed  15.577  percent of rows
# processed  15.607  percent of rows
# processed  15.638  percent of rows
# processed  15.668  percent of rows
# processed  15.699  percent of rows
# processed  15.729  percent of rows
# processed  15.76  percent of rows
# processed  15.79  percent of rows
# processed  15.821  percent of rows
# processed  15.851  percent of rows
# processed  15.882  percent of rows
# processed  15.912  percent of rows
# processed  15.943  percent of rows
# processed  15.974  percent of rows
# processed  16.004  percent of rows
# processed  16.035  percent of rows
# processed  16.065  percent of rows
# processed  16.096  percent of rows
# processed  16.126  percent of rows
# processed  16.157  percent of rows
# processed  16.187  percent of rows
# processed  16.218  percent of rows
# processed  16.248  percent of rows
# processed  16.279  percent of rows
# processed  16.31  percent of rows
# processed  16.34  percent of rows
# processed  16.371  percent of rows
# processed  16.401  percent of rows
# processed  16.432  percent of rows
# processed  16.462  percent of rows
# processed  16.493  percent of rows
# processed  16.523  percent of rows
# processed  16.554  percent of rows
# processed  16.584  percent of rows
# processed  16.615  percent of rows
# processed  16.646  percent of rows
# processed  16.676  percent of rows
# processed  16.707  percent of rows
# processed  16.737  percent of rows
# processed  16.768  percent of rows
# processed  16.798  percent of rows
# processed  16.829  percent of rows
# processed  16.859  percent of rows
# processed  16.89  percent of rows
# processed  16.92  percent of rows
# processed  16.951  percent of rows
# processed  16.981  percent of rows
# processed  17.012  percent of rows
# processed  17.043  percent of rows
# processed  17.073  percent of rows
# processed  17.104  percent of rows
# processed  17.134  percent of rows
# processed  17.165  percent of rows
# processed  17.195  percent of rows
# processed  17.226  percent of rows
# processed  17.256  percent of rows
# processed  17.287  percent of rows
# processed  17.317  percent of rows
# processed  17.348  percent of rows
# processed  17.379  percent of rows
# processed  17.409  percent of rows
# processed  17.44  percent of rows
# processed  17.47  percent of rows
# processed  17.501  percent of rows
# processed  17.531  percent of rows
# processed  17.562  percent of rows
# processed  17.592  percent of rows
# processed  17.623  percent of rows
# processed  17.653  percent of rows
# processed  17.684  percent of rows
# processed  17.714  percent of rows
# processed  17.745  percent of rows
# processed  17.776  percent of rows
# processed  17.806  percent of rows
# processed  17.837  percent of rows
# processed  17.867  percent of rows
# processed  17.898  percent of rows
# processed  17.928  percent of rows
# processed  17.959  percent of rows
# processed  17.989  percent of rows
# processed  18.02  percent of rows
# processed  18.05  percent of rows
# processed  18.081  percent of rows
# processed  18.112  percent of rows
# processed  18.142  percent of rows
# processed  18.173  percent of rows
# processed  18.203  percent of rows
# processed  18.234  percent of rows
# processed  18.264  percent of rows
# processed  18.295  percent of rows
# processed  18.325  percent of rows
# processed  18.356  percent of rows
# processed  18.386  percent of rows
# processed  18.417  percent of rows
# processed  18.448  percent of rows
# processed  18.478  percent of rows
# processed  18.509  percent of rows
# processed  18.539  percent of rows
# processed  18.57  percent of rows
# processed  18.6  percent of rows
# processed  18.631  percent of rows
# processed  18.661  percent of rows
# processed  18.692  percent of rows
# processed  18.722  percent of rows
# processed  18.753  percent of rows
# processed  18.783  percent of rows
# processed  18.814  percent of rows
# processed  18.845  percent of rows
# processed  18.875  percent of rows
# processed  18.906  percent of rows
# processed  18.936  percent of rows
# processed  18.967  percent of rows
# processed  18.997  percent of rows
# processed  19.028  percent of rows
# processed  19.058  percent of rows
# processed  19.089  percent of rows
# processed  19.119  percent of rows
# processed  19.15  percent of rows
# processed  19.181  percent of rows
# processed  19.211  percent of rows
# processed  19.242  percent of rows
# processed  19.272  percent of rows
# processed  19.303  percent of rows
# processed  19.333  percent of rows
# processed  19.364  percent of rows
# processed  19.394  percent of rows
# processed  19.425  percent of rows
# processed  19.455  percent of rows
# processed  19.486  percent of rows
# processed  19.516  percent of rows
# processed  19.547  percent of rows
# processed  19.578  percent of rows
# processed  19.608  percent of rows
# processed  19.639  percent of rows
# processed  19.669  percent of rows
# processed  19.7  percent of rows
# processed  19.73  percent of rows
# processed  19.761  percent of rows
# processed  19.791  percent of rows
# processed  19.822  percent of rows
# processed  19.852  percent of rows
# processed  19.883  percent of rows
# processed  19.914  percent of rows
# processed  19.944  percent of rows
# processed  19.975  percent of rows
# processed  20.005  percent of rows
# processed  20.036  percent of rows
# processed  20.066  percent of rows
# processed  20.097  percent of rows
# processed  20.127  percent of rows
# processed  20.158  percent of rows
# processed  20.188  percent of rows
# processed  20.219  percent of rows
# processed  20.249  percent of rows
# processed  20.28  percent of rows
# processed  20.311  percent of rows
# processed  20.341  percent of rows
# processed  20.372  percent of rows
# processed  20.402  percent of rows
# processed  20.433  percent of rows
# processed  20.463  percent of rows
# processed  20.494  percent of rows
# processed  20.524  percent of rows
# processed  20.555  percent of rows
# processed  20.585  percent of rows
# processed  20.616  percent of rows
# processed  20.647  percent of rows
# processed  20.677  percent of rows
# processed  20.708  percent of rows
# processed  20.738  percent of rows
# processed  20.769  percent of rows
# processed  20.799  percent of rows
# processed  20.83  percent of rows
# processed  20.86  percent of rows
# processed  20.891  percent of rows
# processed  20.921  percent of rows
# processed  20.952  percent of rows
# processed  20.983  percent of rows
# processed  21.013  percent of rows
# processed  21.044  percent of rows
# processed  21.074  percent of rows
# processed  21.105  percent of rows
# processed  21.135  percent of rows
# processed  21.166  percent of rows
# processed  21.196  percent of rows
# processed  21.227  percent of rows
# processed  21.257  percent of rows
# processed  21.288  percent of rows
# processed  21.318  percent of rows
# processed  21.349  percent of rows
# processed  21.38  percent of rows
# processed  21.41  percent of rows
# processed  21.441  percent of rows
# processed  21.471  percent of rows
# processed  21.502  percent of rows
# processed  21.532  percent of rows
# processed  21.563  percent of rows
# processed  21.593  percent of rows
# processed  21.624  percent of rows
# processed  21.654  percent of rows
# processed  21.685  percent of rows
# processed  21.716  percent of rows
# processed  21.746  percent of rows
# processed  21.777  percent of rows
# processed  21.807  percent of rows
# processed  21.838  percent of rows
# processed  21.868  percent of rows
# processed  21.899  percent of rows
# processed  21.929  percent of rows
# processed  21.96  percent of rows
# processed  21.99  percent of rows
# processed  22.021  percent of rows
# processed  22.051  percent of rows
# processed  22.082  percent of rows
# processed  22.113  percent of rows
# processed  22.143  percent of rows
# processed  22.174  percent of rows
# processed  22.204  percent of rows
# processed  22.235  percent of rows
# processed  22.265  percent of rows
# processed  22.296  percent of rows
# processed  22.326  percent of rows
# processed  22.357  percent of rows
# processed  22.387  percent of rows
# processed  22.418  percent of rows
# processed  22.449  percent of rows
# processed  22.479  percent of rows
# processed  22.51  percent of rows
# processed  22.54  percent of rows
# processed  22.571  percent of rows
# processed  22.601  percent of rows
# processed  22.632  percent of rows
# processed  22.662  percent of rows
# processed  22.693  percent of rows
# processed  22.723  percent of rows
# processed  22.754  percent of rows
# processed  22.784  percent of rows
# processed  22.815  percent of rows
# processed  22.846  percent of rows
# processed  22.876  percent of rows
# processed  22.907  percent of rows
# processed  22.937  percent of rows
# processed  22.968  percent of rows
# processed  22.998  percent of rows
# processed  23.029  percent of rows
# processed  23.059  percent of rows
# processed  23.09  percent of rows
# processed  23.12  percent of rows
# processed  23.151  percent of rows
# processed  23.182  percent of rows
# processed  23.212  percent of rows
# processed  23.243  percent of rows
# processed  23.273  percent of rows
# processed  23.304  percent of rows
# processed  23.334  percent of rows
# processed  23.365  percent of rows
# processed  23.395  percent of rows
# processed  23.426  percent of rows
# processed  23.456  percent of rows
# processed  23.487  percent of rows
# processed  23.518  percent of rows
# processed  23.548  percent of rows
# processed  23.579  percent of rows
# processed  23.609  percent of rows
# processed  23.64  percent of rows
# processed  23.67  percent of rows
# processed  23.701  percent of rows
# processed  23.731  percent of rows
# processed  23.762  percent of rows
# processed  23.792  percent of rows
# processed  23.823  percent of rows
# processed  23.853  percent of rows
# processed  23.884  percent of rows
# processed  23.915  percent of rows
# processed  23.945  percent of rows
# processed  23.976  percent of rows
# processed  24.006  percent of rows
# processed  24.037  percent of rows
# processed  24.067  percent of rows
# processed  24.098  percent of rows
# processed  24.128  percent of rows
# processed  24.159  percent of rows
# processed  24.189  percent of rows
# processed  24.22  percent of rows
# processed  24.251  percent of rows
# processed  24.281  percent of rows
# processed  24.312  percent of rows
# processed  24.342  percent of rows
# processed  24.373  percent of rows
# processed  24.403  percent of rows
# processed  24.434  percent of rows
# processed  24.464  percent of rows
# processed  24.495  percent of rows
# processed  24.525  percent of rows
# processed  24.556  percent of rows
# processed  24.586  percent of rows
# processed  24.617  percent of rows
# processed  24.648  percent of rows
# processed  24.678  percent of rows
# processed  24.709  percent of rows
# processed  24.739  percent of rows
# processed  24.77  percent of rows
# processed  24.8  percent of rows
# processed  24.831  percent of rows
# processed  24.861  percent of rows
# processed  24.892  percent of rows
# processed  24.922  percent of rows
# processed  24.953  percent of rows
# processed  24.984  percent of rows
# processed  25.014  percent of rows
# processed  25.045  percent of rows
# processed  25.075  percent of rows
# processed  25.106  percent of rows
# processed  25.136  percent of rows
# processed  25.167  percent of rows
# processed  25.197  percent of rows
# processed  25.228  percent of rows
# processed  25.258  percent of rows
# processed  25.289  percent of rows
# processed  25.319  percent of rows
# processed  25.35  percent of rows
# processed  25.381  percent of rows
# processed  25.411  percent of rows
# processed  25.442  percent of rows
# processed  25.472  percent of rows
# processed  25.503  percent of rows
# processed  25.533  percent of rows
# processed  25.564  percent of rows
# processed  25.594  percent of rows
# processed  25.625  percent of rows
# processed  25.655  percent of rows
# processed  25.686  percent of rows
# processed  25.717  percent of rows
# processed  25.747  percent of rows
# processed  25.778  percent of rows
# processed  25.808  percent of rows
# processed  25.839  percent of rows
# processed  25.869  percent of rows
# processed  25.9  percent of rows
# processed  25.93  percent of rows
# processed  25.961  percent of rows
# processed  25.991  percent of rows
# processed  26.022  percent of rows
# processed  26.053  percent of rows
# processed  26.083  percent of rows
# processed  26.114  percent of rows
# processed  26.144  percent of rows
# processed  26.175  percent of rows
# processed  26.205  percent of rows
# processed  26.236  percent of rows
# processed  26.266  percent of rows
# processed  26.297  percent of rows
# processed  26.327  percent of rows
# processed  26.358  percent of rows
# processed  26.388  percent of rows
# processed  26.419  percent of rows
# processed  26.45  percent of rows
# processed  26.48  percent of rows
# processed  26.511  percent of rows
# processed  26.541  percent of rows
# processed  26.572  percent of rows
# processed  26.602  percent of rows
# processed  26.633  percent of rows
# processed  26.663  percent of rows
# processed  26.694  percent of rows
# processed  26.724  percent of rows
# processed  26.755  percent of rows
# processed  26.786  percent of rows
# processed  26.816  percent of rows
# processed  26.847  percent of rows
# processed  26.877  percent of rows
# processed  26.908  percent of rows
# processed  26.938  percent of rows
# processed  26.969  percent of rows
# processed  26.999  percent of rows
# processed  27.03  percent of rows
# processed  27.06  percent of rows
# processed  27.091  percent of rows
# processed  27.121  percent of rows
# processed  27.152  percent of rows
# processed  27.183  percent of rows
# processed  27.213  percent of rows
# processed  27.244  percent of rows
# processed  27.274  percent of rows
# processed  27.305  percent of rows
# processed  27.335  percent of rows
# processed  27.366  percent of rows
# processed  27.396  percent of rows
# processed  27.427  percent of rows
# processed  27.457  percent of rows
# processed  27.488  percent of rows
# processed  27.519  percent of rows
# processed  27.549  percent of rows
# processed  27.58  percent of rows
# processed  27.61  percent of rows
# processed  27.641  percent of rows
# processed  27.671  percent of rows
# processed  27.702  percent of rows
# processed  27.732  percent of rows
# processed  27.763  percent of rows
# processed  27.793  percent of rows
# processed  27.824  percent of rows
# processed  27.855  percent of rows
# processed  27.885  percent of rows
# processed  27.916  percent of rows
# processed  27.946  percent of rows
# processed  27.977  percent of rows
# processed  28.007  percent of rows
# processed  28.038  percent of rows
# processed  28.068  percent of rows
# processed  28.099  percent of rows
# processed  28.129  percent of rows
# processed  28.16  percent of rows
# processed  28.19  percent of rows
# processed  28.221  percent of rows
# processed  28.252  percent of rows
# processed  28.282  percent of rows
# processed  28.313  percent of rows
# processed  28.343  percent of rows
# processed  28.374  percent of rows
# processed  28.404  percent of rows
# processed  28.435  percent of rows
# processed  28.465  percent of rows
# processed  28.496  percent of rows
# processed  28.526  percent of rows
# processed  28.557  percent of rows
# processed  28.588  percent of rows
# processed  28.618  percent of rows
# processed  28.649  percent of rows
# processed  28.679  percent of rows
# processed  28.71  percent of rows
# processed  28.74  percent of rows
# processed  28.771  percent of rows
# processed  28.801  percent of rows
# processed  28.832  percent of rows
# processed  28.862  percent of rows
# processed  28.893  percent of rows
# processed  28.923  percent of rows
# processed  28.954  percent of rows
# processed  28.985  percent of rows
# processed  29.015  percent of rows
# processed  29.046  percent of rows
# processed  29.076  percent of rows
# processed  29.107  percent of rows
# processed  29.137  percent of rows
# processed  29.168  percent of rows
# processed  29.198  percent of rows
# processed  29.229  percent of rows
# processed  29.259  percent of rows
# processed  29.29  percent of rows
# processed  29.321  percent of rows
# processed  29.351  percent of rows
# processed  29.382  percent of rows
# processed  29.412  percent of rows
# processed  29.443  percent of rows
# processed  29.473  percent of rows
# processed  29.504  percent of rows
# processed  29.534  percent of rows
# processed  29.565  percent of rows
# processed  29.595  percent of rows
# processed  29.626  percent of rows
# processed  29.656  percent of rows
# processed  29.687  percent of rows
# processed  29.718  percent of rows
# processed  29.748  percent of rows
# processed  29.779  percent of rows
# processed  29.809  percent of rows
# processed  29.84  percent of rows
# processed  29.87  percent of rows
# processed  29.901  percent of rows
# processed  29.931  percent of rows
# processed  29.962  percent of rows
# processed  29.992  percent of rows
# processed  30.023  percent of rows
# processed  30.054  percent of rows
# processed  30.084  percent of rows
# processed  30.115  percent of rows
# processed  30.145  percent of rows
# processed  30.176  percent of rows
# processed  30.206  percent of rows
# processed  30.237  percent of rows
# processed  30.267  percent of rows
# processed  30.298  percent of rows
# processed  30.328  percent of rows
# processed  30.359  percent of rows
# processed  30.39  percent of rows
# processed  30.42  percent of rows
# processed  30.451  percent of rows
# processed  30.481  percent of rows
# processed  30.512  percent of rows
# processed  30.542  percent of rows
# processed  30.573  percent of rows
# processed  30.603  percent of rows
# processed  30.634  percent of rows
# processed  30.664  percent of rows
# processed  30.695  percent of rows
# processed  30.725  percent of rows
# processed  30.756  percent of rows
# processed  30.787  percent of rows
# processed  30.817  percent of rows
# processed  30.848  percent of rows
# processed  30.878  percent of rows
# processed  30.909  percent of rows
# processed  30.939  percent of rows
# processed  30.97  percent of rows
# processed  31.0  percent of rows
# processed  31.031  percent of rows
# processed  31.061  percent of rows
# processed  31.092  percent of rows
# processed  31.123  percent of rows
# processed  31.153  percent of rows
# processed  31.184  percent of rows
# processed  31.214  percent of rows
# processed  31.245  percent of rows
# processed  31.275  percent of rows
# processed  31.306  percent of rows
# processed  31.336  percent of rows
# processed  31.367  percent of rows
# processed  31.397  percent of rows
# processed  31.428  percent of rows
# processed  31.458  percent of rows
# processed  31.489  percent of rows
# processed  31.52  percent of rows
# processed  31.55  percent of rows
# processed  31.581  percent of rows
# processed  31.611  percent of rows
# processed  31.642  percent of rows
# processed  31.672  percent of rows
# processed  31.703  percent of rows
# processed  31.733  percent of rows
# processed  31.764  percent of rows
# processed  31.794  percent of rows
# processed  31.825  percent of rows
# processed  31.856  percent of rows
# processed  31.886  percent of rows
# processed  31.917  percent of rows
# processed  31.947  percent of rows
# processed  31.978  percent of rows
# processed  32.008  percent of rows
# processed  32.039  percent of rows
# processed  32.069  percent of rows
# processed  32.1  percent of rows
# processed  32.13  percent of rows
# processed  32.161  percent of rows
# processed  32.191  percent of rows
# processed  32.222  percent of rows
# processed  32.253  percent of rows
# processed  32.283  percent of rows
# processed  32.314  percent of rows
# processed  32.344  percent of rows
# processed  32.375  percent of rows
# processed  32.405  percent of rows
# processed  32.436  percent of rows
# processed  32.466  percent of rows
# processed  32.497  percent of rows
# processed  32.527  percent of rows
# processed  32.558  percent of rows
# processed  32.589  percent of rows
# processed  32.619  percent of rows
# processed  32.65  percent of rows
# processed  32.68  percent of rows
# processed  32.711  percent of rows
# processed  32.741  percent of rows
# processed  32.772  percent of rows
# processed  32.802  percent of rows
# processed  32.833  percent of rows
# processed  32.863  percent of rows
# processed  32.894  percent of rows
# processed  32.925  percent of rows
# processed  32.955  percent of rows
# processed  32.986  percent of rows
# processed  33.016  percent of rows
# processed  33.047  percent of rows
# processed  33.077  percent of rows
# processed  33.108  percent of rows
# processed  33.138  percent of rows
# processed  33.169  percent of rows
# processed  33.199  percent of rows
# processed  33.23  percent of rows
# processed  33.26  percent of rows
# processed  33.291  percent of rows
# processed  33.322  percent of rows
# processed  33.352  percent of rows
# processed  33.383  percent of rows
# processed  33.413  percent of rows
# processed  33.444  percent of rows
# processed  33.474  percent of rows
# processed  33.505  percent of rows
# processed  33.535  percent of rows
# processed  33.566  percent of rows
# processed  33.596  percent of rows
# processed  33.627  percent of rows
# processed  33.658  percent of rows
# processed  33.688  percent of rows
# processed  33.719  percent of rows
# processed  33.749  percent of rows
# processed  33.78  percent of rows
# processed  33.81  percent of rows
# processed  33.841  percent of rows
# processed  33.871  percent of rows
# processed  33.902  percent of rows
# processed  33.932  percent of rows
# processed  33.963  percent of rows
# processed  33.993  percent of rows
# processed  34.024  percent of rows
# processed  34.055  percent of rows
# processed  34.085  percent of rows
# processed  34.116  percent of rows
# processed  34.146  percent of rows
# processed  34.177  percent of rows
# processed  34.207  percent of rows
# processed  34.238  percent of rows
# processed  34.268  percent of rows
# processed  34.299  percent of rows
# processed  34.329  percent of rows
# processed  34.36  percent of rows
# processed  34.391  percent of rows
# processed  34.421  percent of rows
# processed  34.452  percent of rows
# processed  34.482  percent of rows
# processed  34.513  percent of rows
# processed  34.543  percent of rows
# processed  34.574  percent of rows
# processed  34.604  percent of rows
# processed  34.635  percent of rows
# processed  34.665  percent of rows
# processed  34.696  percent of rows
# processed  34.727  percent of rows
# processed  34.757  percent of rows
# processed  34.788  percent of rows
# processed  34.818  percent of rows
# processed  34.849  percent of rows
# processed  34.879  percent of rows
# processed  34.91  percent of rows
# processed  34.94  percent of rows
# processed  34.971  percent of rows
# processed  35.001  percent of rows
# processed  35.032  percent of rows
# processed  35.062  percent of rows
# processed  35.093  percent of rows
# processed  35.124  percent of rows
# processed  35.154  percent of rows
# processed  35.185  percent of rows
# processed  35.215  percent of rows
# processed  35.246  percent of rows
# processed  35.276  percent of rows
# processed  35.307  percent of rows
# processed  35.337  percent of rows
# processed  35.368  percent of rows
# processed  35.398  percent of rows
# processed  35.429  percent of rows
# processed  35.46  percent of rows
# processed  35.49  percent of rows
# processed  35.521  percent of rows
# processed  35.551  percent of rows
# processed  35.582  percent of rows
# processed  35.612  percent of rows
# processed  35.643  percent of rows
# processed  35.673  percent of rows
# processed  35.704  percent of rows
# processed  35.734  percent of rows
# processed  35.765  percent of rows
# processed  35.795  percent of rows
# processed  35.826  percent of rows
# processed  35.857  percent of rows
# processed  35.887  percent of rows
# processed  35.918  percent of rows
# processed  35.948  percent of rows
# processed  35.979  percent of rows
# processed  36.009  percent of rows
# processed  36.04  percent of rows
# processed  36.07  percent of rows
# processed  36.101  percent of rows
# processed  36.131  percent of rows
# processed  36.162  percent of rows
# processed  36.193  percent of rows
# processed  36.223  percent of rows
# processed  36.254  percent of rows
# processed  36.284  percent of rows
# processed  36.315  percent of rows
# processed  36.345  percent of rows
# processed  36.376  percent of rows
# processed  36.406  percent of rows
# processed  36.437  percent of rows
# processed  36.467  percent of rows
# processed  36.498  percent of rows
# processed  36.528  percent of rows
# processed  36.559  percent of rows
# processed  36.59  percent of rows
# processed  36.62  percent of rows
# processed  36.651  percent of rows
# processed  36.681  percent of rows
# processed  36.712  percent of rows
# processed  36.742  percent of rows
# processed  36.773  percent of rows
# processed  36.803  percent of rows
# processed  36.834  percent of rows
# processed  36.864  percent of rows
# processed  36.895  percent of rows
# processed  36.926  percent of rows
# processed  36.956  percent of rows
# processed  36.987  percent of rows
# processed  37.017  percent of rows
# processed  37.048  percent of rows
# processed  37.078  percent of rows
# processed  37.109  percent of rows
# processed  37.139  percent of rows
# processed  37.17  percent of rows
# processed  37.2  percent of rows
# processed  37.231  percent of rows
# processed  37.262  percent of rows
# processed  37.292  percent of rows
# processed  37.323  percent of rows
# processed  37.353  percent of rows
# processed  37.384  percent of rows
# processed  37.414  percent of rows
# processed  37.445  percent of rows
# processed  37.475  percent of rows
# processed  37.506  percent of rows
# processed  37.536  percent of rows
# processed  37.567  percent of rows
# processed  37.597  percent of rows
# processed  37.628  percent of rows
# processed  37.659  percent of rows
# processed  37.689  percent of rows
# processed  37.72  percent of rows
# processed  37.75  percent of rows
# processed  37.781  percent of rows
# processed  37.811  percent of rows
# processed  37.842  percent of rows
# processed  37.872  percent of rows
# processed  37.903  percent of rows
# processed  37.933  percent of rows
# processed  37.964  percent of rows
# processed  37.995  percent of rows
# processed  38.025  percent of rows
# processed  38.056  percent of rows
# processed  38.086  percent of rows
# processed  38.117  percent of rows
# processed  38.147  percent of rows
# processed  38.178  percent of rows
# processed  38.208  percent of rows
# processed  38.239  percent of rows
# processed  38.269  percent of rows
# processed  38.3  percent of rows
# processed  38.33  percent of rows
# processed  38.361  percent of rows
# processed  38.392  percent of rows
# processed  38.422  percent of rows
# processed  38.453  percent of rows
# processed  38.483  percent of rows
# processed  38.514  percent of rows
# processed  38.544  percent of rows
# processed  38.575  percent of rows
# processed  38.605  percent of rows
# processed  38.636  percent of rows
# processed  38.666  percent of rows
# processed  38.697  percent of rows
# processed  38.728  percent of rows
# processed  38.758  percent of rows
# processed  38.789  percent of rows
# processed  38.819  percent of rows
# processed  38.85  percent of rows
# processed  38.88  percent of rows
# processed  38.911  percent of rows
# processed  38.941  percent of rows
# processed  38.972  percent of rows
# processed  39.002  percent of rows
# processed  39.033  percent of rows
# processed  39.063  percent of rows
# processed  39.094  percent of rows
# processed  39.125  percent of rows
# processed  39.155  percent of rows
# processed  39.186  percent of rows
# processed  39.216  percent of rows
# processed  39.247  percent of rows
# processed  39.277  percent of rows
# processed  39.308  percent of rows
# processed  39.338  percent of rows
# processed  39.369  percent of rows
# processed  39.399  percent of rows
# processed  39.43  percent of rows
# processed  39.461  percent of rows
# processed  39.491  percent of rows
# processed  39.522  percent of rows
# processed  39.552  percent of rows
# processed  39.583  percent of rows
# processed  39.613  percent of rows
# processed  39.644  percent of rows
# processed  39.674  percent of rows
# processed  39.705  percent of rows
# processed  39.735  percent of rows
# processed  39.766  percent of rows
# processed  39.797  percent of rows
# processed  39.827  percent of rows
# processed  39.858  percent of rows
# processed  39.888  percent of rows
# processed  39.919  percent of rows
# processed  39.949  percent of rows
# processed  39.98  percent of rows
# processed  40.01  percent of rows
# processed  40.041  percent of rows
# processed  40.071  percent of rows
# processed  40.102  percent of rows
# processed  40.132  percent of rows
# processed  40.163  percent of rows
# processed  40.194  percent of rows
# processed  40.224  percent of rows
# processed  40.255  percent of rows
# processed  40.285  percent of rows
# processed  40.316  percent of rows
# processed  40.346  percent of rows
# processed  40.377  percent of rows
# processed  40.407  percent of rows
# processed  40.438  percent of rows
# processed  40.468  percent of rows
# processed  40.499  percent of rows
# processed  40.53  percent of rows
# processed  40.56  percent of rows
# processed  40.591  percent of rows
# processed  40.621  percent of rows
# processed  40.652  percent of rows
# processed  40.682  percent of rows
# processed  40.713  percent of rows
# processed  40.743  percent of rows
# processed  40.774  percent of rows
# processed  40.804  percent of rows
# processed  40.835  percent of rows
# processed  40.865  percent of rows
# processed  40.896  percent of rows
# processed  40.927  percent of rows
# processed  40.957  percent of rows
# processed  40.988  percent of rows
# processed  41.018  percent of rows
# processed  41.049  percent of rows
# processed  41.079  percent of rows
# processed  41.11  percent of rows
# processed  41.14  percent of rows
# processed  41.171  percent of rows
# processed  41.201  percent of rows
# processed  41.232  percent of rows
# processed  41.263  percent of rows
# processed  41.293  percent of rows
# processed  41.324  percent of rows
# processed  41.354  percent of rows
# processed  41.385  percent of rows
# processed  41.415  percent of rows
# processed  41.446  percent of rows
# processed  41.476  percent of rows
# processed  41.507  percent of rows
# processed  41.537  percent of rows
# processed  41.568  percent of rows
# processed  41.599  percent of rows
# processed  41.629  percent of rows
# processed  41.66  percent of rows
# processed  41.69  percent of rows
# processed  41.721  percent of rows
# processed  41.751  percent of rows
# processed  41.782  percent of rows
# processed  41.812  percent of rows
# processed  41.843  percent of rows
# processed  41.873  percent of rows
# processed  41.904  percent of rows
# processed  41.934  percent of rows
# processed  41.965  percent of rows
# processed  41.996  percent of rows
# processed  42.026  percent of rows
# processed  42.057  percent of rows
# processed  42.087  percent of rows
# processed  42.118  percent of rows
# processed  42.148  percent of rows
# processed  42.179  percent of rows
# processed  42.209  percent of rows
# processed  42.24  percent of rows
# processed  42.27  percent of rows
# processed  42.301  percent of rows
# ...
# processed  88.389  percent of rows
# processed  88.42  percent of rows
# processed  88.45  percent of rows
# processed  88.481  percent of rows
# processed  88.511  percent of rows
# processed  88.542  percent of rows
# processed  88.572  percent of rows
# processed  88.603  percent of rows
# processed  88.634  percent of rows
# processed  88.664  percent of rows
# processed  88.695  percent of rows
# processed  88.725  percent of rows
# processed  88.756  percent of rows
# processed  88.786  percent of rows
# processed  88.817  percent of rows
# processed  88.847  percent of rows
# processed  88.878  percent of rows
# processed  88.908  percent of rows
# processed  88.939  percent of rows
# processed  88.969  percent of rows
# processed  89.0  percent of rows
# processed  89.031  percent of rows
# processed  89.061  percent of rows
# processed  89.092  percent of rows
# processed  89.122  percent of rows
# processed  89.153  percent of rows
# processed  89.183  percent of rows
# processed  89.214  percent of rows
# processed  89.244  percent of rows
# processed  89.275  percent of rows
# processed  89.305  percent of rows
# processed  89.336  percent of rows
# processed  89.367  percent of rows
# processed  89.397  percent of rows
# processed  89.428  percent of rows
# processed  89.458  percent of rows
# processed  89.489  percent of rows
# processed  89.519  percent of rows
# processed  89.55  percent of rows
# processed  89.58  percent of rows
# processed  89.611  percent of rows
# processed  89.641  percent of rows
# processed  89.672  percent of rows
# processed  89.702  percent of rows
# processed  89.733  percent of rows
# processed  89.764  percent of rows
# processed  89.794  percent of rows
# processed  89.825  percent of rows
# processed  89.855  percent of rows
# processed  89.886  percent of rows
# processed  89.916  percent of rows
# processed  89.947  percent of rows
# processed  89.977  percent of rows
# processed  90.008  percent of rows
# processed  90.038  percent of rows
# processed  90.069  percent of rows
# processed  90.1  percent of rows
# processed  90.13  percent of rows
# processed  90.161  percent of rows
# processed  90.191  percent of rows
# processed  90.222  percent of rows
# processed  90.252  percent of rows
# processed  90.283  percent of rows
# processed  90.313  percent of rows
# processed  90.344  percent of rows
# processed  90.374  percent of rows
# processed  90.405  percent of rows
# processed  90.436  percent of rows
# processed  90.466  percent of rows
# processed  90.497  percent of rows
# processed  90.527  percent of rows
# processed  90.558  percent of rows
# processed  90.588  percent of rows
# processed  90.619  percent of rows
# processed  90.649  percent of rows
# processed  90.68  percent of rows
# processed  90.71  percent of rows
# processed  90.741  percent of rows
# processed  90.771  percent of rows
# processed  90.802  percent of rows
# processed  90.833  percent of rows
# processed  90.863  percent of rows
# processed  90.894  percent of rows
# processed  90.924  percent of rows
# processed  90.955  percent of rows
# processed  90.985  percent of rows
# processed  91.016  percent of rows
# processed  91.046  percent of rows
# processed  91.077  percent of rows
# processed  91.107  percent of rows
# processed  91.138  percent of rows
# processed  91.169  percent of rows
# processed  91.199  percent of rows
# processed  91.23  percent of rows
# processed  91.26  percent of rows
# processed  91.291  percent of rows
# processed  91.321  percent of rows
# processed  91.352  percent of rows
# processed  91.382  percent of rows
# processed  91.413  percent of rows
# processed  91.443  percent of rows
# processed  91.474  percent of rows
# processed  91.504  percent of rows
# processed  91.535  percent of rows
# processed  91.566  percent of rows
# processed  91.596  percent of rows
# processed  91.627  percent of rows
# processed  91.657  percent of rows
# processed  91.688  percent of rows
# processed  91.718  percent of rows
# processed  91.749  percent of rows
# processed  91.779  percent of rows
# processed  91.81  percent of rows
# processed  91.84  percent of rows
# processed  91.871  percent of rows
# processed  91.902  percent of rows
# processed  91.932  percent of rows
# processed  91.963  percent of rows
# processed  91.993  percent of rows
# processed  92.024  percent of rows
# processed  92.054  percent of rows
# processed  92.085  percent of rows
# processed  92.115  percent of rows
# processed  92.146  percent of rows
# processed  92.176  percent of rows
# processed  92.207  percent of rows
# processed  92.238  percent of rows
# processed  92.268  percent of rows
# processed  92.299  percent of rows
# processed  92.329  percent of rows
# processed  92.36  percent of rows
# processed  92.39  percent of rows
# processed  92.421  percent of rows
# processed  92.451  percent of rows
# processed  92.482  percent of rows
# processed  92.512  percent of rows
# processed  92.543  percent of rows
# processed  92.573  percent of rows
# processed  92.604  percent of rows
# processed  92.635  percent of rows
# processed  92.665  percent of rows
# processed  92.696  percent of rows
# processed  92.726  percent of rows
# processed  92.757  percent of rows
# processed  92.787  percent of rows
# processed  92.818  percent of rows
# processed  92.848  percent of rows
# processed  92.879  percent of rows
# processed  92.909  percent of rows
# processed  92.94  percent of rows
# processed  92.971  percent of rows
# processed  93.001  percent of rows
# processed  93.032  percent of rows
# processed  93.062  percent of rows
# processed  93.093  percent of rows
# processed  93.123  percent of rows
# processed  93.154  percent of rows
# processed  93.184  percent of rows
# processed  93.215  percent of rows
# processed  93.245  percent of rows
# processed  93.276  percent of rows
# processed  93.306  percent of rows
# processed  93.337  percent of rows
# processed  93.368  percent of rows
# processed  93.398  percent of rows
# processed  93.429  percent of rows
# processed  93.459  percent of rows
# processed  93.49  percent of rows
# processed  93.52  percent of rows
# processed  93.551  percent of rows
# processed  93.581  percent of rows
# processed  93.612  percent of rows
# processed  93.642  percent of rows
# processed  93.673  percent of rows
# processed  93.704  percent of rows
# processed  93.734  percent of rows
# processed  93.765  percent of rows
# processed  93.795  percent of rows
# processed  93.826  percent of rows
# processed  93.856  percent of rows
# processed  93.887  percent of rows
# processed  93.917  percent of rows
# processed  93.948  percent of rows
# processed  93.978  percent of rows
# processed  94.009  percent of rows
# processed  94.039  percent of rows
# processed  94.07  percent of rows
# processed  94.101  percent of rows
# processed  94.131  percent of rows
# processed  94.162  percent of rows
# processed  94.192  percent of rows
# processed  94.223  percent of rows
# processed  94.253  percent of rows
# processed  94.284  percent of rows
# processed  94.314  percent of rows
# processed  94.345  percent of rows
# processed  94.375  percent of rows
# processed  94.406  percent of rows
# processed  94.437  percent of rows
# processed  94.467  percent of rows
# processed  94.498  percent of rows
# processed  94.528  percent of rows
# processed  94.559  percent of rows
# processed  94.589  percent of rows
# processed  94.62  percent of rows
# processed  94.65  percent of rows
# processed  94.681  percent of rows
# processed  94.711  percent of rows
# processed  94.742  percent of rows
# processed  94.773  percent of rows
# processed  94.803  percent of rows
# processed  94.834  percent of rows
# processed  94.864  percent of rows
# processed  94.895  percent of rows
# processed  94.925  percent of rows
# processed  94.956  percent of rows
# processed  94.986  percent of rows
# processed  95.017  percent of rows
# processed  95.047  percent of rows
# processed  95.078  percent of rows
# processed  95.108  percent of rows
# processed  95.139  percent of rows
# processed  95.17  percent of rows
# processed  95.2  percent of rows
# processed  95.231  percent of rows
# processed  95.261  percent of rows
# processed  95.292  percent of rows
# processed  95.322  percent of rows
# processed  95.353  percent of rows
# processed  95.383  percent of rows
# processed  95.414  percent of rows
# processed  95.444  percent of rows
# processed  95.475  percent of rows
# processed  95.506  percent of rows
# processed  95.536  percent of rows
# processed  95.567  percent of rows
# processed  95.597  percent of rows
# processed  95.628  percent of rows
# processed  95.658  percent of rows
# processed  95.689  percent of rows
# processed  95.719  percent of rows
# processed  95.75  percent of rows
# processed  95.78  percent of rows
# processed  95.811  percent of rows
# processed  95.841  percent of rows
# processed  95.872  percent of rows
# processed  95.903  percent of rows
# processed  95.933  percent of rows
# processed  95.964  percent of rows
# processed  95.994  percent of rows
# processed  96.025  percent of rows
# processed  96.055  percent of rows
# processed  96.086  percent of rows
# processed  96.116  percent of rows
# processed  96.147  percent of rows
# processed  96.177  percent of rows
# processed  96.208  percent of rows
# processed  96.239  percent of rows
# processed  96.269  percent of rows
# processed  96.3  percent of rows
# processed  96.33  percent of rows
# processed  96.361  percent of rows
# processed  96.391  percent of rows
# processed  96.422  percent of rows
# processed  96.452  percent of rows
# processed  96.483  percent of rows
# processed  96.513  percent of rows
# processed  96.544  percent of rows
# processed  96.574  percent of rows
# processed  96.605  percent of rows
# processed  96.636  percent of rows
# processed  96.666  percent of rows
# processed  96.697  percent of rows
# processed  96.727  percent of rows
# processed  96.758  percent of rows
# processed  96.788  percent of rows
# processed  96.819  percent of rows
# processed  96.849  percent of rows
# processed  96.88  percent of rows
# processed  96.91  percent of rows
# processed  96.941  percent of rows
# processed  96.972  percent of rows
# processed  97.002  percent of rows
# processed  97.033  percent of rows
# processed  97.063  percent of rows
# processed  97.094  percent of rows
# processed  97.124  percent of rows
# processed  97.155  percent of rows
# processed  97.185  percent of rows
# processed  97.216  percent of rows
# processed  97.246  percent of rows
# processed  97.277  percent of rows
# processed  97.308  percent of rows
# processed  97.338  percent of rows
# processed  97.369  percent of rows
# processed  97.399  percent of rows
# processed  97.43  percent of rows
# processed  97.46  percent of rows
# processed  97.491  percent of rows
# processed  97.521  percent of rows
# processed  97.552  percent of rows
# processed  97.582  percent of rows
# processed  97.613  percent of rows
# processed  97.643  percent of rows
# processed  97.674  percent of rows
# processed  97.705  percent of rows
# processed  97.735  percent of rows
# processed  97.766  percent of rows
# processed  97.796  percent of rows
# processed  97.827  percent of rows
# processed  97.857  percent of rows
# processed  97.888  percent of rows
# processed  97.918  percent of rows
# processed  97.949  percent of rows
# processed  97.979  percent of rows
# processed  98.01  percent of rows
# processed  98.041  percent of rows
# processed  98.071  percent of rows
# processed  98.102  percent of rows
# processed  98.132  percent of rows
# processed  98.163  percent of rows
# processed  98.193  percent of rows
# processed  98.224  percent of rows
# processed  98.254  percent of rows
# processed  98.285  percent of rows
# processed  98.315  percent of rows
# processed  98.346  percent of rows
# processed  98.376  percent of rows
# processed  98.407  percent of rows
# processed  98.438  percent of rows
# processed  98.468  percent of rows
# processed  98.499  percent of rows
# processed  98.529  percent of rows
# processed  98.56  percent of rows
# processed  98.59  percent of rows
# processed  98.621  percent of rows
# processed  98.651  percent of rows
# processed  98.682  percent of rows
# processed  98.712  percent of rows
# processed  98.743  percent of rows
# processed  98.774  percent of rows
# processed  98.804  percent of rows
# processed  98.835  percent of rows
# processed  98.865  percent of rows
# processed  98.896  percent of rows
# processed  98.926  percent of rows
# processed  98.957  percent of rows
# processed  98.987  percent of rows
# processed  99.018  percent of rows
# processed  99.048  percent of rows
# processed  99.079  percent of rows
# processed  99.11  percent of rows
# processed  99.14  percent of rows
# processed  99.171  percent of rows
# processed  99.201  percent of rows
# processed  99.232  percent of rows
# processed  99.262  percent of rows
# processed  99.293  percent of rows
# processed  99.323  percent of rows
# processed  99.354  percent of rows
# processed  99.384  percent of rows
# processed  99.415  percent of rows
# processed  99.445  percent of rows
# processed  99.476  percent of rows
# processed  99.507  percent of rows
# processed  99.537  percent of rows
# processed  99.568  percent of rows
# processed  99.598  percent of rows
# processed  99.629  percent of rows
# processed  99.659  percent of rows
# processed  99.69  percent of rows
# processed  99.72  percent of rows
# processed  99.751  percent of rows
# processed  99.781  percent of rows
# processed  99.812  percent of rows
# processed  99.843  percent of rows
# processed  99.873  percent of rows
# processed  99.904  percent of rows
# processed  99.934  percent of rows
# processed  99.965  percent of rows
# processed  99.995  percent of rows
# processed  100.026  percent of rows
#           YEAR  SAMPLE   SERIAL      CBSERIAL  HHWT        CLUSTER  STATEICP  \
# 7         2000  200001        2           NaN    18  2000000000021         5
# 40        2000  200001       19           NaN    13  2000000000191         5
# 348       2000  200001      157           NaN    18  2000000001571         5
# 381       2000  200001      172           NaN    15  2000000001721         5
# 412       2000  200001      184           NaN    21  2000000001841         5
# ...        ...     ...      ...           ...   ...            ...       ...
# 65116532  2019  201901  1271421  2.019001e+12    93  2019012714211        49
# 65119398  2019  201901  1272531  2.019001e+12    21  2019012725311        49
# 65126860  2019  201901  1275462  2.019001e+12   277  2019012754621        49
# 65134158  2019  201901  1278328  2.019001e+12    53  2019012783281        49
# 65154716  2019  201901  1286410  2.019001e+12   107  2019012864101        49
#
#           STRATA  GQ  PERNUM  ...  OCCSOC   IND  IND1990  INDNAICS  WKSWORK1  \
# 7             60   1       1  ...  291060   809      840      6214      52.0
# 40            64   1       1  ...  291060   797      812      6211      52.0
# 348           65   1       1  ...  291060   797      812      6211      48.0
# 381           64   1       1  ...  291060   797      812      6211      52.0
# 412           60   1       2  ...  436010   819      831       622      41.0
# ...          ...  ..     ...  ...     ...   ...      ...       ...       ...
# 65116532  461448   1       1  ...  432021  8090      840      6214      52.0
# 65119398  100048   1       1  ...  432021  8191      831      622M      52.0
# 65126860  330348   1       1  ...  432021  8070      822     62132      52.0
# 65134158  670248   1       2  ...  432021  8191      831      622M      52.0
# 65154716  461748   1       1  ...  432021  8180      840      621M      52.0
#
#           WKSWORK2  UHRSWORK  LOOKING  WORKEDYR  INCWAGE
# 7                6        50        0         3   150000
# 40               6        50        0         3        0
# 348              5        60        0         3   294000
# 381              6        64        0         3   294000
# 412              4        40        0         3    17700
# ...            ...       ...      ...       ...      ...
# 65116532         6        40        3         3    30000
# 65119398         6        40        3         3    29000
# 65126860         6        52        3         3     7900
# 65134158         6        40        3         3    21000
# 65154716         6        40        1         3    26000
#
# [208615 rows x 33 columns]

# %%
# For Wages, need to only look at those who are employed

df_medical_grp = df_medical[df_medical['EMPSTAT'] == 1]
df_medical_grp = df_medical_grp[df_medical['INCWAGE'] != 0]
df_medical_grp['INCWAGE_REAL'] = df_medical_grp.apply(lambda x: convert_99(x['YEAR'], x['INCWAGE']), axis=1)
df_medical_grp['LOGWAGE_REAL'] = np.log(df_medical_grp['INCWAGE_REAL'])

# group by year and occupational code
wage_df_med = df_medical_grp.groupby(['YEAR', 'OCCSOC']).agg({'EDUC': 'mean', 'LOGWAGE_REAL': 'mean'}).reset_index()

wage_df_med.head()
# Out:
# /Users/sidsatya/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#    YEAR  OCCSOC       EDUC  LOGWAGE_REAL
# 0  2000  291060  10.958342     11.595251
# 1  2000  432021   6.512346      9.922775
# 2  2000  436010   6.878899     10.035454
# 3  2001  291060  10.939594     11.576120
# 4  2001  432021   5.647059      9.907961

# %%
# construct time series
years = np.arange(2000, 2018, 1)

med_wages = pd.DataFrame({'Year': years})

# cooks = [] 
for occ in medical_codes:
    mean_wages = []
    mean_educ = [] 
    
    for year in years: 
        wage = np.mean(wage_df_med[(wage_df_med['YEAR'] == year) & (wage_df_med['OCCSOC'] == occ)]['LOGWAGE_REAL'])
        mean_wages.append(wage)
        
        mean_educ.append(np.mean(emp_df_med[(emp_df_med['YEAR'] == year) & (emp_df_med['OCCSOC'] == occ)]['EDUC']))
    
    med_wages[occ + '_wage'] = mean_wages
    med_wages[occ + '_educ'] = mean_educ
    
med_wages
# Out:
#     Year  291060_wage  291060_educ  436010_wage  436010_educ  432021_wage  \
# 0   2000    11.595251    10.958757    10.035454     6.881667     9.922775
# 1   2001    11.576120    10.944532    10.021128     6.919327     9.907961
# 2   2002    11.633264    10.950784    10.002926     6.874021     9.796480
# 3   2003    11.614727    10.964679    10.019691     6.901925     9.996705
# 4   2004    11.520324    10.973900    10.050204     6.987066    10.000421
# 5   2005    11.650869    10.985846    10.040931     6.928554     9.934914
# 6   2006    11.645316    10.981744    10.027772     6.989029     9.904461
# 7   2007    11.659573    10.986005    10.040509     7.026334     9.892997
# 8   2008    11.634753    10.865343    10.029758     7.015552     9.953849
# 9   2009    11.680786    10.976980    10.061386     7.105263     9.863206
# 10  2010    11.674261    10.961774    10.074646     7.129438     9.893021
# 11  2011    11.650837    10.952715    10.044420     7.128326     9.955568
# 12  2012    11.662032    10.963194    10.045249     7.169468     9.903138
# 13  2013    11.688320    10.928096    10.025252     7.173882     9.964556
# 14  2014    11.706481    11.000000    10.034175     7.177728     9.853869
# 15  2015    11.738507    10.962378    10.064412     7.251210     9.926298
# 16  2016    11.790126    10.957029    10.042839     7.267710     9.952499
# 17  2017    11.747906    10.950844    10.064789     7.317665    10.002895
#
#     432021_educ
# 0      6.509202
# 1      5.647059
# 2      6.736842
# 3      6.800000
# 4      6.666667
# 5      6.666667
# 6      6.606061
# 7      6.794118
# 8      6.484848
# 9      7.114286
# 10     7.060000
# 11     6.725000
# 12     6.860465
# 13     6.769231
# 14     6.937500
# 15     7.258065
# 16     7.051282
# 17     6.745098

# %%
plt.figure(figsize=(16,8))
plt.plot(med_wages['Year'], med_wages['291060_wage'], label=medical_dict['291060'])
plt.plot(med_wages['Year'], med_wages['436010_wage'], label=medical_dict['436010'])
plt.plot(med_wages['Year'], med_wages['432021_wage'], label=medical_dict['432021'])
plt.vlines(2011, 9, 12, linestyle="dashed")
plt.xticks(years)
plt.legend()
plt.title("Change in Mean Wages Over Time By Occupation")
# Out:
# Text(0.5, 1.0, 'Change in Mean Wages Over Time By Occupation')

# %%
data_wages = med_wages[['Year', '291060_wage', '436010_wage', '432021_wage']]
data_wages = data_wages.melt(id_vars = ['Year'], 
                              var_name = ['occ'],
                              value_name = 'log wage')

data_educ = med_emp[['Year', '291060_educ', '436010_educ', '432021_educ']]
data_educ = data_educ.melt(id_vars = ['Year'], 
                          var_name = ['occ'],
                          value_name = 'educ')

data_wages = pd.concat([data_wages, data_educ['educ']], axis=1)

# compare only two jobs 
data_wages = data_wages[data_wages['occ'] != '432021_wage']


data_wages['Pre'] = data_wages['Year'].apply(lambda x: 1 if x < 2011 else 0)
data_wages['Post'] = data_wages['Year'].apply(lambda x: 1 if x >= 2011 else 0)
data_wages['AI'] = data_wages['occ'].apply(lambda x: 1 if x == '436010_wage' else 0)
data_wages['AIPost'] = data_wages['AI']*data_wages['Post']
data_wages = data_wages[data_wages['Year'] >= 2005]
# data_wages.head()

year_dummies = pd.get_dummies(data_wages['Year']).rename(columns = lambda x: 'year_' + str(x)).iloc[:, :-1]
#data_wages = pd.concat([data_wages, year_dummies], axis=1)
data_wages.head()
# Out:
#    Year          occ   log wage       educ  Pre  Post  AI  AIPost
# 5  2005  291060_wage  11.650869  10.985846    1     0   0       0
# 6  2006  291060_wage  11.645316  10.981744    1     0   0       0
# 7  2007  291060_wage  11.659573  10.986005    1     0   0       0
# 8  2008  291060_wage  11.634753  10.865343    1     0   0       0
# 9  2009  291060_wage  11.680786  10.976980    1     0   0       0

# %%
e_os_0 = np.mean(data_wages[(data_wages['Post'] == 0) & (data_wages['AI'] == 0)]['log wage'])
e_os_1 = np.mean(data_wages[(data_wages['Post'] == 0) & (data_wages['AI'] == 1)]['log wage'])
e_ot_0 = np.mean(data_wages[(data_wages['Post'] == 1) & (data_wages['AI'] == 0)]['log wage'])
e_ot_1 = np.mean(data_wages[(data_wages['Post'] == 1) & (data_wages['AI'] == 1)]['log wage'])

pi = e_os_1 - e_os_0
pi_plus_beta = e_ot_1 - e_ot_0

beta = pi_plus_beta - pi
beta
# Out:
# -0.05439400239906789

# %%
#X = pd.concat([data_wages[['Post', 'AI', 'AIPost', 'educ']], year_dummies], axis=1)
X = data_wages[['Post', 'AI', 'AIPost']]
X = smf.add_constant(X)
Y = data_wages['log wage']
wage_res1 = smf.OLS(Y,X).fit()

X = data_wages[['Post', 'AI', 'AIPost', 'educ']]
X = smf.add_constant(X)
Y = data_wages['log wage']
wage_res2 = smf.OLS(Y,X).fit()

stargazer = Stargazer([wage_res1, wage_res2])
stargazer.title("Wage Regressions")
stargazer.custom_columns(['No Covariates', 'Adding Education as a Covariate'], [1, 1])
stargazer
# Out:
# Wage Regressions<br><table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable:log wage</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">No Covariates</td><td colspan="1">Adding Education as a Covariate</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">AI</td><td>-1.612<sup>***</sup></td><td>-0.930<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(0.017)</td><td>(0.431)</td></tr><tr><td style="text-align:left">AIPost</td><td>-0.054<sup>**</sup></td><td>-0.086<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.023)</td><td>(0.030)</td></tr><tr><td style="text-align:left">Post</td><td>0.054<sup>***</sup></td><td>0.055<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.017)</td><td>(0.016)</td></tr><tr><td style="text-align:left">const</td><td>11.658<sup>***</sup></td><td>9.756<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.012)</td><td>(1.202)</td></tr><tr><td style="text-align:left">educ</td><td></td><td>0.173<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.110)</td></tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>26</td><td>26</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.999</td><td>0.999</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.999</td><td>0.999</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.030 (df=22)</td><td>0.029 (df=21)</td></tr><tr><td style="text-align: left">F Statistic</td><td>6604.849<sup>***</sup> (df=3; 22)</td><td>5292.623<sup>***</sup> (df=4; 21)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="2" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# The coefficient on AIPost is the difference in differences estimate. This variable is statistically significant. The coefficient on Post is equal to the change in the secretaries mean wage over time. The coefficient on AI is the difference in mean wage between physicians and secretaries before the release of IBM Watson

# %%
#physicians = df_medical[(df_medical['YEAR']==2005) & (df_medical['OCCSOC'] == '291060')][['YEAR', 'INCWAGE', 'IND1990']]
#physicians.groupby('IND1990').agg('mean')
phys_ind = df_medical.groupby(['IND1990', 'YEAR']).agg('mean').reset_index()
#phys_ind

ind_codes = np.unique(phys_ind['IND1990'])

df_ind = pd.DataFrame({'Year': years})
for code in ind_codes: 
    mwa = []
    for year in years:
        mwa.append(np.mean(phys_ind[(phys_ind['YEAR']==year) & (phys_ind['IND1990'] == code)]['INCWAGE']))
    
    df_ind[code] = mwa
    
plt.figure(figsize = (16,8))
plt.plot(df_ind['Year'], df_ind[812], label='812')
plt.plot(df_ind['Year'], df_ind[820], label='820')
plt.plot(df_ind['Year'], df_ind[821], label='821')
plt.plot(df_ind['Year'], df_ind[822], label='822')
plt.plot(df_ind['Year'], df_ind[831], label='831')
plt.plot(df_ind['Year'], df_ind[832], label='832')
plt.plot(df_ind['Year'], df_ind[840], label='840')
plt.xticks(years)
plt.legend()

# %% [markdown]
# We can see a dip in wages in 2004. This seems strange, so will need more inspection. For now, might need to only use years 2005 - 2017 = 12 datapoints.

# %%
# need to only look at those who are employed
def calculate_emp(x, y): 
    if (x == 1): 
        return x*y
    else: 
        return 0 
    
df_medical_grp2 = df_medical[df_medical['EMPSTAT'] == 1]
df_medical_grp2['EMP'] = df_medical_grp2['PERWT']
#df_medical_grp2['LOGEMP'] = np.log(df_medical_grp2['EMP'])

# group by year and occupational code
emp_df_med = df_medical_grp2.groupby(['YEAR', 'OCCSOC']).agg({'EMP': 'sum', 'EDUC': 'mean'}).reset_index()
emp_df_med['LOGEMP'] = np.log(emp_df_med['EMP'])

emp_df_med.head()
# Out:
# /Users/sidsatya/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#    YEAR  OCCSOC      EMP       EDUC     LOGEMP
# 0  2000  291060  1122390  10.958757  13.930971
# 1  2000  432021     5601   6.509202   8.630700
# 2  2000  436010   731697   6.881667  13.503122
# 3  2001  291060   554360  10.944532  13.225570
# 4  2001  432021     3607   5.647059   8.190632

# %%
# construct time series
years = np.arange(2000, 2018, 1)

med_emp = pd.DataFrame({'Year': years})

# cooks = [] 
for occ in medical_codes:
    tot_emp = [] 
    mean_educ = []
    for year in years: 
        emp = np.mean(emp_df_med[(emp_df_med['YEAR'] == year) & (emp_df_med['OCCSOC'] == occ)]['LOGEMP'])
        tot_emp.append(emp)
        
        mean_educ.append(np.mean(emp_df_med[(emp_df_med['YEAR'] == year) & (emp_df_med['OCCSOC'] == occ)]['EDUC']))
    
    med_emp[occ + '_emp'] = tot_emp
    med_emp[occ + '_educ'] = mean_educ
    
med_emp
# Out:
#     Year  291060_emp  291060_educ  436010_emp  436010_educ  432021_emp  \
# 0   2000   13.930971    10.958757   13.503122     6.881667    8.630700
# 1   2001   13.225570    10.944532   12.842274     6.919327    8.190632
# 2   2002   13.237016    10.950784   12.849617     6.874021    8.698181
# 3   2003   13.301498    10.964679   12.840229     6.901925    8.572249
# 4   2004   13.324974    10.973900   12.856965     6.987066    8.015988
# 5   2005   13.334409    10.985846   12.900427     6.928554    8.137688
# 6   2006   13.335539    10.981744   12.911573     6.989029    8.349011
# 7   2007   13.364829    10.986005   12.915915     7.026334    8.276140
# 8   2008   13.410436    10.865343   12.997172     7.015552    8.076205
# 9   2009   13.398813    10.976980   13.017711     7.105263    8.369157
# 10  2010   13.395040    10.961774   12.989182     7.129438    8.624432
# 11  2011   13.440269    10.952715   12.948422     7.128326    8.393895
# 12  2012   13.432063    10.963194   12.983154     7.169468    8.328934
# 13  2013   13.442786    10.928096   12.922402     7.173882    8.556029
# 14  2014   13.384523    11.000000   12.889023     7.177728    8.205765
# 15  2015   13.431737    10.962378   12.890600     7.251210    8.231908
# 16  2016   13.446244    10.957029   12.857960     7.267710    8.254789
# 17  2017   13.477594    10.950844   12.864861     7.317665    8.868835
#
#     432021_educ
# 0      6.509202
# 1      5.647059
# 2      6.736842
# 3      6.800000
# 4      6.666667
# 5      6.666667
# 6      6.606061
# 7      6.794118
# 8      6.484848
# 9      7.114286
# 10     7.060000
# 11     6.725000
# 12     6.860465
# 13     6.769231
# 14     6.937500
# 15     7.258065
# 16     7.051282
# 17     6.745098

# %%
plt.figure(figsize=(16,8))
plt.plot(med_wages['Year'], med_emp['291060_emp'], label=medical_dict['291060'])
plt.plot(med_wages['Year'], med_emp['436010_emp'], label=medical_dict['436010'])
plt.plot(med_wages['Year'], med_emp['432021_emp'], label=medical_dict['432021'])
plt.vlines(2011, 7, 15, linestyle="dashed")
plt.xticks(years)
plt.legend()
plt.title("Change in FTE Employment Over Time By Occupation")
# Out:
# Text(0.5, 1.0, 'Change in FTE Employment Over Time By Occupation')

# %% [markdown]
# Equation:
#
# $Y_{ot} = T_{1ot}\delta_{1} + T_{2ot}\delta_{2} + AI_{ot}Post_{ot}\beta_{1} + AI_{ot}\pi + v_{ot}$
#
# Y_ot is outcome variable for occupation o in time t. T1 and T2 are dummies for pre and post periods. AI_ot is an indicator = 1 if the job is one related to Automating Prediction Tasks and 0 otherwise. Post_ot is an indicator = 1 if in the post period of the treatment.

# %%
data = med_emp[['Year', '291060_emp', '436010_emp', '432021_emp']]
data = data.melt(id_vars = ['Year'], 
          var_name = ['occ'],
          value_name = 'log emp')

data_educ = med_emp[['Year', '291060_educ', '436010_educ', '432021_educ']]
data_educ = data_educ.melt(id_vars = ['Year'], 
                      var_name = ['occ'],
                      value_name = 'educ')

data = pd.concat([data, data_educ['educ']], axis=1)

# compare only two jobs 
data = data[data['occ'] != '432021_wage']

data['Pre'] = data['Year'].apply(lambda x: 1 if x < 2011 else 0)
data['Post'] = data['Year'].apply(lambda x: 1 if x >= 2011 else 0)
data['AI'] = data['occ'].apply(lambda x: 1 if x == '436010_emp' else 0)
data['AIPost'] = data['AI']*data['Post']
data = data[data['Year'] >= 2001]
year_dummies = pd.get_dummies(data['Year']).rename(columns = lambda x: 'year_' + str(x)).iloc[:, :-1]
data.head()
# Out:
#    Year         occ    log emp       educ  Pre  Post  AI  AIPost
# 1  2001  291060_emp  13.225570  10.944532    1     0   0       0
# 2  2002  291060_emp  13.237016  10.950784    1     0   0       0
# 3  2003  291060_emp  13.301498  10.964679    1     0   0       0
# 4  2004  291060_emp  13.324974  10.973900    1     0   0       0
# 5  2005  291060_emp  13.334409  10.985846    1     0   0       0

# %% [markdown]
# $E[y_{os} | A_{o} = 0] = \delta_{1}$
#
# $E[y_{os} | A_{o} = 1] = \delta_{1} + \pi$
#
# $E[y_{ot} | A_{o} = 0] = \delta_{2}$
#
# $E[y_{ot} | A_{o} = 1] = \delta_{2} + \beta_{1} + \pi$
#
# We want to estimate $\beta_{1}$

# %%
e_os_0 = np.mean(data[(data['Post'] == 0) & (data['AI'] == 0)]['log emp'])
e_os_1 = np.mean(data[(data['Post'] == 0) & (data['AI'] == 1)]['log emp'])
e_ot_0 = np.mean(data[(data['Post'] == 1) & (data['AI'] == 0)]['log emp'])
e_ot_1 = np.mean(data[(data['Post'] == 1) & (data['AI'] == 1)]['log emp'])

pi = e_os_1 - e_os_0
pi_plus_beta = e_ot_1 - e_ot_0

beta = pi_plus_beta - pi
beta
# Out:
# -0.09325368327383465

# %%
#X = pd.concat([data[['Post', 'AI', 'AIPost', 'educ']], year_dummies], axis=1)
X = data[['Post', 'AI', 'AIPost']]
X = smf.add_constant(X)
Y = data['log emp']
emp_res1 = smf.OLS(Y,X).fit()

X = data[['Post', 'AI', 'AIPost', 'educ']]
X = smf.add_constant(X)
Y = data['log emp']
emp_res2 = smf.OLS(Y,X).fit()

stargazer = Stargazer([emp_res1, emp_res2])
stargazer.title("Employment Regressions")
stargazer.custom_columns(['No Covariates', 'Education'], [1, 1])
stargazer
# Out:
# Employment Regressions<br><table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable:log emp</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">No Covariates</td><td colspan="1">Education</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">AI</td><td>2.080<sup>**</sup></td><td>4.229<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.828)</td><td>(0.109)</td></tr><tr><td style="text-align:left">AIPost</td><td>-0.093<sup></sup></td><td>-0.211<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(1.290)</td><td>(0.159)</td></tr><tr><td style="text-align:left">Post</td><td>0.089<sup></sup></td><td>-0.058<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.745)</td><td>(0.092)</td></tr><tr><td style="text-align:left">const</td><td>10.832<sup>***</sup></td><td>0.436<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(0.478)</td><td>(0.197)</td></tr><tr><td style="text-align:left">educ</td><td></td><td>1.180<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.021)</td></tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>51</td><td>51</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.181</td><td>0.988</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.128</td><td>0.987</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>2.137 (df=47)</td><td>0.263 (df=46)</td></tr><tr><td style="text-align: left">F Statistic</td><td>3.454<sup>**</sup> (df=3; 47)</td><td>936.994<sup>***</sup> (df=4; 46)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="2" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# The coefficient on AIPost is the difference in differences estimate which we found above. This variable is not statistically significant. The coefficient on Post is -7367.5167, which is equal to the change in the secretaries employment over time. The coefficient on AI is ~42230, which is the difference in FTE employment between physicians and secretaries before the release of IBM Watson

# %% [markdown]
# **WORK TO BE DONE**

# %% [markdown]
# 1. Revise the thought process for the regressions, take note of the models on the thesis doc, and gather info about OVB or assumptions that might be violated. It is important to understand what I expect to happen based on the assumptions from the JEP paper and compare it to the results.
# 2. Think about potential covaraites like sex, age, race to add and look at michael webb's regressions to see how he defined changes in employment or wage
# 3. Consider more regressions to run, such as an OLS similar to the one done in the feeling economy paper.
# 4. IDEA: Take low-skilled vs high-skill labor. Define high-skill as college education or more. I'll have to use mean education first. Then, regress outcomes for low-skill and high-skill in a DiD approach, using Watson as treatment. I can introduce occupation-level variables this way, such as mean education. I can also include industry fixed effects. This would give an insight into potential changes in low skill and high skill labor in the medical industry.

# %% [markdown]
# **SIMPLE OLS ON NUMBER OF PATENTS AND WAGES/EMPLOYMENT**

# %%
aipatents_world = pd.read_csv("data/aipatents_world.csv")
aw = aipatents_world.iloc[7:, :].reset_index()
aw
# Out:
#     index  Unnamed: 0        Year  KindDate Patents Office & Families  \
# 0       7         181  2005-01-01  PRIORITY       IP5 Patent families
# 1       8         205  2006-01-01  PRIORITY       IP5 Patent families
# 2       9         229  2007-01-01  PRIORITY       IP5 Patent families
# 3      10         253  2008-01-01  PRIORITY       IP5 Patent families
# 4      11         277  2009-01-01  PRIORITY       IP5 Patent families
# 5      12         301  2010-01-01  PRIORITY       IP5 Patent families
# 6      13         325  2011-01-01  PRIORITY       IP5 Patent families
# 7      14         349  2012-01-01  PRIORITY       IP5 Patent families
# 8      15         373  2013-01-01  PRIORITY       IP5 Patent families
# 9      16         397  2014-01-01  PRIORITY       IP5 Patent families
# 10     17         421  2015-01-01  PRIORITY       IP5 Patent families
# 11     18         445  2016-01-01  PRIORITY       IP5 Patent families
# 12     19         469  2017-01-01  PRIORITY       IP5 Patent families
#
#                                Ref. Country  num_patents
# 0   Inventor(s)'s country(ies) of residence       1818.0
# 1   Inventor(s)'s country(ies) of residence       1969.0
# 2   Inventor(s)'s country(ies) of residence       2183.0
# 3   Inventor(s)'s country(ies) of residence       2277.0
# 4   Inventor(s)'s country(ies) of residence       2250.0
# 5   Inventor(s)'s country(ies) of residence       2335.0
# 6   Inventor(s)'s country(ies) of residence       2404.0
# 7   Inventor(s)'s country(ies) of residence       2719.0
# 8   Inventor(s)'s country(ies) of residence       2980.0
# 9   Inventor(s)'s country(ies) of residence       3247.0
# 10  Inventor(s)'s country(ies) of residence       3451.0
# 11  Inventor(s)'s country(ies) of residence       4496.0
# 12  Inventor(s)'s country(ies) of residence       4432.0

# %%
dw_ols = data_wages[['Year', 'occ', 'log wage', 'educ']]
dw_ols_p = pd.concat([dw_ols[dw_ols['occ'] == '291060_wage'].reset_index(), aw['num_patents']], axis=1)
dw_ols_s = pd.concat([dw_ols[dw_ols['occ'] == '436010_wage'].reset_index(), aw['num_patents']], axis=1)
dw_ols_s
# Out:
#     index  Year          occ   log wage      educ  num_patents
# 0      23  2005  436010_wage  12.900427  6.928554       1818.0
# 1      24  2006  436010_wage  12.911573  6.989029       1969.0
# 2      25  2007  436010_wage  12.915915  7.026334       2183.0
# 3      26  2008  436010_wage  12.997172  7.015552       2277.0
# 4      27  2009  436010_wage  13.017711  7.105263       2250.0
# 5      28  2010  436010_wage  12.989182  7.129438       2335.0
# 6      29  2011  436010_wage  12.948422  7.128326       2404.0
# 7      30  2012  436010_wage  12.983154  7.169468       2719.0
# 8      31  2013  436010_wage  12.922402  7.173882       2980.0
# 9      32  2014  436010_wage  12.889023  7.177728       3247.0
# 10     33  2015  436010_wage  12.890600  7.251210       3451.0
# 11     34  2016  436010_wage  12.857960  7.267710       4496.0
# 12     35  2017  436010_wage  12.864861  7.317665       4432.0

# %%
aw['Year'] = np.arange(2005, 2018,1)
dw = pd.merge(data_wages, aw[['Year', 'num_patents']], how='inner', on='Year')

X = dw[['num_patents', 'educ', 'AI']]
X = smf.add_constant(X)
Y = dw['log wage']
res2 = smf.OLS(Y, X).fit()
#print(res2.summary())

X = dw_ols_s[['num_patents', 'educ']]
X = smf.add_constant(X)
Y = dw_ols_s['log wage']
res3 = smf.OLS(Y, X).fit()

X = dw_ols_p[['num_patents', 'educ']]
X = smf.add_constant(X)
Y = dw_ols_p['log wage']
res4 = smf.OLS(Y, X).fit()

stargazer = Stargazer([res2, res3, res4])
stargazer.title("Physicians vs. Secretaries Regressions")
stargazer.custom_columns(['Combined', 'Secretaries', 'Physicians'], [1, 1, 1])
stargazer
# Out:
# Physicians vs. Secretaries Regressions<br><table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:log wage</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Combined</td><td colspan="1">Secretaries</td><td colspan="1">Physicians</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">AI</td><td>1.689<sup>***</sup></td><td></td><td></td></tr><tr><td style="text-align:left"></td><td>(0.521)</td><td></td><td></td></tr><tr><td style="text-align:left">const</td><td>15.134<sup>***</sup></td><td>9.662<sup>***</sup></td><td>18.895<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.948)</td><td>(1.470)</td><td>(2.394)</td></tr><tr><td style="text-align:left">educ</td><td>-0.316<sup>**</sup></td><td>0.497<sup>**</sup></td><td>-0.510<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(0.136)</td><td>(0.216)</td><td>(0.218)</td></tr><tr><td style="text-align:left">num_patents</td><td>0.000<sup></sup></td><td>-0.000<sup>***</sup></td><td>0.000<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td><td>(0.000)</td><td>(0.000)</td></tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>26</td><td>13</td><td>13</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.971</td><td>0.600</td><td>0.715</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.967</td><td>0.519</td><td>0.658</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.045 (df=22)</td><td>0.036 (df=10)</td><td>0.026 (df=10)</td></tr><tr><td style="text-align: left">F Statistic</td><td>243.360<sup>***</sup> (df=3; 22)</td><td>7.486<sup>**</sup> (df=2; 10)</td><td>12.541<sup>***</sup> (df=2; 10)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %%
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               log wage   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.967
# Method:                 Least Squares   F-statistic:                     243.4
# Date:                Sun, 25 Apr 2021   Prob (F-statistic):           5.12e-17
# Time:                        00:20:02   Log-Likelihood:                 45.786
# No. Observations:                  26   AIC:                            -83.57
# Df Residuals:                      22   BIC:                            -78.54
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          15.1337      0.948     15.970      0.000      13.168      17.099
# num_patents  1.855e-05   1.32e-05      1.404      0.174   -8.85e-06    4.59e-05
# educ           -0.3164      0.136     -2.327      0.030      -0.598      -0.034
# AI              1.6894      0.521      3.242      0.004       0.609       2.770
# ==============================================================================
# Omnibus:                        0.763   Durbin-Watson:                   1.242
# Prob(Omnibus):                  0.683   Jarque-Bera (JB):                0.806
# Skew:                           0.277   Prob(JB):                        0.668
# Kurtosis:                       2.338   Cond. No.                     3.61e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.61e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Looking at Employment Right Now**

# %%
de = data[data['Year'] >= 2005]
de = pd.merge(de, aw[['Year', 'num_patents']], how='inner', on='Year')
de
# Out:
#     Year         occ    log emp       educ  Pre  Post  AI  AIPost  num_patents
# 0   2005  291060_emp  13.334409  10.985846    1     0   1       0       1818.0
# 1   2005  436010_emp  12.900427   6.928554    1     0   0       0       1818.0
# 2   2005  432021_emp   8.137688   6.666667    1     0   0       0       1818.0
# 3   2006  291060_emp  13.335539  10.981744    1     0   1       0       1969.0
# 4   2006  436010_emp  12.911573   6.989029    1     0   0       0       1969.0
# 5   2006  432021_emp   8.349011   6.606061    1     0   0       0       1969.0
# 6   2007  291060_emp  13.364829  10.986005    1     0   1       0       2183.0
# 7   2007  436010_emp  12.915915   7.026334    1     0   0       0       2183.0
# 8   2007  432021_emp   8.276140   6.794118    1     0   0       0       2183.0
# 9   2008  291060_emp  13.410436  10.865343    1     0   1       0       2277.0
# 10  2008  436010_emp  12.997172   7.015552    1     0   0       0       2277.0
# 11  2008  432021_emp   8.076205   6.484848    1     0   0       0       2277.0
# 12  2009  291060_emp  13.398813  10.976980    1     0   1       0       2250.0
# 13  2009  436010_emp  13.017711   7.105263    1     0   0       0       2250.0
# 14  2009  432021_emp   8.369157   7.114286    1     0   0       0       2250.0
# 15  2010  291060_emp  13.395040  10.961774    1     0   1       0       2335.0
# 16  2010  436010_emp  12.989182   7.129438    1     0   0       0       2335.0
# 17  2010  432021_emp   8.624432   7.060000    1     0   0       0       2335.0
# 18  2011  291060_emp  13.440269  10.952715    0     1   1       1       2404.0
# 19  2011  436010_emp  12.948422   7.128326    0     1   0       0       2404.0
# 20  2011  432021_emp   8.393895   6.725000    0     1   0       0       2404.0
# 21  2012  291060_emp  13.432063  10.963194    0     1   1       1       2719.0
# 22  2012  436010_emp  12.983154   7.169468    0     1   0       0       2719.0
# 23  2012  432021_emp   8.328934   6.860465    0     1   0       0       2719.0
# 24  2013  291060_emp  13.442786  10.928096    0     1   1       1       2980.0
# 25  2013  436010_emp  12.922402   7.173882    0     1   0       0       2980.0
# 26  2013  432021_emp   8.556029   6.769231    0     1   0       0       2980.0
# 27  2014  291060_emp  13.384523  11.000000    0     1   1       1       3247.0
# 28  2014  436010_emp  12.889023   7.177728    0     1   0       0       3247.0
# 29  2014  432021_emp   8.205765   6.937500    0     1   0       0       3247.0
# 30  2015  291060_emp  13.431737  10.962378    0     1   1       1       3451.0
# 31  2015  436010_emp  12.890600   7.251210    0     1   0       0       3451.0
# 32  2015  432021_emp   8.231908   7.258065    0     1   0       0       3451.0
# 33  2016  291060_emp  13.446244  10.957029    0     1   1       1       4496.0
# 34  2016  436010_emp  12.857960   7.267710    0     1   0       0       4496.0
# 35  2016  432021_emp   8.254789   7.051282    0     1   0       0       4496.0
# 36  2017  291060_emp  13.477594  10.950844    0     1   1       1       4432.0
# 37  2017  436010_emp  12.864861   7.317665    0     1   0       0       4432.0
# 38  2017  432021_emp   8.868835   6.745098    0     1   0       0       4432.0

# %%
X = de[['num_patents', 'AI', 'educ']]
X = smf.add_constant(X)
Y = de['log emp']
res5 = smf.OLS(Y, X).fit()


de_p = de[de['occ'] == '291060_emp']
X = de_p[['num_patents', 'educ']]
X = smf.add_constant(X)
Y = de_p['log emp']
res6 = smf.OLS(Y, X).fit()

de_s = de[de['occ'] == '436010_emp']
X = de_s[['num_patents', 'educ']]
X = smf.add_constant(X)
Y = de_s['log emp']
res7 = smf.OLS(Y, X).fit()

stargazer = Stargazer([res5, res6, res7])
stargazer.title("Employment OLS Regs")
stargazer.custom_columns(['Combined', 'Secretaries', 'Physicians'], [1, 1, 1])
stargazer
# Out:
# Employment OLS Regs<br><table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:log emp</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Combined</td><td colspan="1">Secretaries</td><td colspan="1">Physicians</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">AI</td><td>-26.099<sup>***</sup></td><td></td><td></td></tr><tr><td style="text-align:left"></td><td>(5.557)</td><td></td><td></td></tr><tr><td style="text-align:left">const</td><td>-38.828<sup>***</sup></td><td>18.895<sup>***</sup></td><td>9.662<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(9.508)</td><td>(2.394)</td><td>(1.470)</td></tr><tr><td style="text-align:left">educ</td><td>7.272<sup>***</sup></td><td>-0.510<sup>**</sup></td><td>0.497<sup>**</sup></td></tr><tr><td style="text-align:left"></td><td>(1.394)</td><td>(0.218)</td><td>(0.216)</td></tr><tr><td style="text-align:left">num_patents</td><td>-0.000<sup></sup></td><td>0.000<sup>***</sup></td><td>-0.000<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.000)</td><td>(0.000)</td><td>(0.000)</td></tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>39</td><td>13</td><td>13</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.621</td><td>0.715</td><td>0.600</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.589</td><td>0.658</td><td>0.519</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>1.481 (df=35)</td><td>0.026 (df=10)</td><td>0.036 (df=10)</td></tr><tr><td style="text-align: left">F Statistic</td><td>19.125<sup>***</sup> (df=3; 35)</td><td>12.541<sup>***</sup> (df=2; 10)</td><td>7.486<sup>**</sup> (df=2; 10)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %%
X = de[['num_patents', 'AI']]
X = smf.add_constant(X)
Y = de['educ']
res8 = smf.OLS(Y, X).fit()

print(res8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   educ   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     2181.
# Date:                Sun, 25 Apr 2021   Prob (F-statistic):           2.71e-38
# Time:                        00:39:21   Log-Likelihood:                 13.759
# No. Observations:                  39   AIC:                            -21.52
# Df Residuals:                      36   BIC:                            -16.53
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           6.7916      0.101     67.262      0.000       6.587       6.996
# num_patents  7.071e-05   3.37e-05      2.097      0.043    2.33e-06       0.000
# AI              3.9689      0.060     66.019      0.000       3.847       4.091
# ==============================================================================
# Omnibus:                        5.482   Durbin-Watson:                   2.363
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                4.753
# Skew:                          -0.854   Prob(JB):                       0.0929
# Kurtosis:                       3.084   Cond. No.                     1.06e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.06e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Industry and Year Fixed Effects**

# %% [markdown]
# Looking only at ind1990 = 812, Offices of Physicians.

# %% [markdown]
# **Wages**

# %%
df_medical_grp = df_medical[df_medical['EMPSTAT'] == 1]
df_medical_grp = df_medical_grp[df_medical['INCWAGE'] != 0]
df_medical_grp['INCWAGE_REAL'] = df_medical_grp.apply(lambda x: convert_99(x['YEAR'], x['INCWAGE']), axis=1)
df_medical_grp['LOGWAGE_REAL'] = np.log(df_medical_grp['INCWAGE_REAL'])
df_medical_grp = df_medical_grp[(df_medical_grp['IND1990'] == 812)]

# group by year and occupational code
wage_df_med = df_medical_grp.groupby(['YEAR', 'OCCSOC', 'IND1990']).agg({'EDUC': 'mean',
                                                                         'LOGWAGE_REAL': 'mean',
                                                                         'AGE': 'mean'}).reset_index()

wage_df_med['LOGEDUC'] = np.log(wage_df_med['EDUC'])
wage_df_med['LOGAGE'] = np.log(wage_df_med['AGE'])
wage_df_med = wage_df_med[(wage_df_med['YEAR'] <= 2017) & (wage_df_med['OCCSOC'] != '432021')]
wage_df_med.head()
# Out:
# /Users/sidsatya/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#    YEAR  OCCSOC  IND1990       EDUC  LOGWAGE_REAL        AGE   LOGEDUC  \
# 0  2000  291060      812  10.966951     11.791087  45.883529  2.394886
# 2  2000  436010      812   6.883488     10.036114  41.016718  1.929125
# 3  2001  291060      812  10.962547     11.800783  46.046816  2.394485
# 5  2001  436010      812   7.046083     10.012508  41.451613  1.952472
# 6  2002  291060      812  10.933333     11.916533  46.100000  2.391816
#
#      LOGAGE
# 0  3.826106
# 2  3.713980
# 3  3.829659
# 5  3.724527
# 6  3.830813

# %%
wage_df_med['Pre'] = wage_df_med['YEAR'].apply(lambda x: 1 if x < 2011 else 0)
wage_df_med['Post'] = wage_df_med['YEAR'].apply(lambda x: 1 if x >= 2011 else 0)
wage_df_med['AI'] = wage_df_med['OCCSOC'].apply(lambda x: 1 if x == '436010' else 0)
wage_df_med['AIPost'] = wage_df_med['AI']*wage_df_med['Post']
#wage_df_med = wage_df_med[wage_df_med['YEAR'] >= 2005]

ind_dummies = pd.get_dummies(wage_df_med['IND1990']).rename(columns= lambda x: 'ind_' + str(x)).iloc[:, :-1]
year_dummies = pd.get_dummies(wage_df_med['YEAR']).iloc[:, :-1].rename(columns = lambda x: str(x))

# %%
X = wage_df_med[['Post', 'AI', 'AIPost']]
X = smf.add_constant(X)
Y = wage_df_med['LOGWAGE_REAL']
fe_w_res1 = smf.OLS(Y,X).fit()

X = pd.concat([wage_df_med[['Post', 'AI', 'AIPost']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = wage_df_med['LOGWAGE_REAL']
fe_w_res2 = smf.OLS(Y,X).fit()

X = pd.concat([wage_df_med[['Post', 'AI', 'AIPost', 'LOGEDUC', 'LOGAGE']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = wage_df_med['LOGWAGE_REAL']
fe_w_res3 = smf.OLS(Y,X).fit()

stargazer = Stargazer([fe_w_res1, fe_w_res2, fe_w_res3])
stargazer.title("Wage OLS Regs")
stargazer.custom_columns(['No Controls', 'Year FE', 'Year FE + Controls'], [1, 1, 1])
stargazer
# Out:
# Wage OLS Regs<br><table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:LOGWAGE_REAL</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">No Controls</td><td colspan="1">Year FE</td><td colspan="1">Year FE + Controls</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">2000</td><td></td><td>0.881<sup>***</sup></td><td>1.037<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.495)</td></tr><tr><td style="text-align:left">2001</td><td></td><td>0.874<sup>***</sup></td><td>1.041<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.515)</td></tr><tr><td style="text-align:left">2002</td><td></td><td>0.908<sup>***</sup></td><td>1.056<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.515)</td></tr><tr><td style="text-align:left">2003</td><td></td><td>0.888<sup>***</sup></td><td>1.037<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.529)</td></tr><tr><td style="text-align:left">2004</td><td></td><td>0.830<sup>***</sup></td><td>0.990<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.541)</td></tr><tr><td style="text-align:left">2005</td><td></td><td>0.917<sup>***</sup></td><td>1.073<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.549)</td></tr><tr><td style="text-align:left">2006</td><td></td><td>0.913<sup>***</sup></td><td>1.069<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.561)</td></tr><tr><td style="text-align:left">2007</td><td></td><td>0.920<sup>***</sup></td><td>1.085<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.566)</td></tr><tr><td style="text-align:left">2008</td><td></td><td>0.893<sup>***</sup></td><td>1.046<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.559)</td></tr><tr><td style="text-align:left">2009</td><td></td><td>0.951<sup>***</sup></td><td>1.117<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.588)</td></tr><tr><td style="text-align:left">2010</td><td></td><td>0.946<sup>***</sup></td><td>1.108<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.034)</td><td>(0.574)</td></tr><tr><td style="text-align:left">2011</td><td></td><td>-0.077<sup></sup></td><td>-0.093<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.049)</td><td>(0.056)</td></tr><tr><td style="text-align:left">2012</td><td></td><td>-0.053<sup></sup></td><td>-0.061<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.049)</td><td>(0.054)</td></tr><tr><td style="text-align:left">2013</td><td></td><td>-0.049<sup></sup></td><td>-0.056<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.049)</td><td>(0.054)</td></tr><tr><td style="text-align:left">2014</td><td></td><td>-0.043<sup></sup></td><td>-0.052<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.049)</td><td>(0.054)</td></tr><tr><td style="text-align:left">2015</td><td></td><td>-0.022<sup></sup></td><td>-0.023<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.049)</td><td>(0.053)</td></tr><tr><td style="text-align:left">2016</td><td></td><td>0.009<sup></sup></td><td>0.003<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.049)</td><td>(0.053)</td></tr><tr><td style="text-align:left">AI</td><td>-1.829<sup>***</sup></td><td>-1.829<sup>***</sup></td><td>-2.296<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.020)</td><td>(0.021)</td><td>(0.723)</td></tr><tr><t ...
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# **Employment**

# %%
# group by year and occupational code
emp_df_med = df_medical_grp.groupby(['YEAR', 'OCCSOC', 'IND1990']).agg({'EDUC': 'mean', 
                                                                        'AGE': 'mean',
                                                                        'PERWT': 'sum'}).reset_index()

emp_df_med = emp_df_med[(emp_df_med['YEAR'] <= 2017) & (emp_df_med['OCCSOC'] != '432021')]
emp_df_med['LOGEMP'] = np.log(emp_df_med['PERWT'])
emp_df_med['LOGEDUC'] = np.log(emp_df_med['EDUC'])
emp_df_med['LOGAGE'] = np.log(emp_df_med['AGE'])
emp_df_med.head()
# Out:
#    YEAR  OCCSOC  IND1990       EDUC        AGE   PERWT     LOGEMP   LOGEDUC  \
# 0  2000  291060      812  10.966951  45.883529  470680  13.061934  2.394886
# 2  2000  436010      812   6.883488  41.016718  161962  11.995117  1.929125
# 3  2001  291060      812  10.962547  46.046816  227575  12.335235  2.394485
# 5  2001  436010      812   7.046083  41.451613   95363  11.465446  1.952472
# 6  2002  291060      812  10.933333  46.100000  231405  12.351925  2.391816
#
#      LOGAGE
# 0  3.826106
# 2  3.713980
# 3  3.829659
# 5  3.724527
# 6  3.830813

# %%
emp_df_med['Pre'] = emp_df_med['YEAR'].apply(lambda x: 1 if x < 2011 else 0)
emp_df_med['Post'] = emp_df_med['YEAR'].apply(lambda x: 1 if x >= 2011 else 0)
emp_df_med['AI'] = emp_df_med['OCCSOC'].apply(lambda x: 1 if x == '436010' else 0)
emp_df_med['AIPost'] = emp_df_med['AI']*emp_df_med['Post']
#wage_df_med = wage_df_med[wage_df_med['YEAR'] >= 2005]

ind_dummies = pd.get_dummies(emp_df_med['IND1990']).rename(columns= lambda x: 'ind_' + str(x)).iloc[:, :-1]
year_dummies = pd.get_dummies(emp_df_med['YEAR']).iloc[:, :-1].rename(columns = lambda x: str(x))

# %%
X = emp_df_med[['Post', 'AI', 'AIPost']]
X = smf.add_constant(X)
Y = emp_df_med['LOGEMP']
empferes1 = smf.OLS(Y,X).fit()

X = pd.concat([emp_df_med[['Post', 'AI', 'AIPost']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = emp_df_med['LOGEMP']
empferes2 = smf.OLS(Y,X).fit()

X = pd.concat([emp_df_med[['Post', 'AI', 'AIPost', 'LOGEDUC', 'LOGAGE']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = emp_df_med['LOGEMP']
empferes3 = smf.OLS(Y,X).fit()
               
stargazer = Stargazer([empferes1, empferes2, empferes3])
stargazer.title("Employment OLS Regs")
stargazer.custom_columns(['No Controls', 'Year FE', 'Year FE + Controls'], [1, 1, 1])
stargazer
# Out:
# Employment OLS Regs<br><table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:LOGEMP</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">No Controls</td><td colspan="1">Year FE</td><td colspan="1">Year FE + Controls</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">2000</td><td></td><td>1.527<sup>***</sup></td><td>0.751<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.539)</td></tr><tr><td style="text-align:left">2001</td><td></td><td>0.899<sup>***</sup></td><td>0.086<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.561)</td></tr><tr><td style="text-align:left">2002</td><td></td><td>0.844<sup>***</sup></td><td>0.050<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.561)</td></tr><tr><td style="text-align:left">2003</td><td></td><td>0.880<sup>***</sup></td><td>0.067<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.576)</td></tr><tr><td style="text-align:left">2004</td><td></td><td>0.937<sup>***</sup></td><td>0.098<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.589)</td></tr><tr><td style="text-align:left">2005</td><td></td><td>0.973<sup>***</sup></td><td>0.129<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.598)</td></tr><tr><td style="text-align:left">2006</td><td></td><td>0.955<sup>***</sup></td><td>0.094<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.611)</td></tr><tr><td style="text-align:left">2007</td><td></td><td>0.930<sup>***</sup></td><td>0.054<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.617)</td></tr><tr><td style="text-align:left">2008</td><td></td><td>0.907<sup>***</sup></td><td>0.052<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.609)</td></tr><tr><td style="text-align:left">2009</td><td></td><td>0.937<sup>***</sup></td><td>0.033<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.640)</td></tr><tr><td style="text-align:left">2010</td><td></td><td>0.870<sup>***</sup></td><td>-0.014<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.039)</td><td>(0.625)</td></tr><tr><td style="text-align:left">2011</td><td></td><td>0.086<sup></sup></td><td>0.119<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.057)</td><td>(0.061)</td></tr><tr><td style="text-align:left">2012</td><td></td><td>0.044<sup></sup></td><td>0.050<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.057)</td><td>(0.058)</td></tr><tr><td style="text-align:left">2013</td><td></td><td>0.068<sup></sup></td><td>0.093<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.057)</td><td>(0.059)</td></tr><tr><td style="text-align:left">2014</td><td></td><td>-0.012<sup></sup></td><td>0.014<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.057)</td><td>(0.059)</td></tr><tr><td style="text-align:left">2015</td><td></td><td>0.036<sup></sup></td><td>0.050<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.057)</td><td>(0.058)</td></tr><tr><td style="text-align:left">2016</td><td></td><td>-0.044<sup></sup></td><td>-0.029<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.057)</td><td>(0.057)</td></tr><tr><td style="text-align:left">AI</td><td>-0.983<sup>***</sup></td><td>-0.983<sup>***</sup></td><td>0.214<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.067)</td><td>(0.024)</td><td>(0.787)</td></tr><tr><td style="text-align: ...
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# **Regular OLS on Number of Patents**

# %% [markdown]
# **Log Wages**

# %%
aw = aipatents_world.iloc[:-2, :]
dw_ols = wage_df_med[['YEAR', 'OCCSOC', 'LOGWAGE_REAL', 'EDUC', 'AGE']]
dw_ols_p = pd.concat([dw_ols[dw_ols['OCCSOC'] == '291060'].reset_index(), np.log(aw['num_patents'])], axis=1)
dw_ols_s = pd.concat([dw_ols[dw_ols['OCCSOC'] == '436010'].reset_index(), np.log(aw['num_patents'])], axis=1)
dw_ols_p
# Out:
#     index  YEAR  OCCSOC  LOGWAGE_REAL       EDUC        AGE  num_patents
# 0       0  2000  291060     11.791087  10.966951  45.883529     6.722630
# 1       3  2001  291060     11.800783  10.962547  46.046816     7.037906
# 2       6  2002  291060     11.916533  10.933333  46.100000     7.280697
# 3       9  2003  291060     11.810614  10.973776  46.722902     7.234177
# 4      12  2004  291060     11.692556  10.960000  46.957333     7.354362
# 5      15  2005  291060     11.882664  10.987208  47.468774     7.373374
# 6      18  2006  291060     11.880519  10.985630  47.667281     7.362645
# 7      21  2007  291060     11.879649  10.988789  47.546338     7.505492
# 8      24  2008  291060     11.862037  10.877734  47.961719     7.585281
# 9      27  2009  291060     11.912521  10.975299  48.155538     7.688455
# 10     30  2010  291060     11.904495  10.976077  48.446172     7.730614
# 11     33  2011  291060     11.853552  10.956768  48.963232     7.718685
# 12     36  2012  291060     11.895491  10.977041  49.009779     7.755767
# 13     39  2013  291060     11.923922  10.944747  48.912840     7.784889
# 14     42  2014  291060     11.924632  11.000000  49.057627     7.908019
# 15     45  2015  291060     11.971957  10.960097  49.583233     7.999679
# 16     48  2016  291060     12.019923  10.954813  49.410609     8.085487
# 17     51  2017  291060     11.982032  10.946365  48.960667     8.146419

# %%
# dw = pd.merge(data_wages, aw[['Year', 'num_patents']], how='inner', on='Year')

X = dw_ols_p[['num_patents', 'EDUC', 'AGE']]
X = smf.add_constant(X)
Y = dw_ols_p['LOGWAGE_REAL']
wage_res1 = smf.OLS(Y, X).fit()


X = dw_ols_s[['num_patents', 'EDUC', 'AGE']]
X = smf.add_constant(X)
Y = dw_ols_s['LOGWAGE_REAL']
wage_res2 = smf.OLS(Y, X).fit()

stargazer = Stargazer([wage_res1, wage_res2])
stargazer.title("Employment OLS Regs")
stargazer.custom_columns(['Physicians', 'Secretaries'], [1, 1])
stargazer
# Out:
# Employment OLS Regs<br><table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable:LOGWAGE_REAL</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Physicians</td><td colspan="1">Secretaries</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">AGE</td><td>-0.011<sup></sup></td><td>0.003<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.033)</td><td>(0.008)</td></tr><tr><td style="text-align:left">EDUC</td><td>0.094<sup></sup></td><td>0.113<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.504)</td><td>(0.074)</td></tr><tr><td style="text-align:left">const</td><td>9.948<sup>*</sup></td><td>9.308<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(5.397)</td><td>(0.397)</td></tr><tr><td style="text-align:left">num_patents</td><td>0.192<sup>*</sup></td><td>-0.026<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.106)</td><td>(0.037)</td></tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>18</td><td>18</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.583</td><td>0.217</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.494</td><td>0.050</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.055 (df=14)</td><td>0.022 (df=14)</td></tr><tr><td style="text-align: left">F Statistic</td><td>6.525<sup>***</sup> (df=3; 14)</td><td>1.295<sup></sup> (df=3; 14)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="2" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %% [markdown]
# **Log Emp**

# %%
aw = aipatents_world.iloc[:-2, :]
de_ols = emp_df_med[['YEAR', 'OCCSOC', 'LOGEMP', 'EDUC', 'AGE']]
de_ols_p = pd.concat([de_ols[de_ols['OCCSOC'] == '291060'].reset_index(), np.log(aw['num_patents'])], axis=1)
de_ols_s = pd.concat([de_ols[de_ols['OCCSOC'] == '436010'].reset_index(), np.log(aw['num_patents'])], axis=1)
de_ols_p
# Out:
#     index  YEAR  OCCSOC     LOGEMP       EDUC        AGE  num_patents
# 0       0  2000  291060  13.061934  10.966951  45.883529     6.722630
# 1       3  2001  291060  12.335235  10.962547  46.046816     7.037906
# 2       6  2002  291060  12.351925  10.933333  46.100000     7.280697
# 3       9  2003  291060  12.449046  10.973776  46.722902     7.234177
# 4      12  2004  291060  12.430108  10.960000  46.957333     7.354362
# 5      15  2005  291060  12.450206  10.987208  47.468774     7.373374
# 6      18  2006  291060  12.450058  10.985630  47.667281     7.362645
# 7      21  2007  291060  12.437803  10.988789  47.546338     7.505492
# 8      24  2008  291060  12.387794  10.877734  47.961719     7.585281
# 9      27  2009  291060  12.378365  10.975299  48.155538     7.688455
# 10     30  2010  291060  12.350770  10.976077  48.446172     7.730614
# 11     33  2011  291060  12.393257  10.956768  48.963232     7.718685
# 12     36  2012  291060  12.323078  10.977041  49.009779     7.755767
# 13     39  2013  291060  12.386551  10.944747  48.912840     7.784889
# 14     42  2014  291060  12.290239  11.000000  49.057627     7.908019
# 15     45  2015  291060  12.352987  10.960097  49.583233     7.999679
# 16     48  2016  291060  12.370693  10.954813  49.410609     8.085487
# 17     51  2017  291060  12.351410  10.946365  48.960667     8.146419

# %%
X = de_ols_p[['num_patents', 'EDUC', 'AGE']]
X = smf.add_constant(X)
Y = de_ols_p['LOGEMP']
emp_res1 = smf.OLS(Y, X).fit()


X = de_ols_s[['num_patents', 'EDUC', 'AGE']]
X = smf.add_constant(X)
Y = de_ols_s['LOGEMP']
emp_res2 = smf.OLS(Y, X).fit()

stargazer = Stargazer([emp_res1, emp_res2])
stargazer.title("Employment OLS Regs")
stargazer.custom_columns(['Physicians', 'Secretaries'], [1, 1])
stargazer
# Out:
# Employment OLS Regs<br><table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable:LOGEMP</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">Physicians</td><td colspan="1">Secretaries</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">AGE</td><td>0.131<sup></sup></td><td>0.013<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.076)</td><td>(0.040)</td></tr><tr><td style="text-align:left">EDUC</td><td>-0.413<sup></sup></td><td>0.618<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(1.173)</td><td>(0.377)</td></tr><tr><td style="text-align:left">const</td><td>15.889<sup></sup></td><td>11.004<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(12.564)</td><td>(2.022)</td></tr><tr><td style="text-align:left">num_patents</td><td>-0.687<sup>**</sup></td><td>-0.601<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.247)</td><td>(0.188)</td></tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>18</td><td>18</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.521</td><td>0.671</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.418</td><td>0.600</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.127 (df=14)</td><td>0.112 (df=14)</td></tr><tr><td style="text-align: left">F Statistic</td><td>5.074<sup>**</sup> (df=3; 14)</td><td>9.510<sup>***</sup> (df=3; 14)</td></tr><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="2" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %%
wage_df_full = df_medical_grp[['YEAR', 'OCCSOC', 'IND1990', 'AGE', 'EDUC', 'LOGWAGE_REAL']]
wage_df_full['LOGEDUC'] = np.log(wage_df_full['EDUC'])
wage_df_full['LOGAGE'] = np.log(wage_df_full['AGE'])
wage_df_full = wage_df_full[(wage_df_full['YEAR'] <= 2017) & (wage_df_full['OCCSOC'] != '432021')]
wage_df_full
# Out:
# /Users/sidsatya/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/sidsatya/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#           YEAR  OCCSOC  IND1990  AGE  EDUC  LOGWAGE_REAL   LOGEDUC    LOGAGE
# 348       2000  291060      812   63    11     12.557778  2.397895  4.143135
# 381       2000  291060      812   54    11     12.557778  2.397895  3.988984
# 856       2000  436010      812   46     6      9.582249  1.791759  3.828641
# 874       2000  291060      812   48    11     12.557778  2.397895  3.871201
# 1901      2000  291060      812   61    11     12.557778  2.397895  4.110874
# ...        ...     ...      ...  ...   ...           ...       ...       ...
# 59015509  2017  291060      812   45    11     11.364808  2.397895  3.806662
# 59017397  2017  436010      812   58     6     10.131539  1.791759  4.060443
# 59025151  2017  291060      812   63    11     12.651848  2.397895  4.143135
# 59025235  2017  291060      812   63    11     11.531256  2.397895  4.143135
# 59027353  2017  436010      812   62    10     10.209501  2.302585  4.127134
#
# [65285 rows x 8 columns]

# %%
wage_df_full['Pre'] = wage_df_full['YEAR'].apply(lambda x: 1 if x < 2011 else 0)
wage_df_full['Post'] = wage_df_full['YEAR'].apply(lambda x: 1 if x >= 2011 else 0)
wage_df_full['AI'] = wage_df_full['OCCSOC'].apply(lambda x: 1 if x == '436010' else 0)
wage_df_full['AIPost'] = wage_df_full['AI']*wage_df_full['Post']
#wage_df_med = wage_df_med[wage_df_med['YEAR'] >= 2005]

ind_dummies = pd.get_dummies(wage_df_full['IND1990']).rename(columns= lambda x: 'ind_' + str(x)).iloc[:, :-1]
year_dummies = pd.get_dummies(wage_df_full['YEAR']).iloc[:, :-1].rename(columns = lambda x: str(x))
wage_df_full
# Out:
#           YEAR  OCCSOC  IND1990  AGE  EDUC  LOGWAGE_REAL   LOGEDUC    LOGAGE  \
# 348       2000  291060      812   63    11     12.557778  2.397895  4.143135
# 381       2000  291060      812   54    11     12.557778  2.397895  3.988984
# 856       2000  436010      812   46     6      9.582249  1.791759  3.828641
# 874       2000  291060      812   48    11     12.557778  2.397895  3.871201
# 1901      2000  291060      812   61    11     12.557778  2.397895  4.110874
# ...        ...     ...      ...  ...   ...           ...       ...       ...
# 59015509  2017  291060      812   45    11     11.364808  2.397895  3.806662
# 59017397  2017  436010      812   58     6     10.131539  1.791759  4.060443
# 59025151  2017  291060      812   63    11     12.651848  2.397895  4.143135
# 59025235  2017  291060      812   63    11     11.531256  2.397895  4.143135
# 59027353  2017  436010      812   62    10     10.209501  2.302585  4.127134
#
#           Pre  Post  AI  AIPost
# 348         1     0   0       0
# 381         1     0   0       0
# 856         1     0   1       0
# 874         1     0   0       0
# 1901        1     0   0       0
# ...       ...   ...  ..     ...
# 59015509    0     1   0       0
# 59017397    0     1   1       1
# 59025151    0     1   0       0
# 59025235    0     1   0       0
# 59027353    0     1   1       1
#
# [65285 rows x 12 columns]

# %%
X = wage_df_full[['Post', 'AI', 'AIPost']]
X = smf.add_constant(X)
Y = wage_df_full['LOGWAGE_REAL']
fe_w_res1 = smf.OLS(Y,X).fit()

X = pd.concat([wage_df_full[['Post', 'AI', 'AIPost']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = wage_df_full['LOGWAGE_REAL']
fe_w_res2 = smf.OLS(Y,X).fit()

X = pd.concat([wage_df_full[['Post', 'AI', 'AIPost', 'EDUC', 'AGE']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = wage_df_full['LOGWAGE_REAL']
fe_w_res3 = smf.OLS(Y,X).fit()

stargazer = Stargazer([fe_w_res1, fe_w_res2, fe_w_res3])
stargazer.title("Wage OLS Regs")
stargazer.custom_columns(['No Controls', 'Year FE', 'Year FE + Controls'], [1, 1, 1])
stargazer
# Out:
# Wage OLS Regs<br><table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:LOGWAGE_REAL</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">No Controls</td><td colspan="1">Year FE</td><td colspan="1">Year FE + Controls</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">2000</td><td></td><td>742101245989.065<sup></sup></td><td>0.815<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.529)</td><td>(0.007)</td></tr><tr><td style="text-align:left">2001</td><td></td><td>742101245988.921<sup></sup></td><td>0.814<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.526)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2002</td><td></td><td>742101245989.040<sup></sup></td><td>0.886<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.527)</td><td>(0.019)</td></tr><tr><td style="text-align:left">2003</td><td></td><td>742101245988.962<sup></sup></td><td>0.818<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.528)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2004</td><td></td><td>742101245988.889<sup></sup></td><td>0.730<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.526)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2005</td><td></td><td>742101245989.021<sup></sup></td><td>0.862<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.528)</td><td>(0.012)</td></tr><tr><td style="text-align:left">2006</td><td></td><td>742101245989.025<sup></sup></td><td>0.856<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.530)</td><td>(0.012)</td></tr><tr><td style="text-align:left">2007</td><td></td><td>742101245989.027<sup></sup></td><td>0.859<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.527)</td><td>(0.012)</td></tr><tr><td style="text-align:left">2008</td><td></td><td>742101245988.993<sup></sup></td><td>0.837<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.527)</td><td>(0.012)</td></tr><tr><td style="text-align:left">2009</td><td></td><td>742101245989.044<sup></sup></td><td>0.884<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.528)</td><td>(0.012)</td></tr><tr><td style="text-align:left">2010</td><td></td><td>742101245989.041<sup></sup></td><td>0.879<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(696722947999.527)</td><td>(0.013)</td></tr><tr><td style="text-align:left">2011</td><td></td><td>-0.102<sup>***</sup></td><td>-0.101<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.018)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2012</td><td></td><td>-0.069<sup>***</sup></td><td>-0.071<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.018)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2013</td><td></td><td>-0.054<sup>***</sup></td><td>-0.052<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.018)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2014</td><td></td><td>-0.050<sup>***</sup></td><td>-0.050<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.019)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2015</td><td></td><td>-0.016<sup></sup></td><td>-0.018<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.018)</td><td>(0.018)</td></tr><tr><td style="text-align:left">2016</td><td></td><td>0.026<sup></sup></td><td>0.024<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.01 ...
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %%
emp_df_full = df_medical_grp[['YEAR', 'OCCSOC', 'IND1990', 'AGE', 'EDUC', 'PERWT', 'RACE']]
emp_df_full = emp_df_full[emp_df_full['PERWT'] > 0]
emp_df_full['LOGEMP'] = np.log(emp_df_full['PERWT'])
emp_df_full['LOGEDUC'] = np.log(emp_df_full['EDUC'])
emp_df_full['LOGAGE'] = np.log(emp_df_full['AGE'])
emp_df_full = emp_df_full[(emp_df_full['YEAR'] <= 2017) & (emp_df_full['OCCSOC'] != '432021')]
emp_df_full
# Out:
# /Users/sidsatya/miniconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#           YEAR  OCCSOC  IND1990  AGE  EDUC  PERWT  RACE    LOGEMP   LOGEDUC  \
# 348       2000  291060      812   63    11     18     1  2.890372  2.397895
# 381       2000  291060      812   54    11     21     1  3.044522  2.397895
# 856       2000  436010      812   46     6     23     1  3.135494  1.791759
# 874       2000  291060      812   48    11     21     1  3.044522  2.397895
# 1901      2000  291060      812   61    11     21     1  3.044522  2.397895
# ...        ...     ...      ...  ...   ...    ...   ...       ...       ...
# 59015509  2017  291060      812   45    11     31     1  3.433987  2.397895
# 59017397  2017  436010      812   58     6     39     1  3.663562  1.791759
# 59025151  2017  291060      812   63    11     71     1  4.262680  2.397895
# 59025235  2017  291060      812   63    11     21     1  3.044522  2.397895
# 59027353  2017  436010      812   62    10    111     1  4.709530  2.302585
#
#             LOGAGE
# 348       4.143135
# 381       3.988984
# 856       3.828641
# 874       3.871201
# 1901      4.110874
# ...            ...
# 59015509  3.806662
# 59017397  4.060443
# 59025151  4.143135
# 59025235  4.143135
# 59027353  4.127134
#
# [65284 rows x 10 columns]

# %%
emp_df_full['Pre'] = emp_df_full['YEAR'].apply(lambda x: 1 if x < 2011 else 0)
emp_df_full['Post'] = emp_df_full['YEAR'].apply(lambda x: 1 if x >= 2011 else 0)
emp_df_full['AI'] = emp_df_full['OCCSOC'].apply(lambda x: 1 if x == '436010' else 0)
emp_df_full['AIPost'] = emp_df_full['AI']*emp_df_full['Post']
#wage_df_med = wage_df_med[wage_df_med['YEAR'] >= 2005]

ind_dummies = pd.get_dummies(emp_df_full['IND1990']).rename(columns= lambda x: 'ind_' + str(x)).iloc[:, :-1]
year_dummies = pd.get_dummies(emp_df_full['YEAR']).iloc[:, :-1].rename(columns = lambda x: str(x))
race_dummies = pd.get_dummies(emp_df_full['RACE']).iloc[:, :-1].rename(columns = lambda x: 'race_'+ str(x))
emp_df_full
# Out:
#           YEAR  OCCSOC  IND1990  AGE  EDUC  PERWT  RACE    LOGEMP   LOGEDUC  \
# 348       2000  291060      812   63    11     18     1  2.890372  2.397895
# 381       2000  291060      812   54    11     21     1  3.044522  2.397895
# 856       2000  436010      812   46     6     23     1  3.135494  1.791759
# 874       2000  291060      812   48    11     21     1  3.044522  2.397895
# 1901      2000  291060      812   61    11     21     1  3.044522  2.397895
# ...        ...     ...      ...  ...   ...    ...   ...       ...       ...
# 59015509  2017  291060      812   45    11     31     1  3.433987  2.397895
# 59017397  2017  436010      812   58     6     39     1  3.663562  1.791759
# 59025151  2017  291060      812   63    11     71     1  4.262680  2.397895
# 59025235  2017  291060      812   63    11     21     1  3.044522  2.397895
# 59027353  2017  436010      812   62    10    111     1  4.709530  2.302585
#
#             LOGAGE  Pre  Post  AI  AIPost
# 348       4.143135    1     0   0       0
# 381       3.988984    1     0   0       0
# 856       3.828641    1     0   1       0
# 874       3.871201    1     0   0       0
# 1901      4.110874    1     0   0       0
# ...            ...  ...   ...  ..     ...
# 59015509  3.806662    0     1   0       0
# 59017397  4.060443    0     1   1       1
# 59025151  4.143135    0     1   0       0
# 59025235  4.143135    0     1   0       0
# 59027353  4.127134    0     1   1       1
#
# [65284 rows x 14 columns]

# %%
X = emp_df_full[['Post', 'AI', 'AIPost']]
X = smf.add_constant(X)
Y = emp_df_full['LOGEMP']
fe_w_res1 = smf.OLS(Y,X).fit()

X = pd.concat([emp_df_full[['Post', 'AI', 'AIPost']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = emp_df_full['LOGEMP']
fe_w_res2 = smf.OLS(Y,X).fit()

X = pd.concat([emp_df_full[['Post', 'AI', 'AIPost', 'EDUC', 'AGE', 'RACE']], year_dummies], axis=1)
X = smf.add_constant(X)
Y = emp_df_full['LOGEMP']
fe_w_res3 = smf.OLS(Y,X).fit()

stargazer = Stargazer([fe_w_res1, fe_w_res2, fe_w_res3])
stargazer.title("Employment OLS Regs")
stargazer.custom_columns(['No Controls', 'Year FE', 'Year FE + Controls'], [1, 1, 1])
stargazer
# Out:
# Employment OLS Regs<br><table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable:LOGEMP</em></td></tr><tr><td style="text-align:left"></td><tr><td></td><td colspan="1">No Controls</td><td colspan="1">Year FE</td><td colspan="1">Year FE + Controls</td></tr><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">2000</td><td></td><td>220554080164.468<sup></sup></td><td>-1.171<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.325)</td><td>(0.006)</td></tr><tr><td style="text-align:left">2001</td><td></td><td>220554080166.640<sup></sup></td><td>1.002<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.324)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2002</td><td></td><td>220554080166.780<sup></sup></td><td>1.135<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.323)</td><td>(0.017)</td></tr><tr><td style="text-align:left">2003</td><td></td><td>220554080166.701<sup></sup></td><td>1.058<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.328)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2004</td><td></td><td>220554080166.692<sup></sup></td><td>1.051<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.325)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2005</td><td></td><td>220554080165.848<sup></sup></td><td>0.210<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.324)</td><td>(0.011)</td></tr><tr><td style="text-align:left">2006</td><td></td><td>220554080165.847<sup></sup></td><td>0.208<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.324)</td><td>(0.011)</td></tr><tr><td style="text-align:left">2007</td><td></td><td>220554080165.841<sup></sup></td><td>0.202<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.323)</td><td>(0.011)</td></tr><tr><td style="text-align:left">2008</td><td></td><td>220554080165.833<sup></sup></td><td>0.199<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.326)</td><td>(0.011)</td></tr><tr><td style="text-align:left">2009</td><td></td><td>220554080165.826<sup></sup></td><td>0.193<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.323)</td><td>(0.011)</td></tr><tr><td style="text-align:left">2010</td><td></td><td>220554080165.830<sup></sup></td><td>0.196<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(561726533860.324)</td><td>(0.011)</td></tr><tr><td style="text-align:left">2011</td><td></td><td>0.001<sup></sup></td><td>0.003<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.016)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2012</td><td></td><td>0.043<sup>***</sup></td><td>0.046<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.016)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2013</td><td></td><td>0.008<sup></sup></td><td>0.008<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.016)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2014</td><td></td><td>0.015<sup></sup></td><td>0.016<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.016)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2015</td><td></td><td>0.027<sup>*</sup></td><td>0.030<sup>*</sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.016)</td><td>(0.016)</td></tr><tr><td style="text-align:left">2016</td><td></td><td>0.006<sup></sup></td><td>0.006<sup></sup></td></tr><tr><td style="text-align:left"></td><td></td><td>(0.016)</td><td>(0.016)</td></ ...
#  <td colspan="3" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>
